# %% [markdown]
# # Autotalker Hyperparameter Tuning

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of Computational Biology (ICB), Talavera-López Lab
# - **Date of Creation:** 07.12.2022
# - **Date of Last Modification:** 10.01.2023

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../autotalker") # 'autotalker' repo https://github.com/sebastianbirk/autotalker.git needs to be cloned into same folder as 'autotalker-reproducibility'

# %%
import itertools
import os
import random
import warnings
from datetime import datetime

import anndata as ad
import matplotlib
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sp
import seaborn as sns
import squidpy as sq

from autotalker.models import Autotalker
from autotalker.utils import (add_gps_from_gp_dict_to_adata,
                              extract_gp_dict_from_mebocost_es_interactions,
                              extract_gp_dict_from_nichenet_ligand_target_mx,
                              extract_gp_dict_from_omnipath_lr_interactions,
                              filter_and_combine_gp_dict_gps)

# %% [markdown]
# ### 1.2 Define Parameters

# %%
## Model
# Dataset
dataset = "seqfish_mouse_organogenesis_embryo1"

# Anndata keys
counts_key = "counts"
cell_type_key = "celltype_mapped_refined"
adj_key = "spatial_connectivities"
spatial_key = "spatial"
gp_names_key = "autotalker_gp_names"
active_gp_names_key = "autotalker_active_gp_names"
gp_targets_mask_key = "autotalker_gp_targets"
gp_sources_mask_key = "autotalker_gp_sources"
latent_key = "autotalker_latent"

## Others
random_seed = 42

# %% [markdown]
# ### 1.3 Run Notebook Setup

# %%
# Ignore future warnings and user warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

# %% [markdown]
# ### 1.4 Configure Paths and Create Directories

# %%
# Define paths
figure_folder_path = "../figures"
model_artifacts_folder_path = "../model_artifacts"
gp_data_folder_path = "../datasets/gp_data" # gene program data
srt_data_folder_path = "../datasets/srt_data" # spatially resolved transcriptomics data
srt_data_gold_folder_path = f"{srt_data_folder_path}/gold"
nichenet_ligand_target_mx_file_path = gp_data_folder_path + "/nichenet_ligand_target_matrix.csv"
omnipath_lr_interactions_file_path = gp_data_folder_path + "/omnipath_lr_interactions.csv"

# Create required directories
os.makedirs(figure_folder_path, exist_ok=True)
os.makedirs(model_artifacts_folder_path, exist_ok=True)
os.makedirs(gp_data_folder_path, exist_ok=True)

# %% [markdown]
# ### 1.5 Define Functions

# %%
def run_hyperparam_tuning(dataset,
                          hyperparam_option_dict,
                          n_iters,
                          experiment_name,
                          gp_mask="combined_priors",
                          save_figures=False,
                          save_model=False):
    # Read dataset
    print("--- DATASET ---")
    print(f"Using dataset {dataset}.")
    adata = ad.read_h5ad(f"{srt_data_gold_folder_path}/{dataset}.h5ad")
    n_nodes = adata.layers["counts"].shape[0]
    n_genes = adata.layers["counts"].shape[1]
    print(f"Number of nodes (cells): {n_nodes}.")
    print(f"Number of node features (genes): {n_genes}.")
        
    # Retrieve gene program mask
    print("")
    print("--- GENE PROGRAMS ---")
    print(f"Using '{gp_mask}' GP mask.")
    
    if gp_mask == "fc":
        n_output = len(adata.var) * 2
        adata.varm[gp_targets_mask_key] = np.ones((len(adata.var), len(adata.var)))
        adata.varm[gp_sources_mask_key] = np.ones((len(adata.var), len(adata.var)))
        adata.uns[gp_names_key] = np.array([f"FC_GP_{i}" for i in range(len(adata.var))])
    
    elif gp_mask == "combined_priors":
        nichenet_keep_target_ratio = 0.01
        omnipath_min_curation_effort = 0
        gp_filter_mode = "subset"
        combine_overlap_gps = True
        overlap_thresh_source_genes = 0.9
        overlap_thresh_target_genes = 0.9
        overlap_thresh_genes = 0.9
        min_genes_per_gp = 1
        min_source_genes_per_gp = 0
        min_target_genes_per_gp = 0
        
        nichenet_gp_dict = extract_gp_dict_from_nichenet_ligand_target_mx(
            keep_target_ratio=nichenet_keep_target_ratio,
            load_from_disk=False,
            save_to_disk=False,
            file_path=nichenet_ligand_target_mx_file_path)
        omnipath_gp_dict = extract_gp_dict_from_omnipath_lr_interactions(
            min_curation_effort=omnipath_min_curation_effort,
            load_from_disk=False,
            save_to_disk=False,
            file_path=omnipath_lr_interactions_file_path)
        mebocost_gp_dict = extract_gp_dict_from_mebocost_es_interactions(
            dir_path = f"{gp_data_folder_path}/metabolite_enzyme_sensor_gps/",
            species="mouse",
            genes_uppercase=True)
        combined_gp_dict = dict(nichenet_gp_dict)
        combined_gp_dict.update(omnipath_gp_dict)
        combined_gp_dict.update(mebocost_gp_dict)

        # Filter and combine gene programs
        combined_new_gp_dict = filter_and_combine_gp_dict_gps(
            gp_dict=combined_gp_dict,
            gp_filter_mode=gp_filter_mode,
            combine_overlap_gps=combine_overlap_gps,
            overlap_thresh_source_genes=overlap_thresh_source_genes,
            overlap_thresh_target_genes=overlap_thresh_target_genes,
            overlap_thresh_genes=overlap_thresh_genes,
            verbose=True)

        print(f"Number of gene programs before filtering and combining: {len(combined_gp_dict)}.")
        print(f"Number of gene programs after filtering and combining: {len(combined_new_gp_dict)}.")
        
        # Add the gene program dictionary as binary masks to the adata for model training
        add_gps_from_gp_dict_to_adata(
            gp_dict=combined_new_gp_dict,
            adata=adata,
            genes_uppercase=True,
            gp_targets_mask_key=gp_targets_mask_key,
            gp_sources_mask_key=gp_sources_mask_key,
            gp_names_key=gp_names_key,
            min_genes_per_gp=min_genes_per_gp,
            min_source_genes_per_gp=min_source_genes_per_gp,
            min_target_genes_per_gp=min_target_genes_per_gp,
            max_genes_per_gp=None,
            max_source_genes_per_gp=None,
            max_target_genes_per_gp=None)
        
    # Summarize gene programs
    print(f"Number of gene programs with probed genes: {len(adata.uns['autotalker_gp_names'])}.")
    print(f"Example gene programs: {random.sample(list(adata.uns['autotalker_gp_names']), 5)}.")
    print(f"Number of gene program target genes: {adata.varm['autotalker_gp_targets'].sum()}.")
    print(f"Number of gene program source genes: {adata.varm['autotalker_gp_sources'].sum()}.")

    # Loop `n_iters` times through combination of hyperparams 
    iters = range(n_iters)
    hyperparams, hyperparam_values = zip(*hyperparam_option_dict.items())
    for hyperparam_comb in itertools.product(*hyperparam_values, iters):
        hyperparam_dict = {}
        for hyperparam, hyperparam_value in zip(hyperparams, hyperparam_comb):
            hyperparam_dict[hyperparam] = hyperparam_value
        
        experiment = mlflow.set_experiment(experiment_name)
            
        # Log dataset params
        mlflow.log_param("dataset", dataset)
        mlflow.log_param("n_nodes", n_nodes)
        mlflow.log_param("n_genes", n_genes)
    
        # Log gp mask params
        mlflow.log_param("gp_mask", gp_mask)
        mlflow.log_param("nichenet_keep_target_ratio", nichenet_keep_target_ratio)
        mlflow.log_param("omnipath_min_curation_effort", omnipath_min_curation_effort)
        mlflow.log_param("gp_filter_mode", gp_filter_mode)
        mlflow.log_param("combine_overlap_gps", combine_overlap_gps)
        mlflow.log_param("overlap_thresh_source_genes", overlap_thresh_source_genes)
        mlflow.log_param("overlap_thresh_target_genes", overlap_thresh_target_genes)
        mlflow.log_param("overlap_thresh_genes", overlap_thresh_genes)
        mlflow.log_param("min_genes_per_gp", min_genes_per_gp)
        mlflow.log_param("min_source_genes_per_gp", min_source_genes_per_gp)
        mlflow.log_param("min_target_genes_per_gp", min_target_genes_per_gp) 
        
        if save_figures or save_model:
            # Get time for timestamping saved artifacts
            now = datetime.now()
            current_timestamp = now.strftime("%d%m%Y_%H%M%S")

            run_figure_folder_path = f"{figure_folder_path}/{dataset}/hyperparam_tuning/{experiment_name}/runs/{current_timestamp}"
            os.makedirs(run_figure_folder_path, exist_ok=True)
            run_model_artifacts_folder_path = f"{model_artifacts_folder_path}/{dataset}/hyperparam_tuning/{experiment_name}/runs/{current_timestamp}"
            os.makedirs(run_model_artifacts_folder_path, exist_ok=True)
        
        # Copy adata
        adata_run = adata.copy()

        print("")
        print("--- SPATIAL CONNECTIVITY ---")
        # Compute spatial neighborhood
        sq.gr.spatial_neighbors(adata_run,
                                coord_type="generic",
                                spatial_key=spatial_key,
                                radius=hyperparam_dict["radius"])
        avg_edges_per_node = round(adata_run.obsp['spatial_connectivities'].sum(axis=0).mean(), 2)
        print(f"Average number of edges per node: {avg_edges_per_node}.")
        n_edges = int(sp.triu(adata_run.obsp['spatial_connectivities'], k=1).sum())
        print(f"Number of total edges: {n_edges}.")
        mlflow.log_param("avg_n_neighbors", avg_edges_per_node)
        mlflow.log_param("n_edges", n_edges)
        avg_n_neighbors_rounded = int(round(avg_edges_per_node))

        # Initialize model
        print("")
        if hyperparam_dict["n_hidden_encoder_divisor"] is None:
            n_hidden_encoder = len(adata.uns[gp_names_key]) # gp mask size
        else:
            n_hidden_encoder = int(len(adata.var) / hyperparam_dict["n_hidden_encoder_divisor"])
        model = Autotalker(adata_run,
                           counts_key=counts_key,
                           adj_key=adj_key,
                           gp_names_key=gp_names_key,
                           active_gp_names_key=active_gp_names_key,
                           gp_targets_mask_key=gp_targets_mask_key,
                           gp_sources_mask_key=gp_sources_mask_key,
                           latent_key=latent_key,
                           gene_expr_recon_dist=hyperparam_dict["gene_expr_recon_dist"],
                           node_label_method=hyperparam_dict["node_label_method"],
                           active_gp_thresh_ratio=hyperparam_dict["active_gp_thresh_ratio"],
                           n_hidden_encoder=n_hidden_encoder,
                           conv_layer_encoder=hyperparam_dict["conv_layer_encoder"],
                           encoder_n_attention_heads=hyperparam_dict["encoder_n_attention_heads"])

        # Train model
        print("")
        model.train(n_epochs=hyperparam_dict["n_epochs"],
                    n_epochs_all_gps=hyperparam_dict["n_epochs_all_gps"],
                    lr=hyperparam_dict["lr"],
                    lambda_edge_recon=hyperparam_dict["lambda_edge_recon"],
                    lambda_gene_expr_recon=hyperparam_dict["lambda_gene_expr_recon"],
                    lambda_group_lasso=hyperparam_dict["lambda_group_lasso"],
                    edge_val_ratio=0.1,
                    node_val_ratio=0.1,
                    edge_batch_size=hyperparam_dict["batch_size"],
                    node_batch_size=hyperparam_dict["batch_size"],
                    mlflow_experiment_id=experiment.experiment_id,
                    verbose=True,
                    seed=random.randint(0, 10000))
        
        if save_figures:
            # Log visualizations
            # Use autotalker latent space for UMAP generation
            sc.pp.neighbors(model.adata, use_rep=latent_key)
            sc.tl.umap(model.adata, min_dist=0.3)

            # Create subplot of cell-type annotations in spatial and latent space
            fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 29))
            title = fig.suptitle(t="Cell-type Annotations in Spatial and Latent Space",
                                 x=0.85,
                                 y=0.925,
                                 fontsize=20)
            sc.pl.spatial(adata=model.adata,
                          color=[cell_type_key],
                          spot_size=0.03,
                          title="Spatial Space",
                          ax=axs[0],
                          show=False)
            sc.pl.umap(adata=model.adata,
                       color=[cell_type_key],
                       title="Latent Space",
                       ax=axs[1],
                       show=False)
            handles, labels = axs[0].get_legend_handles_labels()
            lgd = fig.legend(handles, labels, bbox_to_anchor=(1.225, 0.625))
            axs[0].get_legend().remove()
            axs[1].get_legend().remove()
            plt.subplots_adjust(wspace=0, hspace=0.1)
            fig.savefig(f"{run_figure_folder_path}/cell_type_annotations_in_spatial_and_latent_space.png",
                        bbox_extra_artists=(lgd, title),
                        bbox_inches="tight")
            plt.close(fig)

            # Create subplot of latent Leiden cluster annotations in latent and spatial space
            resolution = 0.3
            model.compute_latent_graph_connectivities(adata=model.adata,
                                                      n_neighbors=int(round(avg_edges_per_node)),
                                                      mode="knn",
                                                      seed=random_seed)
            sc.tl.leiden(adata=model.adata,
                         resolution=resolution,
                         random_state=random_seed,
                         key_added=f"leiden_latent_{str(resolution)}",
                         adjacency=model.adata.obsp["latent_connectivities"])
            fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 20))
            title = fig.suptitle(t="Latent Leiden Cluster Annotations in Latent and Spatial Space",
                                 x=0.85,
                                 y=0.925,
                                 fontsize=20)
            sc.pl.umap(adata=model.adata,
                       color=[f"leiden_latent_{str(resolution)}"],
                       title=f"Latent Space",
                       ax=axs[0],
                       show=False)
            sc.pl.spatial(adata=model.adata,
                          color=[f"leiden_latent_{str(resolution)}"],
                          spot_size=0.03,
                          title=f"Spatial Space",
                          ax=axs[1],
                          show=False)
            handles, labels = axs[0].get_legend_handles_labels()
            lgd = fig.legend(handles, labels, bbox_to_anchor=(1.025, 0.7))
            axs[0].get_legend().remove()
            axs[1].get_legend().remove()
            plt.subplots_adjust(wspace=0, hspace=0.1)
            fig.savefig(f"{run_figure_folder_path}/latent_leiden_cluster_annotations_in_latent_and_spatial_space.png",
                        bbox_extra_artists=(lgd, title),
                        bbox_inches="tight")
            plt.close(fig)

            mlflow.log_artifacts(run_figure_folder_path,
                                 current_timestamp)
        
        if save_model:            
            model.save(dir_path=run_model_artifacts_folder_path,
                       overwrite=True,
                       save_adata=True,
                       adata_file_name=f"{dataset}.h5ad")

        mlflow.end_run()
        print("--------------------")
        print("")
        print("--------------------")

# %%
def plot_hyperparam_benchmarking_metrics(fig_title,
                                         df,
                                         y_col_name,
                                         sort_col="val_mse_score",
                                         plot_ratio_active_gps=False,
                                         save_fig=False,
                                         file_name="benchmarking_metrics.png"):
    # Compute evaluation metric ranks for sorting
    val_mse_score_ranks = (df.groupby([y_col_name])
                           ["val_mse_score"].mean().rank(ascending=True)
                           .rename("val_mse_score_rank"))
    val_auroc_score_ranks = (df.groupby([y_col_name])
                                ["val_auroc_score"].mean().rank(ascending=False)
                                .rename("val_auroc_score_rank"))
    df = df.merge(val_mse_score_ranks, on=[y_col_name])
    df = df.merge(val_auroc_score_ranks, on=[y_col_name])

    if sort_col == "val_mse_score":
        df.sort_values(by=["val_mse_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    elif sort_col == "val_auroc_score":
        df.sort_values(by=["val_auroc_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    elif sort_col == "total_score":
        df["val_total_score_rank"] = (df["val_mse_score_rank"] + 
                                      df["val_auroc_score_rank"]).rank(ascending=True)
        df.sort_values(by=["val_total_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    
    if plot_ratio_active_gps:
        fig, axes = plt.subplots(3, 1, sharey=True, figsize=(10, 20))
        sns.boxplot(data=df, ax=axes[2], x="ratio_active_gps", y=y_col_name)
        axes[2].set_title("Ratio of Active Gene Programs")
    else:
        fig, axes = plt.subplots(2, 1, sharey=True, figsize=(10, 15))
    fig.suptitle(fig_title, fontsize=15)
    sns.boxplot(data=df, ax=axes[0], x="val_auroc_score", y=y_col_name)
    axes[0].set_title("Edge Reconstruction Area Under ROC Curve")
    sns.boxplot(data=df, ax=axes[1], x="val_mse_score", y=y_col_name)
    axes[1].set_title("Gene Expression Reconstruction Mean Squared Error")
    plt.subplots_adjust(left=0.1,
                        bottom=0.1,
                        right=0.9,
                        top=0.94,
                        wspace=0.175,
                        hspace=0.175)
    if save_fig:
        # Get time for timestamping saved artefacts
        now = datetime.now()
        current_timestamp = now.strftime("%d%m%Y_%H%M%S")
        benchmark_fig_run_dir = f"{figure_folder_path}/{dataset}/benchmarking/{experiment_name}/results/{current_timestamp}"
        os.makedirs(benchmark_fig_run_dir, exist_ok=True)
        plt.savefig(f"{benchmark_fig_run_dir}/{file_name}",
                    bbox_inches='tight')

# %% [markdown]
# ## 2. Hyperparameter Tuning Experiments

# %% [markdown]
# ### 2.1. Loss Weights

# %% [markdown]
# - Different combinations of the edge reconstruction loss and gene expression reconstruction loss weighting hyperparameters are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per loss weight combination.

# %%
experiment_name = "loss_weights"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = [64]

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200] # 0.10241
hyperparam_option_dict["lambda_edge_recon"] = [0, 0.1, 0.2, 0.33, 0.5, 1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [1.]

model = run_hyperparam_tuning(dataset=dataset,
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=1,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              save_model=False)
# Out:
# --- DATASET ---
# Using dataset seqfish_mouse_organogenesis_embryo1.
# Number of nodes (cells): 19451.
# Number of node features (genes): 351.
#
# --- GENE PROGRAMS ---
# Using 'combined_priors' GP mask.
# Downloading NicheNet ligand target potential matrix from the web. This might take a while...
# Removing GP 'CTF1_ligand_receptor_GP' as it is a subset of GP 'CTF1_ligand_targetgenes_GP'.
# Removing GP 'LEP_ligand_receptor_GP' as it is a subset of GP 'LEP_ligand_targetgenes_GP'.
# Removing GP 'IL4_ligand_receptor_GP' as it is a subset of GP 'IL4_ligand_targetgenes_GP'.
# Removing GP 'IL12A_ligand_receptor_GP' as it is a subset of GP 'IL12A_ligand_targetgenes_GP'.
# Removing GP 'IL23A_ligand_receptor_GP' as it is a subset of GP 'IL23A_ligand_targetgenes_GP'.
# Removing GP 'CSF2_ligand_receptor_GP' as it is a subset of GP 'CSF2_ligand_targetgenes_GP'.
# Removing GP 'IL21_ligand_receptor_GP' as it is a subset of GP 'IL21_ligand_targetgenes_GP'.
# Removing GP 'TSLP_ligand_receptor_GP' as it is a subset of GP 'TSLP_ligand_targetgenes_GP'.
# Removing GP 'GH2_ligand_receptor_GP' as it is a subset of GP 'GH2_ligand_targetgenes_GP'.
# Removing GP 'EGF_ligand_receptor_GP' as it is a subset of GP 'EGF_ligand_targetgenes_GP'.
# Removing GP 'IL10_ligand_receptor_GP' as it is a subset of GP 'IL10_ligand_targetgenes_GP'.
# Removing GP 'TNFSF4_ligand_receptor_GP' as it is a subset of GP 'TNFSF4_ligand_targetgenes_GP'.
# Removing GP 'TNFSF18_ligand_receptor_GP' as it is a subset of GP 'TNFSF18_ligand_targetgenes_GP'.
# Removing GP 'TGFB1_ligand_receptor_GP' as it is a subset of GP 'TGFB1_ligand_targetgenes_GP'.
# Removing GP 'BMP2_ligand_receptor_GP' as it is a subset of GP 'BMP2_ligand_targetgenes_GP'.
# Removing GP 'IL1B_ligand_receptor_GP' as it is a subset of GP 'IL1B_ligand_targetgenes_GP'.
# Removing GP 'CSH1_ligand_receptor_GP' as it is a subset of GP 'CSH1_ligand_targetgenes_GP'.
# Removing GP 'EDN1_ligand_receptor_GP' as it is a subset of GP 'EDN1_ligand_targetgenes_GP'.
# Removing GP 'EDN3_ligand_receptor_GP' as it is a subset of GP 'EDN3_ligand_targetgenes_GP'.
# Removing GP 'GCG_ligand_receptor_GP' as it is a subset of GP 'GCG_ligand_targetgenes_GP'.
# Removing GP 'HCRT_ligand_receptor_GP' as it is a subset of GP 'HCRT_ligand_targetgenes_GP'.
# Removing GP 'IGF1_ligand_receptor_GP' as it is a subset of GP 'IGF1_ligand_targetgenes_GP'.
# Removing GP 'GRP_ligand_receptor_GP' as it is a subset of GP 'GRP_ligand_targetgenes_GP'.
# Removing GP 'NTF3_ligand_receptor_GP' as it is a subset of GP 'NTF3_ligand_targetgenes_GP'.
# Removing GP 'AVP_ligand_receptor_GP' as it is a subset of GP 'AVP_ligand_targetgenes_GP'.
# Removing GP 'CSHL1_ligand_receptor_GP' as it is a subset of GP 'CSHL1_ligand_targetgenes_GP'.
# Removing GP 'PROK1_ligand_receptor_GP' as it is a subset of GP 'PROK1_ligand_targetgenes_GP'.
# Removing GP 'AGT_ligand_receptor_GP' as it is a subset of GP 'AGT_ligand_targetgenes_GP'.
# Removing GP 'GHRH_ligand_receptor_GP' as it is a subset of GP 'GHRH_ligand_targetgenes_GP'.
# Removing GP 'DLL3_ligand_receptor_GP' as it is a subset of GP 'DLL3_ligand_targetgenes_GP'.
# Removing GP 'DLL4_ligand_receptor_GP' as it is a subset of GP 'DLL4_ligand_targetgenes_GP'.
# Removing GP 'FGF23_ligand_receptor_GP' as it is a subset of GP 'FGF23_ligand_targetgenes_GP'.
# Removing GP 'GDF6_ligand_receptor_GP' as it is a subset of GP 'GDF6_ligand_targetgenes_GP'.
# Removing GP 'GDF9_ligand_receptor_GP' as it is a subset of GP 'GDF9_ligand_targetgenes_GP'.
# Removing GP 'IL12B_ligand_receptor_GP' as it is a subset of GP 'IL12B_ligand_targetgenes_GP'.
# Removing GP 'JAG1_ligand_receptor_GP' as it is a subset of GP 'JAG1_ligand_targetgenes_GP'.
# Removing GP 'CRLF1_ligand_receptor_GP' as it is a subset of GP 'CRLF1_ligand_targetgenes_GP'.
# Removing GP 'VGF_ligand_receptor_GP' as it is a subset of GP 'VGF_ligand_targetgenes_GP'.
# Removing GP 'IL27_ligand_receptor_GP' as it is a subset of GP 'IL27_ligand_targetgenes_GP'.
# Removing GP 'CMTM8_ligand_receptor_GP' as it is a subset of GP 'CMTM8_ligand_targetgenes_GP'.
# Removing GP 'SECTM1_ligand_receptor_GP' as it is a subset of GP 'SECTM1_ligand_targetgenes_GP'.
# Removing GP 'CMTM2_ligand_receptor_GP' as it is a subset of GP 'CMTM2_ligand_targetgenes_GP'.
# Removing GP 'BMP8A_ligand_receptor_GP' as it is a subset of GP 'BMP8A_ligand_targetgenes_GP'.
# Removing GP 'GDF3_ligand_receptor_GP' as it is a subset of GP 'GDF3_ligand_targetgenes_GP'.
# Removing GP 'EFNB3_ligand_targetgenes_GP' as it is a subset of GP 'EFNB3_ligand_receptor_GP'.
# Removing GP 'EFNB2_ligand_targetgenes_GP' as it is a subset of GP 'EFNB2_ligand_receptor_GP'.
# Removing GP 'EFNB1_ligand_targetgenes_GP' as it is a subset of GP 'EFNB1_ligand_receptor_GP'.
# Removing GP 'CCL23_ligand_targetgenes_GP' as it is a subset of GP 'CCL23_ligand_receptor_GP'.
# Removing GP 'CCL27_ligand_targetgenes_GP' as it is a subset of GP 'CCL27_ligand_receptor_GP'.
# Removing GP 'CCL28_ligand_targetgenes_GP' as it is a subset of GP 'CCL28_ligand_receptor_GP'.
# Removing GP 'CCL16_ligand_targetgenes_GP' as it is a subset of GP 'CCL16_ligand_receptor_GP'.
# Removing GP 'CXCL5_ligand_targetgenes_GP' as it is a subset of GP 'CXCL5_ligand_receptor_GP'.
# Removing GP 'PMCH_ligand_targetgenes_GP' as it is a subset of GP 'PMCH_ligand_receptor_GP'.
# Removing GP 'NMS_ligand_targetgenes_GP' as it is a subset of GP 'NMS_ligand_receptor_GP'.
# Removing GP 'NMU_ligand_targetgenes_GP' as it is a subset of GP 'NMU_ligand_receptor_GP'.
# Removing GP 'NPB_ligand_targetgenes_GP' as it is a subset of GP 'NPB_ligand_receptor_GP'.
# Removing GP 'NPW_ligand_targetgenes_GP' as it is a subset of GP 'NPW_ligand_receptor_GP'.
# Removing GP 'RLN3_ligand_targetgenes_GP' as it is a subset of GP 'RLN3_ligand_receptor_GP'.
# Removing GP 'PYY_ligand_targetgenes_GP' as it is a subset of GP 'PYY_ligand_receptor_GP'.
# Removing GP 'PPY_ligand_targetgenes_GP' as it is a subset of GP 'PPY_ligand_receptor_GP'.
# Removing GP 'NRG3_ligand_targetgenes_GP' as it is a subset of GP 'NRG3_ligand_receptor_GP'.
# Removing GP 'NRG4_ligand_targetgenes_GP' as it is a subset of GP 'NRG4_ligand_receptor_GP'.
# Removing GP 'FGF22_ligand_targetgenes_GP' as it is a subset of GP 'FGF22_ligand_receptor_GP'.
# Removing GP 'FGF13_ligand_targetgenes_GP' as it is a subset of GP 'FGF13_ligand_receptor_GP'.
# Removing GP 'FGF11_ligand_targetgenes_GP' as it is a subset of GP 'FGF11_ligand_receptor_GP'.
# Removing GP 'FGF14_ligand_targetgenes_GP' as it is a subset of GP 'FGF14_ligand_receptor_GP'.
# Removing GP 'PODXL2_ligand_targetgenes_GP' as it is a subset of GP 'PODXL2_ligand_receptor_GP'.
# Removing GP 'ADM2_ligand_targetgenes_GP' as it is a subset of GP 'ADM2_ligand_receptor_GP'.
# Removing GP 'APOB_ligand_targetgenes_GP' as it is a subset of GP 'APOB_ligand_receptor_GP'.
# Removing GP 'NPS_ligand_targetgenes_GP' as it is a subset of GP 'NPS_ligand_receptor_GP'.
# Removing GP 'PTH2_ligand_targetgenes_GP' as it is a subset of GP 'PTH2_ligand_receptor_GP'.
# Removing GP 'INSL3_ligand_targetgenes_GP' as it is a subset of GP 'INSL3_ligand_receptor_GP'.
# Removing GP 'NECTIN3_ligand_targetgenes_GP' as it is a subset of GP 'NECTIN3_ligand_receptor_GP'.
# Removing GP 'LAMA1_ligand_targetgenes_GP' as it is a subset of GP 'LAMA1_ligand_receptor_GP'.
# Removing GP 'WNT9A_ligand_targetgenes_GP' as it is a subset of GP 'WNT9A_ligand_receptor_GP'.
# Removing GP 'WNT9B_ligand_targetgenes_GP' as it is a subset of GP 'WNT9B_ligand_receptor_GP'.
# Removing GP 'WNT3_ligand_targetgenes_GP' as it is a subset of GP 'WNT3_ligand_receptor_GP'.
# Removing GP 'SOST_ligand_targetgenes_GP' as it is a subset of GP 'SOST_ligand_receptor_GP'.
# Removing GP 'EFNA1_ligand_targetgenes_GP' as it is a subset of GP 'EFNA1_ligand_receptor_GP'.
# Removing GP 'EFNA2_ligand_targetgenes_GP' as it is a subset of GP 'EFNA2_ligand_receptor_GP'.
# Removing GP 'EFNA3_ligand_targetgenes_GP' as it is a subset of GP 'EFNA3_ligand_receptor_GP'.
# Removing GP 'CCL22_ligand_targetgenes_GP' as it is a subset of GP 'CCL22_ligand_receptor_GP'.
# Removing GP 'NRG2_ligand_targetgenes_GP' as it is a subset of GP 'NRG2_ligand_receptor_GP'.
# Removing GP 'LAMC2_ligand_targetgenes_GP' as it is a subset of GP 'LAMC2_ligand_receptor_GP'.
# Removing GP 'ICAM5_ligand_targetgenes_GP' as it is a subset of GP 'ICAM5_ligand_receptor_GP'.
# Removing GP 'COMP_ligand_targetgenes_GP' as it is a subset of GP 'COMP_ligand_receptor_GP'.
# Removing GP 'CHAD_ligand_targetgenes_GP' as it is a subset of GP 'CHAD_ligand_receptor_GP'.
# Removing GP 'THBS4_ligand_targetgenes_GP' as it is a subset of GP 'THBS4_ligand_receptor_GP'.
# Removing GP 'SEMA7A_ligand_targetgenes_GP' as it is a subset of GP 'SEMA7A_ligand_receptor_GP'.
# Removing GP 'CCL8_ligand_targetgenes_GP' as it is a subset of GP 'CCL8_ligand_receptor_GP'.
# Removing GP 'CCL7_ligand_targetgenes_GP' as it is a subset of GP 'CCL7_ligand_receptor_GP'.
# Removing GP 'XCL1_ligand_targetgenes_GP' as it is a subset of GP 'XCL1_ligand_receptor_GP'.
# Removing GP 'CCL4L1_ligand_targetgenes_GP' as it is a subset of GP 'CCL4L1_ligand_receptor_GP'.
# Removing GP 'COPA_ligand_targetgenes_GP' as it is a subset of GP 'COPA_ligand_receptor_GP'.
# Removing GP 'GUCA2A_ligand_targetgenes_GP' as it is a subset of GP 'GUCA2A_ligand_receptor_GP'.
# Removing GP 'GUCA2B_ligand_targetgenes_GP' as it is a subset of GP 'GUCA2B_ligand_receptor_GP'.
# Removing GP 'NTN4_ligand_targetgenes_GP' as it is a subset of GP 'NTN4_ligand_receptor_GP'.
# Removing GP 'CD99_ligand_targetgenes_GP' as it is a subset of GP 'CD99_ligand_receptor_GP'.
# Removing GP 'SEMA3C_ligand_targetgenes_GP' as it is a subset of GP 'SEMA3C_ligand_receptor_GP'.
# Removing GP 'NECTIN2_ligand_targetgenes_GP' as it is a subset of GP 'NECTIN2_ligand_receptor_GP'.
# Removing GP 'HLA-B_ligand_targetgenes_GP' as it is a subset of GP 'HLA-B_ligand_receptor_GP'.
# Removing GP 'HLA-C_ligand_targetgenes_GP' as it is a subset of GP 'HLA-C_ligand_receptor_GP'.
# Removing GP 'CNTN1_ligand_targetgenes_GP' as it is a subset of GP 'CNTN1_ligand_receptor_GP'.
# Removing GP 'SEMA3F_ligand_targetgenes_GP' as it is a subset of GP 'SEMA3F_ligand_receptor_GP'.
# Removing GP 'FAM3C_ligand_targetgenes_GP' as it is a subset of GP 'FAM3C_ligand_receptor_GP'.
# Removing GP 'ULBP2_ligand_targetgenes_GP' as it is a subset of GP 'ULBP2_ligand_receptor_GP'.
# Removing GP 'GPHA2_ligand_targetgenes_GP' as it is a subset of GP 'GPHA2_ligand_receptor_GP'.
# Removing GP 'FLRT3_ligand_targetgenes_GP' as it is a subset of GP 'FLRT3_ligand_receptor_GP'.
# Removing GP 'PRND_ligand_targetgenes_GP' as it is a subset of GP 'PRND_ligand_receptor_GP'.
# Removing GP 'NDP_ligand_targetgenes_GP' as it is a subset of GP 'NDP_ligand_receptor_GP'.
# Removing GP 'RSPO2_ligand_targetgenes_GP' as it is a subset of GP 'RSPO2_ligand_receptor_GP'.
# Removing GP 'RSPO4_ligand_targetgenes_GP' as it is a subset of GP 'RSPO4_ligand_receptor_GP'.
# Removing GP 'NTN3_ligand_targetgenes_GP' as it is a subset of GP 'NTN3_ligand_receptor_GP'.
# Removing GP 'DHH_ligand_targetgenes_GP' as it is a subset of GP 'DHH_ligand_receptor_GP'.
# Removing GP 'DSC1_ligand_targetgenes_GP' as it is a subset of GP 'DSC1_ligand_receptor_GP'.
# Removing GP 'DSC2_ligand_targetgenes_GP' as it is a subset of GP 'DSC2_ligand_receptor_GP'.
# Removing GP 'NLGN2_ligand_targetgenes_GP' as it is a subset of GP 'NLGN2_ligand_receptor_GP'.
# Removing GP 'NXPH1_ligand_targetgenes_GP' as it is a subset of GP 'NXPH1_ligand_receptor_GP'.
# Removing GP 'NPFF_ligand_targetgenes_GP' as it is a subset of GP 'NPFF_ligand_receptor_GP'.
# Removing GP 'TAC3_ligand_targetgenes_GP' as it is a subset of GP 'TAC3_ligand_receptor_GP'.
# Removing GP 'TAC4_ligand_targetgenes_GP' as it is a subset of GP 'TAC4_ligand_receptor_GP'.
# Removing GP 'NMB_ligand_targetgenes_GP' as it is a subset of GP 'NMB_ligand_receptor_GP'.
# Removing GP 'GALP_ligand_targetgenes_GP' as it is a subset of GP 'GALP_ligand_receptor_GP'.
# Removing GP 'MLN_ligand_targetgenes_GP' as it is a subset of GP 'MLN_ligand_receptor_GP'.
# Removing GP 'IL17B_ligand_targetgenes_GP' as it is a subset of GP 'IL17B_ligand_receptor_GP'.
# Removing GP 'QRFP_ligand_targetgenes_GP' as it is a subset of GP 'QRFP_ligand_receptor_GP'.
# Removing GP 'TXLNA_ligand_targetgenes_GP' as it is a subset of GP 'TXLNA_ligand_receptor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Guanosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Inosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Corticosterone_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Cortisol_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'D-Galactose_metabolite_enzyme_sensor_GP' as it is a subset of GP 'D-Glucose_metabolite_enzyme_sensor_GP'.
# Removing GP 'D-Maltose_metabolite_enzyme_sensor_GP' as it is a subset of GP 'D-Glucose_metabolite_enzyme_sensor_GP'.
# Removing GP 'Estriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Estrone_metabolite_enzyme_sensor_GP'.
# Removing GP 'Estriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Estradiol_metabolite_enzyme_sensor_GP'.
# Removing GP 'L-Dopa_metabolite_enzyme_sensor_GP' as it is a subset of GP 'L-Tyrosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Guanosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Stearic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Epinephrine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Norepinephrine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Stearic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Androsterone_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Testosterone_metabolite_enzyme_sensor_GP'.
# Removing GP 'Liothyronine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Thyroxine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Cytidine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Uridine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Thymine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Uracil_metabolite_enzyme_sensor_GP'.
# Removing GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Stearic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Stearic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Prostaglandin F2a_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Prostaglandin E2_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Retinal_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'all-trans-Retinoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Docosahexaenoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Eicosapentaenoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Eicosapentaenoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Docosahexaenoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP '9-cis-Retinoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Calcitriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Calcidiol_metabolite_enzyme_sensor_GP'.
# Number of gene programs before filtering and combining: 1725.
# Number of gene programs after filtering and combining: 1575.
# Number of gene programs with probed genes: 489.
# Example gene programs: ['L-Lactic acid_metabolite_enzyme_sensor_GP', 'DLL3_ligand_targetgenes_GP', 'BMP15_ligand_targetgenes_GP', 'CD40LG_ligand_targetgenes_GP', 'SFRP2_ligand_receptor_GP'].
# Number of gene program target genes: 7476.
# Number of gene program source genes: 127.
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 2.0.
# Number of total edges: 19473.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17506
# Number of validation nodes: 1945
# Number of training edges: 17526
# Number of validation edges: 1947
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 1.3656; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 585.6582; train_group_lasso_reg_loss: 0.0000; train_global_loss: 587.0237; train_optim_loss: 587.0237; val_kl_reg_loss: 1.3857; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 564.1559; val_group_lasso_reg_loss: 0.0000; val_global_loss: 565.5416; val_optim_loss: 565.5416
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 1.3095; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 556.7712; train_group_lasso_reg_loss: 0.0000; train_global_loss: 558.0807; train_optim_loss: 558.0807; val_kl_reg_loss: 1.4659; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 549.8195; val_group_lasso_reg_loss: 0.0000; val_global_loss: 551.2854; val_optim_loss: 551.2854
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.5003; val_auprc_score: 0.5001; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 1.2301; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 543.8278; train_group_lasso_reg_loss: 0.0000; train_global_loss: 545.0580; train_optim_loss: 545.0580; val_kl_reg_loss: 1.2420; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 538.7464; val_group_lasso_reg_loss: 0.0000; val_global_loss: 539.9884; val_optim_loss: 539.9884
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 1.1980; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 533.7458; train_group_lasso_reg_loss: 0.0000; train_global_loss: 534.9438; train_optim_loss: 534.9438; val_kl_reg_loss: 1.2719; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 528.7338; val_group_lasso_reg_loss: 0.0000; val_global_loss: 530.0057; val_optim_loss: 530.0057
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 1.1710; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 525.6173; train_group_lasso_reg_loss: 0.0000; train_global_loss: 526.7882; train_optim_loss: 526.7882; val_kl_reg_loss: 1.2265; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 523.4142; val_group_lasso_reg_loss: 0.0000; val_global_loss: 524.6407; val_optim_loss: 524.6407
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 1.1535; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 518.7971; train_group_lasso_reg_loss: 0.0000; train_global_loss: 519.9506; train_optim_loss: 519.9506; val_kl_reg_loss: 1.2024; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 519.0094; val_group_lasso_reg_loss: 0.0000; val_global_loss: 520.2118; val_optim_loss: 520.2118
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1437; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 513.2897; train_group_lasso_reg_loss: 0.0000; train_global_loss: 514.4334; train_optim_loss: 514.4334; val_kl_reg_loss: 1.2158; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 513.2237; val_group_lasso_reg_loss: 0.0000; val_global_loss: 514.4396; val_optim_loss: 514.4396
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.5005; val_auprc_score: 0.5003; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 1.1424; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 508.7610; train_group_lasso_reg_loss: 0.0000; train_global_loss: 509.9034; train_optim_loss: 509.9034; val_kl_reg_loss: 1.2023; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 509.7882; val_group_lasso_reg_loss: 0.0000; val_global_loss: 510.9905; val_optim_loss: 510.9905
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1369; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 504.8627; train_group_lasso_reg_loss: 0.0000; train_global_loss: 505.9996; train_optim_loss: 505.9996; val_kl_reg_loss: 1.2062; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 509.3710; val_group_lasso_reg_loss: 0.0000; val_global_loss: 510.5772; val_optim_loss: 510.5772
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.5005; val_auprc_score: 0.5003; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 1.1383; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 501.8499; train_group_lasso_reg_loss: 0.0000; train_global_loss: 502.9882; train_optim_loss: 502.9882; val_kl_reg_loss: 1.1724; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 506.3991; val_group_lasso_reg_loss: 0.0000; val_global_loss: 507.5715; val_optim_loss: 507.5715
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.5010; val_auprc_score: 0.5005; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 1.1398; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 499.1559; train_group_lasso_reg_loss: 0.0000; train_global_loss: 500.2957; train_optim_loss: 500.2957; val_kl_reg_loss: 1.1971; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 505.0880; val_group_lasso_reg_loss: 0.0000; val_global_loss: 506.2851; val_optim_loss: 506.2851
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.5003; val_auprc_score: 0.5001; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 1.1364; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 497.0682; train_group_lasso_reg_loss: 0.0000; train_global_loss: 498.2046; train_optim_loss: 498.2046; val_kl_reg_loss: 1.2188; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 502.1411; val_group_lasso_reg_loss: 0.0000; val_global_loss: 503.3599; val_optim_loss: 503.3599
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.5015; val_auprc_score: 0.5008; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1345; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 495.0181; train_group_lasso_reg_loss: 0.0000; train_global_loss: 496.1526; train_optim_loss: 496.1526; val_kl_reg_loss: 1.1692; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 500.9398; val_group_lasso_reg_loss: 0.0000; val_global_loss: 502.1091; val_optim_loss: 502.1091
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.5005; val_auprc_score: 0.5003; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 1.1367; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 493.6307; train_group_lasso_reg_loss: 0.0000; train_global_loss: 494.7674; train_optim_loss: 494.7674; val_kl_reg_loss: 1.2083; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 500.3934; val_group_lasso_reg_loss: 0.0000; val_global_loss: 501.6017; val_optim_loss: 501.6017
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 1.1387; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 492.0627; train_group_lasso_reg_loss: 0.0000; train_global_loss: 493.2014; train_optim_loss: 493.2014; val_kl_reg_loss: 1.2022; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 499.6526; val_group_lasso_reg_loss: 0.0000; val_global_loss: 500.8548; val_optim_loss: 500.8548
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.5015; val_auprc_score: 0.5008; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1411; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 490.9448; train_group_lasso_reg_loss: 0.0000; train_global_loss: 492.0859; train_optim_loss: 492.0859; val_kl_reg_loss: 1.2266; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 498.7191; val_group_lasso_reg_loss: 0.0000; val_global_loss: 499.9457; val_optim_loss: 499.9457
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1521; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 490.0373; train_group_lasso_reg_loss: 0.0000; train_global_loss: 491.1894; train_optim_loss: 491.1894; val_kl_reg_loss: 1.2057; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 498.2120; val_group_lasso_reg_loss: 0.0000; val_global_loss: 499.4177; val_optim_loss: 499.4177
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.5010; val_auprc_score: 0.5005; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 1.1399; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 489.1399; train_group_lasso_reg_loss: 0.0000; train_global_loss: 490.2798; train_optim_loss: 490.2798; val_kl_reg_loss: 1.2332; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 496.5231; val_group_lasso_reg_loss: 0.0000; val_global_loss: 497.7563; val_optim_loss: 497.7563
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.5010; val_auprc_score: 0.5005; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 1.1530; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 488.2171; train_group_lasso_reg_loss: 0.0000; train_global_loss: 489.3701; train_optim_loss: 489.3701; val_kl_reg_loss: 1.2316; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 499.9874; val_group_lasso_reg_loss: 0.0000; val_global_loss: 501.2191; val_optim_loss: 501.2191
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.5015; val_auprc_score: 0.5008; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 1.1473; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 487.5045; train_group_lasso_reg_loss: 0.0000; train_global_loss: 488.6519; train_optim_loss: 488.6519; val_kl_reg_loss: 1.2247; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 500.4554; val_group_lasso_reg_loss: 0.0000; val_global_loss: 501.6801; val_optim_loss: 501.6801
#
# Model training finished after 2 min 0 sec.
# Using best model state, which was in epoch 18.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.5026
# Val AUPRC score: 0.5013
# Val best accuracy score: 0.5018
# Val best F1 score: 0.6675
# Val MSE score: 1.2817
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 2.0.
# Number of total edges: 19473.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17506
# Number of validation nodes: 1945
# Number of training edges: 17526
# Number of validation edges: 1947
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.6960; val_auprc_score: 0.6220; val_best_acc_score: 0.6626; val_best_f1_score: 0.7476; train_kl_reg_loss: 0.3792; train_edge_recon_loss: 4.3133; train_gene_expr_recon_loss: 589.3968; train_group_lasso_reg_loss: 0.0000; train_global_loss: 594.0893; train_optim_loss: 594.0893; val_kl_reg_loss: 0.5608; val_edge_recon_loss: 3.7429; val_gene_expr_recon_loss: 562.2943; val_group_lasso_reg_loss: 0.0000; val_global_loss: 566.5980; val_optim_loss: 566.5980
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.6877; val_auprc_score: 0.6156; val_best_acc_score: 0.6507; val_best_f1_score: 0.7411; train_kl_reg_loss: 0.6020; train_edge_recon_loss: 3.7111; train_gene_expr_recon_loss: 558.7684; train_group_lasso_reg_loss: 0.0000; train_global_loss: 563.0814; train_optim_loss: 563.0814; val_kl_reg_loss: 0.7177; val_edge_recon_loss: 3.3538; val_gene_expr_recon_loss: 547.6264; val_group_lasso_reg_loss: 0.0000; val_global_loss: 551.6979; val_optim_loss: 551.6979
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.6710; val_auprc_score: 0.6032; val_best_acc_score: 0.6225; val_best_f1_score: 0.7260; train_kl_reg_loss: 0.7017; train_edge_recon_loss: 3.1819; train_gene_expr_recon_loss: 545.3592; train_group_lasso_reg_loss: 0.0000; train_global_loss: 549.2428; train_optim_loss: 549.2428; val_kl_reg_loss: 0.7645; val_edge_recon_loss: 3.0532; val_gene_expr_recon_loss: 536.9095; val_group_lasso_reg_loss: 0.0000; val_global_loss: 540.7271; val_optim_loss: 540.7271
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.6826; val_auprc_score: 0.6117; val_best_acc_score: 0.6305; val_best_f1_score: 0.7302; train_kl_reg_loss: 0.7752; train_edge_recon_loss: 2.8913; train_gene_expr_recon_loss: 534.9390; train_group_lasso_reg_loss: 0.0000; train_global_loss: 538.6055; train_optim_loss: 538.6055; val_kl_reg_loss: 0.8313; val_edge_recon_loss: 2.6347; val_gene_expr_recon_loss: 527.5868; val_group_lasso_reg_loss: 0.0000; val_global_loss: 531.0528; val_optim_loss: 531.0528
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.6452; val_auprc_score: 0.5849; val_best_acc_score: 0.5948; val_best_f1_score: 0.7116; train_kl_reg_loss: 0.8244; train_edge_recon_loss: 2.6604; train_gene_expr_recon_loss: 526.7414; train_group_lasso_reg_loss: 0.0000; train_global_loss: 530.2261; train_optim_loss: 530.2261; val_kl_reg_loss: 0.8745; val_edge_recon_loss: 2.8973; val_gene_expr_recon_loss: 520.5911; val_group_lasso_reg_loss: 0.0000; val_global_loss: 524.3629; val_optim_loss: 524.3629
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.6870; val_auprc_score: 0.6150; val_best_acc_score: 0.6276; val_best_f1_score: 0.7287; train_kl_reg_loss: 0.8602; train_edge_recon_loss: 2.5056; train_gene_expr_recon_loss: 519.8895; train_group_lasso_reg_loss: 0.0000; train_global_loss: 523.2554; train_optim_loss: 523.2554; val_kl_reg_loss: 0.9428; val_edge_recon_loss: 2.3982; val_gene_expr_recon_loss: 515.8177; val_group_lasso_reg_loss: 0.0000; val_global_loss: 519.1588; val_optim_loss: 519.1588
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.6586; val_auprc_score: 0.5942; val_best_acc_score: 0.6009; val_best_f1_score: 0.7148; train_kl_reg_loss: 0.8955; train_edge_recon_loss: 2.3530; train_gene_expr_recon_loss: 514.2433; train_group_lasso_reg_loss: 0.0000; train_global_loss: 517.4918; train_optim_loss: 517.4918; val_kl_reg_loss: 0.9384; val_edge_recon_loss: 2.3302; val_gene_expr_recon_loss: 513.4925; val_group_lasso_reg_loss: 0.0000; val_global_loss: 516.7611; val_optim_loss: 516.7611
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.6635; val_auprc_score: 0.5978; val_best_acc_score: 0.6138; val_best_f1_score: 0.7213; train_kl_reg_loss: 0.9102; train_edge_recon_loss: 2.2602; train_gene_expr_recon_loss: 509.7862; train_group_lasso_reg_loss: 0.0000; train_global_loss: 512.9566; train_optim_loss: 512.9566; val_kl_reg_loss: 0.9751; val_edge_recon_loss: 2.3358; val_gene_expr_recon_loss: 509.0647; val_group_lasso_reg_loss: 0.0000; val_global_loss: 512.3756; val_optim_loss: 512.3756
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.6821; val_auprc_score: 0.6114; val_best_acc_score: 0.6166; val_best_f1_score: 0.7227; train_kl_reg_loss: 0.9192; train_edge_recon_loss: 2.1515; train_gene_expr_recon_loss: 505.7765; train_group_lasso_reg_loss: 0.0000; train_global_loss: 508.8472; train_optim_loss: 508.8472; val_kl_reg_loss: 0.9837; val_edge_recon_loss: 2.1419; val_gene_expr_recon_loss: 507.4788; val_group_lasso_reg_loss: 0.0000; val_global_loss: 510.6044; val_optim_loss: 510.6044
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.6697; val_auprc_score: 0.6022; val_best_acc_score: 0.6091; val_best_f1_score: 0.7190; train_kl_reg_loss: 0.9391; train_edge_recon_loss: 2.1309; train_gene_expr_recon_loss: 502.6472; train_group_lasso_reg_loss: 0.0000; train_global_loss: 505.7172; train_optim_loss: 505.7172; val_kl_reg_loss: 0.9633; val_edge_recon_loss: 2.1523; val_gene_expr_recon_loss: 504.8578; val_group_lasso_reg_loss: 0.0000; val_global_loss: 507.9734; val_optim_loss: 507.9734
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.6895; val_auprc_score: 0.6170; val_best_acc_score: 0.6258; val_best_f1_score: 0.7277; train_kl_reg_loss: 0.9448; train_edge_recon_loss: 2.0358; train_gene_expr_recon_loss: 500.0465; train_group_lasso_reg_loss: 0.0000; train_global_loss: 503.0271; train_optim_loss: 503.0271; val_kl_reg_loss: 0.9955; val_edge_recon_loss: 1.8999; val_gene_expr_recon_loss: 503.0362; val_group_lasso_reg_loss: 0.0000; val_global_loss: 505.9316; val_optim_loss: 505.9316
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.6733; val_auprc_score: 0.6049; val_best_acc_score: 0.6091; val_best_f1_score: 0.7188; train_kl_reg_loss: 0.9610; train_edge_recon_loss: 1.9630; train_gene_expr_recon_loss: 497.7165; train_group_lasso_reg_loss: 0.0000; train_global_loss: 500.6405; train_optim_loss: 500.6405; val_kl_reg_loss: 0.9666; val_edge_recon_loss: 1.9944; val_gene_expr_recon_loss: 503.3269; val_group_lasso_reg_loss: 0.0000; val_global_loss: 506.2879; val_optim_loss: 506.2879
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.6923; val_auprc_score: 0.6191; val_best_acc_score: 0.6240; val_best_f1_score: 0.7266; train_kl_reg_loss: 0.9661; train_edge_recon_loss: 1.9619; train_gene_expr_recon_loss: 495.8865; train_group_lasso_reg_loss: 0.0000; train_global_loss: 498.8146; train_optim_loss: 498.8146; val_kl_reg_loss: 0.9853; val_edge_recon_loss: 1.8943; val_gene_expr_recon_loss: 502.1268; val_group_lasso_reg_loss: 0.0000; val_global_loss: 505.0064; val_optim_loss: 505.0064
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.6887; val_auprc_score: 0.6164; val_best_acc_score: 0.6240; val_best_f1_score: 0.7266; train_kl_reg_loss: 0.9728; train_edge_recon_loss: 1.9263; train_gene_expr_recon_loss: 494.3398; train_group_lasso_reg_loss: 0.0000; train_global_loss: 497.2389; train_optim_loss: 497.2389; val_kl_reg_loss: 0.9987; val_edge_recon_loss: 1.8912; val_gene_expr_recon_loss: 499.6063; val_group_lasso_reg_loss: 0.0000; val_global_loss: 502.4961; val_optim_loss: 502.4961
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.6845; val_auprc_score: 0.6132; val_best_acc_score: 0.6166; val_best_f1_score: 0.7229; train_kl_reg_loss: 0.9766; train_edge_recon_loss: 1.8758; train_gene_expr_recon_loss: 492.7742; train_group_lasso_reg_loss: 0.0000; train_global_loss: 495.6267; train_optim_loss: 495.6267; val_kl_reg_loss: 1.0436; val_edge_recon_loss: 1.8734; val_gene_expr_recon_loss: 498.7989; val_group_lasso_reg_loss: 0.0000; val_global_loss: 501.7159; val_optim_loss: 501.7159
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.7030; val_auprc_score: 0.6274; val_best_acc_score: 0.6297; val_best_f1_score: 0.7296; train_kl_reg_loss: 0.9842; train_edge_recon_loss: 1.8220; train_gene_expr_recon_loss: 491.6410; train_group_lasso_reg_loss: 0.0000; train_global_loss: 494.4472; train_optim_loss: 494.4472; val_kl_reg_loss: 1.0535; val_edge_recon_loss: 1.7448; val_gene_expr_recon_loss: 499.1220; val_group_lasso_reg_loss: 0.0000; val_global_loss: 501.9203; val_optim_loss: 501.9203
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.6857; val_auprc_score: 0.6141; val_best_acc_score: 0.6117; val_best_f1_score: 0.7203; train_kl_reg_loss: 0.9871; train_edge_recon_loss: 1.7914; train_gene_expr_recon_loss: 490.6050; train_group_lasso_reg_loss: 0.0000; train_global_loss: 493.3834; train_optim_loss: 493.3834; val_kl_reg_loss: 1.0356; val_edge_recon_loss: 1.8862; val_gene_expr_recon_loss: 500.0390; val_group_lasso_reg_loss: 0.0000; val_global_loss: 502.9608; val_optim_loss: 502.9608
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.7025; val_auprc_score: 0.6270; val_best_acc_score: 0.6279; val_best_f1_score: 0.7288; train_kl_reg_loss: 0.9905; train_edge_recon_loss: 1.7951; train_gene_expr_recon_loss: 489.7070; train_group_lasso_reg_loss: 0.0000; train_global_loss: 492.4926; train_optim_loss: 492.4926; val_kl_reg_loss: 1.0427; val_edge_recon_loss: 1.7954; val_gene_expr_recon_loss: 497.5913; val_group_lasso_reg_loss: 0.0000; val_global_loss: 500.4294; val_optim_loss: 500.4294
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.7032; val_auprc_score: 0.6276; val_best_acc_score: 0.6387; val_best_f1_score: 0.7344; train_kl_reg_loss: 0.9947; train_edge_recon_loss: 1.7679; train_gene_expr_recon_loss: 489.0412; train_group_lasso_reg_loss: 0.0000; train_global_loss: 491.8039; train_optim_loss: 491.8039; val_kl_reg_loss: 1.0345; val_edge_recon_loss: 1.7904; val_gene_expr_recon_loss: 500.1771; val_group_lasso_reg_loss: 0.0000; val_global_loss: 503.0021; val_optim_loss: 503.0021
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.7081; val_auprc_score: 0.6315; val_best_acc_score: 0.6333; val_best_f1_score: 0.7316; train_kl_reg_loss: 0.9987; train_edge_recon_loss: 1.7550; train_gene_expr_recon_loss: 488.2639; train_group_lasso_reg_loss: 0.0000; train_global_loss: 491.0175; train_optim_loss: 491.0175; val_kl_reg_loss: 1.0483; val_edge_recon_loss: 1.7397; val_gene_expr_recon_loss: 497.0438; val_group_lasso_reg_loss: 0.0000; val_global_loss: 499.8318; val_optim_loss: 499.8318
#
# Model training finished after 2 min 0 sec.
# Using best model state, which was in epoch 20.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.7074
# Val AUPRC score: 0.6309
# Val best accuracy score: 0.6384
# Val best F1 score: 0.7343
# Val MSE score: 1.2323
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 2.0.
# Number of total edges: 19473.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17506
# Number of validation nodes: 1945
# Number of training edges: 17526
# Number of validation edges: 1947
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.7322; val_auprc_score: 0.6512; val_best_acc_score: 0.6805; val_best_f1_score: 0.7579; train_kl_reg_loss: 0.3190; train_edge_recon_loss: 5.1405; train_gene_expr_recon_loss: 595.0734; train_group_lasso_reg_loss: 0.0000; train_global_loss: 600.5330; train_optim_loss: 600.5330; val_kl_reg_loss: 0.5296; val_edge_recon_loss: 5.0836; val_gene_expr_recon_loss: 581.3463; val_group_lasso_reg_loss: 0.0000; val_global_loss: 586.9594; val_optim_loss: 586.9594
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.7312; val_auprc_score: 0.6504; val_best_acc_score: 0.6638; val_best_f1_score: 0.7484; train_kl_reg_loss: 0.5639; train_edge_recon_loss: 4.7826; train_gene_expr_recon_loss: 563.2321; train_group_lasso_reg_loss: 0.0000; train_global_loss: 568.5786; train_optim_loss: 568.5786; val_kl_reg_loss: 0.6447; val_edge_recon_loss: 4.2567; val_gene_expr_recon_loss: 565.0588; val_group_lasso_reg_loss: 0.0000; val_global_loss: 569.9601; val_optim_loss: 569.9601
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.7206; val_auprc_score: 0.6415; val_best_acc_score: 0.6538; val_best_f1_score: 0.7428; train_kl_reg_loss: 0.6691; train_edge_recon_loss: 4.1029; train_gene_expr_recon_loss: 549.2648; train_group_lasso_reg_loss: 0.0000; train_global_loss: 554.0368; train_optim_loss: 554.0368; val_kl_reg_loss: 0.7522; val_edge_recon_loss: 3.9133; val_gene_expr_recon_loss: 553.3692; val_group_lasso_reg_loss: 0.0000; val_global_loss: 558.0348; val_optim_loss: 558.0348
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.7440; val_auprc_score: 0.6613; val_best_acc_score: 0.6610; val_best_f1_score: 0.7468; train_kl_reg_loss: 0.7443; train_edge_recon_loss: 3.6878; train_gene_expr_recon_loss: 538.7432; train_group_lasso_reg_loss: 0.0000; train_global_loss: 543.1753; train_optim_loss: 543.1753; val_kl_reg_loss: 0.7969; val_edge_recon_loss: 3.4057; val_gene_expr_recon_loss: 542.8781; val_group_lasso_reg_loss: 0.0000; val_global_loss: 547.0806; val_optim_loss: 547.0806
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.7382; val_auprc_score: 0.6563; val_best_acc_score: 0.6579; val_best_f1_score: 0.7451; train_kl_reg_loss: 0.7956; train_edge_recon_loss: 3.4321; train_gene_expr_recon_loss: 529.7757; train_group_lasso_reg_loss: 0.0000; train_global_loss: 534.0035; train_optim_loss: 534.0035; val_kl_reg_loss: 0.8434; val_edge_recon_loss: 3.2262; val_gene_expr_recon_loss: 537.2886; val_group_lasso_reg_loss: 0.0000; val_global_loss: 541.3581; val_optim_loss: 541.3581
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.7410; val_auprc_score: 0.6588; val_best_acc_score: 0.6543; val_best_f1_score: 0.7431; train_kl_reg_loss: 0.8313; train_edge_recon_loss: 3.2895; train_gene_expr_recon_loss: 522.5393; train_group_lasso_reg_loss: 0.0000; train_global_loss: 526.6600; train_optim_loss: 526.6600; val_kl_reg_loss: 0.9131; val_edge_recon_loss: 2.9886; val_gene_expr_recon_loss: 530.8110; val_group_lasso_reg_loss: 0.0000; val_global_loss: 534.7127; val_optim_loss: 534.7127
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.7128; val_auprc_score: 0.6353; val_best_acc_score: 0.6302; val_best_f1_score: 0.7299; train_kl_reg_loss: 0.8711; train_edge_recon_loss: 3.1299; train_gene_expr_recon_loss: 516.3927; train_group_lasso_reg_loss: 0.0000; train_global_loss: 520.3937; train_optim_loss: 520.3937; val_kl_reg_loss: 0.9096; val_edge_recon_loss: 3.1091; val_gene_expr_recon_loss: 526.3559; val_group_lasso_reg_loss: 0.0000; val_global_loss: 530.3746; val_optim_loss: 530.3746
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.7326; val_auprc_score: 0.6516; val_best_acc_score: 0.6410; val_best_f1_score: 0.7358; train_kl_reg_loss: 0.8996; train_edge_recon_loss: 2.9997; train_gene_expr_recon_loss: 511.3610; train_group_lasso_reg_loss: 0.0000; train_global_loss: 515.2603; train_optim_loss: 515.2603; val_kl_reg_loss: 0.9525; val_edge_recon_loss: 2.9617; val_gene_expr_recon_loss: 523.9551; val_group_lasso_reg_loss: 0.0000; val_global_loss: 527.8693; val_optim_loss: 527.8693
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.7396; val_auprc_score: 0.6575; val_best_acc_score: 0.6471; val_best_f1_score: 0.7392; train_kl_reg_loss: 0.9250; train_edge_recon_loss: 2.8732; train_gene_expr_recon_loss: 506.8099; train_group_lasso_reg_loss: 0.0000; train_global_loss: 510.6080; train_optim_loss: 510.6080; val_kl_reg_loss: 0.9827; val_edge_recon_loss: 2.7762; val_gene_expr_recon_loss: 519.8734; val_group_lasso_reg_loss: 0.0000; val_global_loss: 523.6323; val_optim_loss: 523.6323
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.7340; val_auprc_score: 0.6527; val_best_acc_score: 0.6348; val_best_f1_score: 0.7325; train_kl_reg_loss: 0.9340; train_edge_recon_loss: 2.7875; train_gene_expr_recon_loss: 503.4985; train_group_lasso_reg_loss: 0.0000; train_global_loss: 507.2200; train_optim_loss: 507.2200; val_kl_reg_loss: 0.9969; val_edge_recon_loss: 2.6474; val_gene_expr_recon_loss: 516.8919; val_group_lasso_reg_loss: 0.0000; val_global_loss: 520.5362; val_optim_loss: 520.5362
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.7409; val_auprc_score: 0.6588; val_best_acc_score: 0.6479; val_best_f1_score: 0.7395; train_kl_reg_loss: 0.9564; train_edge_recon_loss: 2.6968; train_gene_expr_recon_loss: 500.6534; train_group_lasso_reg_loss: 0.0000; train_global_loss: 504.3066; train_optim_loss: 504.3066; val_kl_reg_loss: 0.9921; val_edge_recon_loss: 2.6463; val_gene_expr_recon_loss: 516.3939; val_group_lasso_reg_loss: 0.0000; val_global_loss: 520.0323; val_optim_loss: 520.0323
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.7451; val_auprc_score: 0.6624; val_best_acc_score: 0.6533; val_best_f1_score: 0.7426; train_kl_reg_loss: 0.9670; train_edge_recon_loss: 2.6094; train_gene_expr_recon_loss: 498.1469; train_group_lasso_reg_loss: 0.0000; train_global_loss: 501.7232; train_optim_loss: 501.7232; val_kl_reg_loss: 1.0301; val_edge_recon_loss: 2.5241; val_gene_expr_recon_loss: 512.8894; val_group_lasso_reg_loss: 0.0000; val_global_loss: 516.4436; val_optim_loss: 516.4436
# ...
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.9600; val_auprc_score: 0.9287; val_best_acc_score: 0.8235; val_best_f1_score: 0.8497; train_kl_reg_loss: 0.6349; train_edge_recon_loss: 2.6628; train_gene_expr_recon_loss: 457.1055; train_group_lasso_reg_loss: 0.0000; train_global_loss: 460.4031; train_optim_loss: 460.4031; val_kl_reg_loss: 0.6388; val_edge_recon_loss: 2.7422; val_gene_expr_recon_loss: 471.6539; val_group_lasso_reg_loss: 0.0000; val_global_loss: 475.0348; val_optim_loss: 475.0348
#
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 1e-05.
#
# Model training finished after 4 min 16 sec.
# Using best model state, which was in epoch 17.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.9603
# Val AUPRC score: 0.9291
# Val best accuracy score: 0.8190
# Val best F1 score: 0.8464
# Val MSE score: 1.1297
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 8.01.
# Number of total edges: 77909.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17506
# Number of validation nodes: 1945
# Number of training edges: 70119
# Number of validation edges: 7790
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.5542; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 484.2292; train_group_lasso_reg_loss: 0.0000; train_global_loss: 484.7834; train_optim_loss: 484.7834; val_kl_reg_loss: 0.4553; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 471.5281; val_group_lasso_reg_loss: 0.0000; val_global_loss: 471.9834; val_optim_loss: 471.9834
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.5001; val_auprc_score: 0.5000; val_best_acc_score: 0.5001; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.4314; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 462.4452; train_group_lasso_reg_loss: 0.0000; train_global_loss: 462.8766; train_optim_loss: 462.8766; val_kl_reg_loss: 0.4093; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 460.7637; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.1730; val_optim_loss: 461.1730
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.5003; val_auprc_score: 0.5002; val_best_acc_score: 0.5002; val_best_f1_score: 0.6668; train_kl_reg_loss: 0.4001; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 454.0555; train_group_lasso_reg_loss: 0.0000; train_global_loss: 454.4557; train_optim_loss: 454.4557; val_kl_reg_loss: 0.3889; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 456.2860; val_group_lasso_reg_loss: 0.0000; val_global_loss: 456.6749; val_optim_loss: 456.6749
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.5003; val_auprc_score: 0.5002; val_best_acc_score: 0.5003; val_best_f1_score: 0.6668; train_kl_reg_loss: 0.3862; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 449.0597; train_group_lasso_reg_loss: 0.0000; train_global_loss: 449.4459; train_optim_loss: 449.4459; val_kl_reg_loss: 0.3854; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 453.8627; val_group_lasso_reg_loss: 0.0000; val_global_loss: 454.2481; val_optim_loss: 454.2481
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.5022; val_auprc_score: 0.5011; val_best_acc_score: 0.5017; val_best_f1_score: 0.6674; train_kl_reg_loss: 0.3788; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 445.7639; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.1427; train_optim_loss: 446.1427; val_kl_reg_loss: 0.3716; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 453.4251; val_group_lasso_reg_loss: 0.0000; val_global_loss: 453.7967; val_optim_loss: 453.7967
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.5024; val_auprc_score: 0.5012; val_best_acc_score: 0.5017; val_best_f1_score: 0.6674; train_kl_reg_loss: 0.3752; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 443.3539; train_group_lasso_reg_loss: 0.0000; train_global_loss: 443.7291; train_optim_loss: 443.7291; val_kl_reg_loss: 0.3748; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 452.2522; val_group_lasso_reg_loss: 0.0000; val_global_loss: 452.6269; val_optim_loss: 452.6269
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.5011; val_auprc_score: 0.5005; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.3767; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 441.8602; train_group_lasso_reg_loss: 0.0000; train_global_loss: 442.2370; train_optim_loss: 442.2370; val_kl_reg_loss: 0.3723; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 450.8286; val_group_lasso_reg_loss: 0.0000; val_global_loss: 451.2008; val_optim_loss: 451.2008
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.5030; val_auprc_score: 0.5015; val_best_acc_score: 0.5019; val_best_f1_score: 0.6675; train_kl_reg_loss: 0.3732; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 440.1824; train_group_lasso_reg_loss: 0.0000; train_global_loss: 440.5556; train_optim_loss: 440.5556; val_kl_reg_loss: 0.3639; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 450.8314; val_group_lasso_reg_loss: 0.0000; val_global_loss: 451.1953; val_optim_loss: 451.1953
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.5012; val_auprc_score: 0.5006; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 0.3725; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 438.8868; train_group_lasso_reg_loss: 0.0000; train_global_loss: 439.2593; train_optim_loss: 439.2593; val_kl_reg_loss: 0.3807; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 450.9188; val_group_lasso_reg_loss: 0.0000; val_global_loss: 451.2995; val_optim_loss: 451.2995
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.5019; val_auprc_score: 0.5009; val_best_acc_score: 0.5012; val_best_f1_score: 0.6672; train_kl_reg_loss: 0.3717; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 437.8804; train_group_lasso_reg_loss: 0.0000; train_global_loss: 438.2521; train_optim_loss: 438.2521; val_kl_reg_loss: 0.3748; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 451.2044; val_group_lasso_reg_loss: 0.0000; val_global_loss: 451.5792; val_optim_loss: 451.5792
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.5013; val_auprc_score: 0.5006; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 0.3720; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 437.1301; train_group_lasso_reg_loss: 0.0000; train_global_loss: 437.5021; train_optim_loss: 437.5021; val_kl_reg_loss: 0.3822; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 452.2012; val_group_lasso_reg_loss: 0.0000; val_global_loss: 452.5834; val_optim_loss: 452.5834
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 0.0001.
#
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.5028; val_auprc_score: 0.5014; val_best_acc_score: 0.5022; val_best_f1_score: 0.6676; train_kl_reg_loss: 0.3660; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 433.7517; train_group_lasso_reg_loss: 0.0000; train_global_loss: 434.1176; train_optim_loss: 434.1176; val_kl_reg_loss: 0.3579; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 449.4915; val_group_lasso_reg_loss: 0.0000; val_global_loss: 449.8494; val_optim_loss: 449.8494
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.5033; val_auprc_score: 0.5016; val_best_acc_score: 0.5023; val_best_f1_score: 0.6677; train_kl_reg_loss: 0.3554; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 433.4616; train_group_lasso_reg_loss: 0.0000; train_global_loss: 433.8170; train_optim_loss: 433.8170; val_kl_reg_loss: 0.3563; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 449.7923; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.1485; val_optim_loss: 450.1485
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.5045; val_auprc_score: 0.5023; val_best_acc_score: 0.5026; val_best_f1_score: 0.6678; train_kl_reg_loss: 0.3533; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 433.1654; train_group_lasso_reg_loss: 0.0000; train_global_loss: 433.5187; train_optim_loss: 433.5187; val_kl_reg_loss: 0.3503; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 449.7448; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.0951; val_optim_loss: 450.0951
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.5035; val_auprc_score: 0.5017; val_best_acc_score: 0.5022; val_best_f1_score: 0.6676; train_kl_reg_loss: 0.3537; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 433.2662; train_group_lasso_reg_loss: 0.0000; train_global_loss: 433.6199; train_optim_loss: 433.6199; val_kl_reg_loss: 0.3550; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 450.3743; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.7293; val_optim_loss: 450.7293
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 1e-05.
#
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.5031; val_auprc_score: 0.5016; val_best_acc_score: 0.5019; val_best_f1_score: 0.6675; train_kl_reg_loss: 0.3534; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 432.6926; train_group_lasso_reg_loss: 0.0000; train_global_loss: 433.0460; train_optim_loss: 433.0460; val_kl_reg_loss: 0.3527; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 448.5904; val_group_lasso_reg_loss: 0.0000; val_global_loss: 448.9431; val_optim_loss: 448.9431
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.5029; val_auprc_score: 0.5014; val_best_acc_score: 0.5020; val_best_f1_score: 0.6676; train_kl_reg_loss: 0.3524; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 432.6351; train_group_lasso_reg_loss: 0.0000; train_global_loss: 432.9875; train_optim_loss: 432.9875; val_kl_reg_loss: 0.3534; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 448.6671; val_group_lasso_reg_loss: 0.0000; val_global_loss: 449.0205; val_optim_loss: 449.0205
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.5027; val_auprc_score: 0.5014; val_best_acc_score: 0.5019; val_best_f1_score: 0.6675; train_kl_reg_loss: 0.3521; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 432.5666; train_group_lasso_reg_loss: 0.0000; train_global_loss: 432.9187; train_optim_loss: 432.9187; val_kl_reg_loss: 0.3527; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 450.3099; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.6626; val_optim_loss: 450.6626
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.5040; val_auprc_score: 0.5021; val_best_acc_score: 0.5030; val_best_f1_score: 0.6680; train_kl_reg_loss: 0.3519; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 432.6371; train_group_lasso_reg_loss: 0.0000; train_global_loss: 432.9891; train_optim_loss: 432.9891; val_kl_reg_loss: 0.3532; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 449.7881; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.1414; val_optim_loss: 450.1414
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 1.0000000000000002e-06.
#
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.5032; val_auprc_score: 0.5016; val_best_acc_score: 0.5025; val_best_f1_score: 0.6678; train_kl_reg_loss: 0.3507; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 432.5797; train_group_lasso_reg_loss: 0.0000; train_global_loss: 432.9304; train_optim_loss: 432.9304; val_kl_reg_loss: 0.3528; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 449.9923; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.3451; val_optim_loss: 450.3451
#
# Model training finished after 11 min 25 sec.
# Using best model state, which was in epoch 16.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.5031
# Val AUPRC score: 0.5016
# Val best accuracy score: 0.5021
# Val best F1 score: 0.6676
# Val MSE score: 0.8947
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 8.01.
# Number of total edges: 77909.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 17506
# Number of validation nodes: 1945
# Number of training edges: 70119
# Number of validation edges: 7790
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.6965; val_auprc_score: 0.6223; val_best_acc_score: 0.6396; val_best_f1_score: 0.7351; train_kl_reg_loss: 0.1949; train_edge_recon_loss: 3.8027; train_gene_expr_recon_loss: 487.6500; train_group_lasso_reg_loss: 0.0000; train_global_loss: 491.6476; train_optim_loss: 491.6476; val_kl_reg_loss: 0.2464; val_edge_recon_loss: 2.5183; val_gene_expr_recon_loss: 466.0115; val_group_lasso_reg_loss: 0.0000; val_global_loss: 468.7762; val_optim_loss: 468.7762
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.7206; val_auprc_score: 0.6415; val_best_acc_score: 0.6496; val_best_f1_score: 0.7405; train_kl_reg_loss: 0.2657; train_edge_recon_loss: 2.3251; train_gene_expr_recon_loss: 463.2395; train_group_lasso_reg_loss: 0.0000; train_global_loss: 465.8303; train_optim_loss: 465.8303; val_kl_reg_loss: 0.2814; val_edge_recon_loss: 1.8213; val_gene_expr_recon_loss: 457.1082; val_group_lasso_reg_loss: 0.0000; val_global_loss: 459.2109; val_optim_loss: 459.2109
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.6745; val_auprc_score: 0.6057; val_best_acc_score: 0.5940; val_best_f1_score: 0.7113; train_kl_reg_loss: 0.2948; train_edge_recon_loss: 1.8304; train_gene_expr_recon_loss: 454.3735; train_group_lasso_reg_loss: 0.0000; train_global_loss: 456.4988; train_optim_loss: 456.4988; val_kl_reg_loss: 0.3063; val_edge_recon_loss: 1.8544; val_gene_expr_recon_loss: 451.6143; val_group_lasso_reg_loss: 0.0000; val_global_loss: 453.7749; val_optim_loss: 453.7749
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.7336; val_auprc_score: 0.6524; val_best_acc_score: 0.6334; val_best_f1_score: 0.7317; train_kl_reg_loss: 0.3118; train_edge_recon_loss: 1.5853; train_gene_expr_recon_loss: 449.1858; train_group_lasso_reg_loss: 0.0000; train_global_loss: 451.0829; train_optim_loss: 451.0829; val_kl_reg_loss: 0.3146; val_edge_recon_loss: 1.3969; val_gene_expr_recon_loss: 448.3058; val_group_lasso_reg_loss: 0.0000; val_global_loss: 450.0173; val_optim_loss: 450.0173
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.6999; val_auprc_score: 0.6249; val_best_acc_score: 0.6004; val_best_f1_score: 0.7145; train_kl_reg_loss: 0.3222; train_edge_recon_loss: 1.4188; train_gene_expr_recon_loss: 445.9579; train_group_lasso_reg_loss: 0.0000; train_global_loss: 447.6989; train_optim_loss: 447.6989; val_kl_reg_loss: 0.3381; val_edge_recon_loss: 1.5160; val_gene_expr_recon_loss: 447.6768; val_group_lasso_reg_loss: 0.0000; val_global_loss: 449.5309; val_optim_loss: 449.5309

# %%
hyperparam_option_dict["radius"] = [0.10241] # [0.03094, 0.03875, 0.05102, 0.07200] # 0.10241
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0, 0.1, 0.2, 0.33, 0.5]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=1,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

def get_loss_weights(row):  
    return f"lambda_edge_recon_{row['lambda_edge_recon_']}_+_lambda_gene_expr_recon_{row['lambda_gene_expr_recon_']}"
df["loss_weights"] = df.apply(lambda row: get_loss_weights(row), axis=1)

# %%
plot_eval_metrics(fig_title="Loss Weights Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="loss_weights",
                  plot_ratio_active_gps=False,
                  file_name="loss_weights_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.2. Benchmark Node Label Method

# %% [markdown]
# - Different node label methods are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per node label method.

# %%
experiment_name = "benchmark_node_label_method"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention", "one-hop-norm", "one-hop-sum"]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Node Label Method Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="node_label_method_",
                  plot_ratio_active_gps=False,
                  file_name="node_label_method_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.3. Benchmark Gene Expression Reconstruction Distribution

# %% [markdown]
# - Different gene expression reconstruction distributions are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per gene expression reconstruction distribution.

# %%
experiment_name = "benchmark_gene_expr_recon_dist"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Gene Expression Reconstruction Distribution Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="gene_expr_recon_dist_",
                  plot_ratio_active_gps=False,
                  file_name="gene_expr_recon_dist_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.4. Benchmark Encoder Layer Architecture

# %% [markdown]
# - Different encoder layer architectures are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per encoder layer architecture.

# %%
experiment_name = "benchmark_encoder_layer_arch"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.2]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = [64]

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["conv_layer_encoder"] = ["gatv2conv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [1, 2, 4, 8]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

def get_encoder_layer_arch(row):  
    return f"conv_layer_encoder_{row['conv_layer_encoder_']}_+_encoder_n_attention_heads_{row['encoder_n_attention_heads_']}"
df["encoder_layer_arch"] = df.apply(lambda row: get_encoder_layer_arch(row), axis=1)

# %%
plot_hyperparam_benchmarking_metrics(fig_title="Encoder Layer Architecture Benchmarking Evaluation Metrics",
                                     df=df,
                                     y_col_name="encoder_layer_arch",
                                     plot_ratio_active_gps=False,
                                     file_name="encoder_layer_arch_benchmarking_eval_metrics.png",
                                     save_fig=True)

# %% [markdown]
# ### 2.5. Benchmark Encoder Hidden Layer Size

# %% [markdown]
# - Different sizes of the encoder hidden layer are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per encoder hidden layer size.

# %%
experiment_name = "benchmark_encoder_n_hidden"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None, 0.5, 1., 2.]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Encoder Hidden Layer Size Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="encoder_n_hidden_",
                  plot_ratio_active_gps=False,
                  file_name="encoder_n_hidden_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.6. Benchmark Active Gene Programs

# %% [markdown]
# - Different combinations of the active gene program threshold ratio and the group lasso regularization weighting hyperparameter are tested. Both these hyperparameters contribute to a reduction of active gene programs.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per active gp hyperparameter combination.

# %%
experiment_name = "benchmark_active_gps"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0., 0.01, 0.03, 0.1, 0.3]
hyperparam_option_dict["lambda_group_lasso"] = [0, 0.01, 0.03, 0.1, 0.3]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# Get active gene program ratio
def get_ratio_active_gps(row):
    return row["n_active_gps"] / (int(row["n_nonaddon_gps_"]) + int(row["n_addon_gps_"]))
df["ratio_active_gps"] = df.apply(lambda row: get_ratio_active_gps(row), axis=1)

# Get combination of active gene program threshold and lambda group lasso
def get_active_gp_thresh_lambda_group_lasso(row):
    return f"active_gp_thresh_{row['active_gp_thresh_ratio_']}_+_lambda_group_lasso_{row['lambda_group_lasso_']}"
df["active_gp_thresh_lambda_group_lasso"] = df.apply(lambda row: get_active_gp_thresh_lambda_group_lasso(row), axis=1)

# %%
plot_eval_metrics(fig_title="Active GP Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="active_gp_thresh_lambda_group_lasso",
                  plot_ratio_active_gps=True,
                  file_name="active_gp_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ## 3. Method Benchmarking Experiments
