# %% [markdown]
# # Autotalker Hyperparameter Tuning

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of Computational Biology (ICB), Talavera-López Lab
# - **Date of Creation:** 07.12.2022
# - **Date of Last Modification:** 13.01.2023

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../autotalker") # 'autotalker' repo https://github.com/sebastianbirk/autotalker.git needs to be cloned into same folder as 'autotalker-reproducibility'

# %%
import itertools
import os
import random
import warnings
from datetime import datetime

import anndata as ad
import matplotlib
import matplotlib.pyplot as plt
import mlflow
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sp
import seaborn as sns
import squidpy as sq

from autotalker.models import Autotalker
from autotalker.utils import (add_gps_from_gp_dict_to_adata,
                              extract_gp_dict_from_mebocost_es_interactions,
                              extract_gp_dict_from_nichenet_ligand_target_mx,
                              extract_gp_dict_from_omnipath_lr_interactions,
                              filter_and_combine_gp_dict_gps)

# %% [markdown]
# ### 1.2 Define Parameters

# %%
## Model
# Anndata keys
counts_key = "counts"
cell_type_key = "celltype_mapped_refined"
adj_key = "spatial_connectivities"
spatial_key = "spatial"
gp_names_key = "autotalker_gp_names"
active_gp_names_key = "autotalker_active_gp_names"
gp_targets_mask_key = "autotalker_gp_targets"
gp_sources_mask_key = "autotalker_gp_sources"
latent_key = "autotalker_latent"

## Others
random_seed = 42

# %% [markdown]
# ### 1.3 Run Notebook Setup

# %%
# Ignore future warnings and user warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

# %% [markdown]
# ### 1.4 Configure Paths and Create Directories

# %%
# Define paths
figure_folder_path = "../figures"
model_artifacts_folder_path = "../model_artifacts"
gp_data_folder_path = "../datasets/gp_data" # gene program data
srt_data_folder_path = "../datasets/srt_data" # spatially resolved transcriptomics data
srt_data_gold_folder_path = f"{srt_data_folder_path}/gold"
nichenet_ligand_target_mx_file_path = gp_data_folder_path + "/nichenet_ligand_target_matrix.csv"
omnipath_lr_interactions_file_path = gp_data_folder_path + "/omnipath_lr_interactions.csv"

# Create required directories
os.makedirs(figure_folder_path, exist_ok=True)
os.makedirs(model_artifacts_folder_path, exist_ok=True)
os.makedirs(gp_data_folder_path, exist_ok=True)

# %% [markdown]
# ### 1.5 Define Functions

# %%
def run_hyperparam_tuning(dataset,
                          hyperparam_option_dict,
                          n_iters,
                          experiment_name,
                          gp_mask="combined_priors",
                          spatial_neighborhood_graph_method="radius",
                          save_figures=False,
                          save_model=False):
    # Read dataset
    print("--- DATASET ---")
    print(f"Using dataset {dataset}.")
    adata = ad.read_h5ad(f"{srt_data_gold_folder_path}/{dataset}.h5ad")
    n_nodes = adata.layers["counts"].shape[0]
    n_genes = adata.layers["counts"].shape[1]
    print(f"Number of nodes (cells): {n_nodes}.")
    print(f"Number of node features (genes): {n_genes}.")
        
    # Retrieve gene program mask
    print("")
    print("--- GENE PROGRAMS ---")
    print(f"Using '{gp_mask}' GP mask.")
    
    if gp_mask == "fc":
        n_output = len(adata.var) * 2
        adata.varm[gp_targets_mask_key] = np.ones((len(adata.var), len(adata.var)))
        adata.varm[gp_sources_mask_key] = np.ones((len(adata.var), len(adata.var)))
        adata.uns[gp_names_key] = np.array([f"FC_GP_{i}" for i in range(len(adata.var))])
    
    elif gp_mask == "combined_priors":
        nichenet_keep_target_ratio = 0.01
        omnipath_min_curation_effort = 0
        gp_filter_mode = "subset"
        combine_overlap_gps = True
        overlap_thresh_source_genes = 0.9
        overlap_thresh_target_genes = 0.9
        overlap_thresh_genes = 0.9
        min_genes_per_gp = 1
        min_source_genes_per_gp = 0
        min_target_genes_per_gp = 0
        
        nichenet_gp_dict = extract_gp_dict_from_nichenet_ligand_target_mx(
            keep_target_ratio=nichenet_keep_target_ratio,
            load_from_disk=False,
            save_to_disk=False,
            file_path=nichenet_ligand_target_mx_file_path)
        omnipath_gp_dict = extract_gp_dict_from_omnipath_lr_interactions(
            min_curation_effort=omnipath_min_curation_effort,
            load_from_disk=False,
            save_to_disk=False,
            file_path=omnipath_lr_interactions_file_path)
        mebocost_gp_dict = extract_gp_dict_from_mebocost_es_interactions(
            dir_path = f"{gp_data_folder_path}/metabolite_enzyme_sensor_gps/",
            species="mouse",
            genes_uppercase=True)
        combined_gp_dict = dict(nichenet_gp_dict)
        combined_gp_dict.update(omnipath_gp_dict)
        combined_gp_dict.update(mebocost_gp_dict)

        # Filter and combine gene programs
        combined_new_gp_dict = filter_and_combine_gp_dict_gps(
            gp_dict=combined_gp_dict,
            gp_filter_mode=gp_filter_mode,
            combine_overlap_gps=combine_overlap_gps,
            overlap_thresh_source_genes=overlap_thresh_source_genes,
            overlap_thresh_target_genes=overlap_thresh_target_genes,
            overlap_thresh_genes=overlap_thresh_genes,
            verbose=True)

        print(f"Number of gene programs before filtering and combining: {len(combined_gp_dict)}.")
        print(f"Number of gene programs after filtering and combining: {len(combined_new_gp_dict)}.")
        
        # Add the gene program dictionary as binary masks to the adata for model training
        add_gps_from_gp_dict_to_adata(
            gp_dict=combined_new_gp_dict,
            adata=adata,
            genes_uppercase=True,
            gp_targets_mask_key=gp_targets_mask_key,
            gp_sources_mask_key=gp_sources_mask_key,
            gp_names_key=gp_names_key,
            min_genes_per_gp=min_genes_per_gp,
            min_source_genes_per_gp=min_source_genes_per_gp,
            min_target_genes_per_gp=min_target_genes_per_gp,
            max_genes_per_gp=None,
            max_source_genes_per_gp=None,
            max_target_genes_per_gp=None)
        
    # Summarize gene programs
    print(f"Number of gene programs with probed genes: {len(adata.uns['autotalker_gp_names'])}.")
    print(f"Example gene programs: {random.sample(list(adata.uns['autotalker_gp_names']), 5)}.")
    print(f"Number of gene program target genes: {adata.varm['autotalker_gp_targets'].sum()}.")
    print(f"Number of gene program source genes: {adata.varm['autotalker_gp_sources'].sum()}.")

    # Loop `n_iters` times through combination of hyperparams 
    iters = range(n_iters)
    hyperparams, hyperparam_values = zip(*hyperparam_option_dict.items())
    for hyperparam_comb in itertools.product(*hyperparam_values, iters):
        hyperparam_dict = {}
        for hyperparam, hyperparam_value in zip(hyperparams, hyperparam_comb):
            hyperparam_dict[hyperparam] = hyperparam_value
        
        experiment = mlflow.set_experiment(experiment_name)
            
        # Log dataset params
        mlflow.log_param("dataset", dataset)
        mlflow.log_param("n_nodes", n_nodes)
        mlflow.log_param("n_genes", n_genes)
    
        # Log gp mask params
        mlflow.log_param("gp_mask", gp_mask)
        mlflow.log_param("nichenet_keep_target_ratio", nichenet_keep_target_ratio)
        mlflow.log_param("omnipath_min_curation_effort", omnipath_min_curation_effort)
        mlflow.log_param("gp_filter_mode", gp_filter_mode)
        mlflow.log_param("combine_overlap_gps", combine_overlap_gps)
        mlflow.log_param("overlap_thresh_source_genes", overlap_thresh_source_genes)
        mlflow.log_param("overlap_thresh_target_genes", overlap_thresh_target_genes)
        mlflow.log_param("overlap_thresh_genes", overlap_thresh_genes)
        mlflow.log_param("min_genes_per_gp", min_genes_per_gp)
        mlflow.log_param("min_source_genes_per_gp", min_source_genes_per_gp)
        mlflow.log_param("min_target_genes_per_gp", min_target_genes_per_gp) 
        
        if save_figures or save_model:
            # Get time for timestamping saved artifacts
            now = datetime.now()
            current_timestamp = now.strftime("%d%m%Y_%H%M%S")

            run_figure_folder_path = f"{figure_folder_path}/{dataset}/hyperparam_tuning/{experiment_name}/runs/{current_timestamp}"
            os.makedirs(run_figure_folder_path, exist_ok=True)
            run_model_artifacts_folder_path = f"{model_artifacts_folder_path}/{dataset}/hyperparam_tuning/{experiment_name}/runs/{current_timestamp}"
            os.makedirs(run_model_artifacts_folder_path, exist_ok=True)
        
        # Copy adata
        adata_run = adata.copy()

        print("")
        print("--- SPATIAL CONNECTIVITY ---")
        if spatial_neighborhood_graph_method == "radius":
            # Compute spatial neighborhood
            sq.gr.spatial_neighbors(adata_run,
                                    coord_type="generic",
                                    spatial_key=spatial_key,
                                    radius=hyperparam_dict["radius"])
        elif spatial_neighborhood_graph_method == "knn_symmetric":
            # Compute spatial neighborhood
            sq.gr.spatial_neighbors(adata_run,
                                    coord_type="generic",
                                    spatial_key=spatial_key,
                                    n_neighs=hyperparam_dict["n_neighbors"])
    
            # Make adjacency matrix symmetric
            adata.obsp["spatial_connectivities"] = adata.obsp["spatial_connectivities"].maximum(adata.obsp["spatial_connectivities"].T)
        
        else:
            raise ValueError("Please specify a valid 'spatial_neighborhood_graph_method'.")
        avg_edges_per_node = round(adata_run.obsp['spatial_connectivities'].sum(axis=0).mean(), 2)
        print(f"Average number of edges per node: {avg_edges_per_node}.")
        n_edges = int(sp.triu(adata_run.obsp['spatial_connectivities'], k=1).sum())
        print(f"Number of total edges: {n_edges}.")
        mlflow.log_param("avg_n_neighbors", avg_edges_per_node)
        mlflow.log_param("n_edges", n_edges)
        avg_n_neighbors_rounded = int(round(avg_edges_per_node))

        # Initialize model
        print("")
        if hyperparam_dict["n_hidden_encoder_divisor"] is None:
            n_hidden_encoder = len(adata.uns[gp_names_key]) # gp mask size
        else:
            n_hidden_encoder = int(len(adata.var) / hyperparam_dict["n_hidden_encoder_divisor"])
        model = Autotalker(adata_run,
                           counts_key=counts_key,
                           adj_key=adj_key,
                           gp_names_key=gp_names_key,
                           active_gp_names_key=active_gp_names_key,
                           gp_targets_mask_key=gp_targets_mask_key,
                           gp_sources_mask_key=gp_sources_mask_key,
                           latent_key=latent_key,
                           gene_expr_recon_dist=hyperparam_dict["gene_expr_recon_dist"],
                           node_label_method=hyperparam_dict["node_label_method"],
                           active_gp_thresh_ratio=hyperparam_dict["active_gp_thresh_ratio"],
                           n_hidden_encoder=n_hidden_encoder,
                           conv_layer_encoder=hyperparam_dict["conv_layer_encoder"],
                           encoder_n_attention_heads=hyperparam_dict["encoder_n_attention_heads"])

        # Train model
        print("")
        model.train(n_epochs=hyperparam_dict["n_epochs"],
                    n_epochs_all_gps=hyperparam_dict["n_epochs_all_gps"],
                    lr=hyperparam_dict["lr"],
                    lambda_edge_recon=hyperparam_dict["lambda_edge_recon"],
                    lambda_gene_expr_recon=hyperparam_dict["lambda_gene_expr_recon"],
                    lambda_group_lasso=hyperparam_dict["lambda_group_lasso"],
                    edge_val_ratio=0.1,
                    node_val_ratio=0.1,
                    edge_batch_size=hyperparam_dict["batch_size"],
                    node_batch_size=hyperparam_dict["batch_size"],
                    mlflow_experiment_id=experiment.experiment_id,
                    verbose=True,
                    seed=hyperparam_comb[-1])
        
        if save_figures:
            # Log visualizations
            # Use autotalker latent space for UMAP generation
            sc.pp.neighbors(model.adata, use_rep=latent_key)
            sc.tl.umap(model.adata, min_dist=0.3)

            # Create subplot of cell-type annotations in spatial and latent space
            fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 29))
            title = fig.suptitle(t="Cell Type Annotations in Physical and Latent Space",
                                 x=0.85,
                                 y=0.925,
                                 fontsize=20)
            sc.pl.spatial(adata=model.adata,
                          color=[cell_type_key],
                          spot_size=0.03,
                          title="Physical Space",
                          ax=axs[0],
                          show=False)
            sc.pl.umap(adata=model.adata,
                       color=[cell_type_key],
                       title="Latent Space",
                       ax=axs[1],
                       show=False)
            handles, labels = axs[0].get_legend_handles_labels()
            lgd = fig.legend(handles, labels, bbox_to_anchor=(1.225, 0.625))
            axs[0].get_legend().remove()
            axs[1].get_legend().remove()
            plt.subplots_adjust(wspace=0, hspace=0.1)
            fig.savefig(f"{run_figure_folder_path}/cell_type_annotations_in_physical_and_latent_space.png",
                        bbox_extra_artists=(lgd, title),
                        bbox_inches="tight")
            plt.close(fig)

            # Create subplot of latent Leiden cluster annotations in latent and spatial space
            resolution = 0.3
            model.compute_latent_graph_connectivities(adata=model.adata,
                                                      n_neighbors=int(round(avg_edges_per_node)),
                                                      mode="knn",
                                                      seed=random_seed)
            sc.tl.leiden(adata=model.adata,
                         resolution=resolution,
                         random_state=random_seed,
                         key_added=f"leiden_latent_{str(resolution)}",
                         adjacency=model.adata.obsp["latent_connectivities"])
            fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(10, 20))
            title = fig.suptitle(t="Latent Leiden Cluster Annotations in Latent and Physical Space",
                                 x=0.85,
                                 y=0.925,
                                 fontsize=20)
            sc.pl.umap(adata=model.adata,
                       color=[f"leiden_latent_{str(resolution)}"],
                       title=f"Latent Space",
                       ax=axs[0],
                       show=False)
            sc.pl.spatial(adata=model.adata,
                          color=[f"leiden_latent_{str(resolution)}"],
                          spot_size=0.03,
                          title=f"Physical Space",
                          ax=axs[1],
                          show=False)
            handles, labels = axs[0].get_legend_handles_labels()
            lgd = fig.legend(handles, labels, bbox_to_anchor=(1.025, 0.7))
            axs[0].get_legend().remove()
            axs[1].get_legend().remove()
            plt.subplots_adjust(wspace=0, hspace=0.1)
            fig.savefig(f"{run_figure_folder_path}/latent_leiden_cluster_annotations_in_latent_and_physical_space.png",
                        bbox_extra_artists=(lgd, title),
                        bbox_inches="tight")
            plt.close(fig)

            mlflow.log_artifacts(run_figure_folder_path,
                                 current_timestamp)
        
        if save_model:            
            model.save(dir_path=run_model_artifacts_folder_path,
                       overwrite=True,
                       save_adata=True,
                       adata_file_name=f"{dataset}.h5ad")

        mlflow.end_run()
        print("--------------------")
        print("")
        print("--------------------")

# %%
def plot_hyperparam_benchmarking_metrics(fig_title,
                                         df,
                                         y_col_name,
                                         sort_col="val_mse_score",
                                         plot_ratio_active_gps=False,
                                         save_fig=False,
                                         file_name="benchmarking_metrics.png"):
    # Compute evaluation metric ranks for sorting
    val_mse_score_ranks = (df.groupby([y_col_name])
                           ["val_mse_score"].mean().rank(ascending=True)
                           .rename("val_mse_score_rank"))
    val_auroc_score_ranks = (df.groupby([y_col_name])
                                ["val_auroc_score"].mean().rank(ascending=False)
                                .rename("val_auroc_score_rank"))
    df = df.merge(val_mse_score_ranks, on=[y_col_name])
    df = df.merge(val_auroc_score_ranks, on=[y_col_name])

    if sort_col == "val_mse_score":
        df.sort_values(by=["val_mse_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    elif sort_col == "val_auroc_score":
        df.sort_values(by=["val_auroc_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    elif sort_col == "total_score":
        df["val_total_score_rank"] = (df["val_mse_score_rank"] + 
                                      df["val_auroc_score_rank"]).rank(ascending=True)
        df.sort_values(by=["val_total_score_rank", y_col_name],
                       inplace=True,
                       ascending=False)
    
    if plot_ratio_active_gps:
        fig, axes = plt.subplots(3, 1, sharey=True, figsize=(10, 20))
        sns.boxplot(data=df, ax=axes[2], x="ratio_active_gps", y=y_col_name)
        axes[2].set_title("Ratio of Active Gene Programs")
    else:
        fig, axes = plt.subplots(2, 1, sharey=True, figsize=(10, 15))
    fig.suptitle(fig_title, fontsize=15)
    sns.boxplot(data=df, ax=axes[0], x="val_auroc_score", y=y_col_name)
    axes[0].set_title("Edge Reconstruction Area Under ROC Curve")
    sns.boxplot(data=df, ax=axes[1], x="val_mse_score", y=y_col_name)
    axes[1].set_title("Gene Expression Reconstruction Mean Squared Error")
    plt.subplots_adjust(left=0.1,
                        bottom=0.1,
                        right=0.9,
                        top=0.94,
                        wspace=0.175,
                        hspace=0.175)
    if save_fig:
        # Get time for timestamping saved artefacts
        now = datetime.now()
        current_timestamp = now.strftime("%d%m%Y_%H%M%S")
        benchmark_fig_run_dir = f"{figure_folder_path}/{dataset}/benchmarking/{experiment_name}/results/{current_timestamp}"
        os.makedirs(benchmark_fig_run_dir, exist_ok=True)
        plt.savefig(f"{benchmark_fig_run_dir}/{file_name}",
                    bbox_inches='tight')

# %% [markdown]
# ## 2. Hyperparameter Tuning Experiments

# %% [markdown]
# ### 2.1. Loss Weights

# %% [markdown]
# - Different combinations of the edge reconstruction loss and gene expression reconstruction loss weighting hyperparameters are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per loss weight combination.

# %%
experiment_name = "loss_weights"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = [64]

# %%
hyperparam_option_dict["radius"] = [0.03979, 0.05279, 0.06450, 0.07458, 0.08348]
hyperparam_option_dict["lambda_edge_recon"] = [0, 0.1, 0.2, 0.33, 0.5, 1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [1.]

model = run_hyperparam_tuning(dataset="seqfish_mouse_organogenesis_embryo1",
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=1,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              save_model=False)

# %%
hyperparam_option_dict["n_neighbors"] = [4, 8, 12, 16, 20]
hyperparam_option_dict["lambda_edge_recon"] = [0, 0.1, 0.2, 0.33, 0.5, 1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [1.]

model = run_hyperparam_tuning(dataset="seqfish_mouse_organogenesis_embryo1",
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=1,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              spatial_neighborhood_graph_method="knn_symmetric",
                              save_model=False)
# Out:
# --- DATASET ---
# Using dataset seqfish_mouse_organogenesis_embryo1.
# Number of nodes (cells): 17806.
# Number of node features (genes): 351.
#
# --- GENE PROGRAMS ---
# Using 'combined_priors' GP mask.
# Downloading NicheNet ligand target potential matrix from the web. This might take a while...
# Removing GP 'CTF1_ligand_receptor_GP' as it is a subset of GP 'CTF1_ligand_targetgenes_GP'.
# Removing GP 'LEP_ligand_receptor_GP' as it is a subset of GP 'LEP_ligand_targetgenes_GP'.
# Removing GP 'IL4_ligand_receptor_GP' as it is a subset of GP 'IL4_ligand_targetgenes_GP'.
# Removing GP 'IL12A_ligand_receptor_GP' as it is a subset of GP 'IL12A_ligand_targetgenes_GP'.
# Removing GP 'IL23A_ligand_receptor_GP' as it is a subset of GP 'IL23A_ligand_targetgenes_GP'.
# Removing GP 'CSF2_ligand_receptor_GP' as it is a subset of GP 'CSF2_ligand_targetgenes_GP'.
# Removing GP 'IL21_ligand_receptor_GP' as it is a subset of GP 'IL21_ligand_targetgenes_GP'.
# Removing GP 'TSLP_ligand_receptor_GP' as it is a subset of GP 'TSLP_ligand_targetgenes_GP'.
# Removing GP 'GH2_ligand_receptor_GP' as it is a subset of GP 'GH2_ligand_targetgenes_GP'.
# Removing GP 'EGF_ligand_receptor_GP' as it is a subset of GP 'EGF_ligand_targetgenes_GP'.
# Removing GP 'IL10_ligand_receptor_GP' as it is a subset of GP 'IL10_ligand_targetgenes_GP'.
# Removing GP 'TNFSF4_ligand_receptor_GP' as it is a subset of GP 'TNFSF4_ligand_targetgenes_GP'.
# Removing GP 'TNFSF18_ligand_receptor_GP' as it is a subset of GP 'TNFSF18_ligand_targetgenes_GP'.
# Removing GP 'TGFB1_ligand_receptor_GP' as it is a subset of GP 'TGFB1_ligand_targetgenes_GP'.
# Removing GP 'BMP2_ligand_receptor_GP' as it is a subset of GP 'BMP2_ligand_targetgenes_GP'.
# Removing GP 'IL1B_ligand_receptor_GP' as it is a subset of GP 'IL1B_ligand_targetgenes_GP'.
# Removing GP 'CSH1_ligand_receptor_GP' as it is a subset of GP 'CSH1_ligand_targetgenes_GP'.
# Removing GP 'EDN1_ligand_receptor_GP' as it is a subset of GP 'EDN1_ligand_targetgenes_GP'.
# Removing GP 'EDN3_ligand_receptor_GP' as it is a subset of GP 'EDN3_ligand_targetgenes_GP'.
# Removing GP 'GCG_ligand_receptor_GP' as it is a subset of GP 'GCG_ligand_targetgenes_GP'.
# Removing GP 'HCRT_ligand_receptor_GP' as it is a subset of GP 'HCRT_ligand_targetgenes_GP'.
# Removing GP 'IGF1_ligand_receptor_GP' as it is a subset of GP 'IGF1_ligand_targetgenes_GP'.
# Removing GP 'GRP_ligand_receptor_GP' as it is a subset of GP 'GRP_ligand_targetgenes_GP'.
# Removing GP 'NTF3_ligand_receptor_GP' as it is a subset of GP 'NTF3_ligand_targetgenes_GP'.
# Removing GP 'AVP_ligand_receptor_GP' as it is a subset of GP 'AVP_ligand_targetgenes_GP'.
# Removing GP 'CSHL1_ligand_receptor_GP' as it is a subset of GP 'CSHL1_ligand_targetgenes_GP'.
# Removing GP 'PROK1_ligand_receptor_GP' as it is a subset of GP 'PROK1_ligand_targetgenes_GP'.
# Removing GP 'AGT_ligand_receptor_GP' as it is a subset of GP 'AGT_ligand_targetgenes_GP'.
# Removing GP 'GHRH_ligand_receptor_GP' as it is a subset of GP 'GHRH_ligand_targetgenes_GP'.
# Removing GP 'DLL3_ligand_receptor_GP' as it is a subset of GP 'DLL3_ligand_targetgenes_GP'.
# Removing GP 'DLL4_ligand_receptor_GP' as it is a subset of GP 'DLL4_ligand_targetgenes_GP'.
# Removing GP 'FGF23_ligand_receptor_GP' as it is a subset of GP 'FGF23_ligand_targetgenes_GP'.
# Removing GP 'GDF6_ligand_receptor_GP' as it is a subset of GP 'GDF6_ligand_targetgenes_GP'.
# Removing GP 'GDF9_ligand_receptor_GP' as it is a subset of GP 'GDF9_ligand_targetgenes_GP'.
# Removing GP 'IL12B_ligand_receptor_GP' as it is a subset of GP 'IL12B_ligand_targetgenes_GP'.
# Removing GP 'JAG1_ligand_receptor_GP' as it is a subset of GP 'JAG1_ligand_targetgenes_GP'.
# Removing GP 'CRLF1_ligand_receptor_GP' as it is a subset of GP 'CRLF1_ligand_targetgenes_GP'.
# Removing GP 'VGF_ligand_receptor_GP' as it is a subset of GP 'VGF_ligand_targetgenes_GP'.
# Removing GP 'IL27_ligand_receptor_GP' as it is a subset of GP 'IL27_ligand_targetgenes_GP'.
# Removing GP 'CMTM8_ligand_receptor_GP' as it is a subset of GP 'CMTM8_ligand_targetgenes_GP'.
# Removing GP 'SECTM1_ligand_receptor_GP' as it is a subset of GP 'SECTM1_ligand_targetgenes_GP'.
# Removing GP 'CMTM2_ligand_receptor_GP' as it is a subset of GP 'CMTM2_ligand_targetgenes_GP'.
# Removing GP 'BMP8A_ligand_receptor_GP' as it is a subset of GP 'BMP8A_ligand_targetgenes_GP'.
# Removing GP 'GDF3_ligand_receptor_GP' as it is a subset of GP 'GDF3_ligand_targetgenes_GP'.
# Removing GP 'EFNB3_ligand_targetgenes_GP' as it is a subset of GP 'EFNB3_ligand_receptor_GP'.
# Removing GP 'EFNB2_ligand_targetgenes_GP' as it is a subset of GP 'EFNB2_ligand_receptor_GP'.
# Removing GP 'EFNB1_ligand_targetgenes_GP' as it is a subset of GP 'EFNB1_ligand_receptor_GP'.
# Removing GP 'CCL23_ligand_targetgenes_GP' as it is a subset of GP 'CCL23_ligand_receptor_GP'.
# Removing GP 'CCL27_ligand_targetgenes_GP' as it is a subset of GP 'CCL27_ligand_receptor_GP'.
# Removing GP 'CCL28_ligand_targetgenes_GP' as it is a subset of GP 'CCL28_ligand_receptor_GP'.
# Removing GP 'CCL16_ligand_targetgenes_GP' as it is a subset of GP 'CCL16_ligand_receptor_GP'.
# Removing GP 'CXCL5_ligand_targetgenes_GP' as it is a subset of GP 'CXCL5_ligand_receptor_GP'.
# Removing GP 'PMCH_ligand_targetgenes_GP' as it is a subset of GP 'PMCH_ligand_receptor_GP'.
# Removing GP 'NMS_ligand_targetgenes_GP' as it is a subset of GP 'NMS_ligand_receptor_GP'.
# Removing GP 'NMU_ligand_targetgenes_GP' as it is a subset of GP 'NMU_ligand_receptor_GP'.
# Removing GP 'NPB_ligand_targetgenes_GP' as it is a subset of GP 'NPB_ligand_receptor_GP'.
# Removing GP 'NPW_ligand_targetgenes_GP' as it is a subset of GP 'NPW_ligand_receptor_GP'.
# Removing GP 'RLN3_ligand_targetgenes_GP' as it is a subset of GP 'RLN3_ligand_receptor_GP'.
# Removing GP 'PYY_ligand_targetgenes_GP' as it is a subset of GP 'PYY_ligand_receptor_GP'.
# Removing GP 'PPY_ligand_targetgenes_GP' as it is a subset of GP 'PPY_ligand_receptor_GP'.
# Removing GP 'NRG3_ligand_targetgenes_GP' as it is a subset of GP 'NRG3_ligand_receptor_GP'.
# Removing GP 'NRG4_ligand_targetgenes_GP' as it is a subset of GP 'NRG4_ligand_receptor_GP'.
# Removing GP 'FGF22_ligand_targetgenes_GP' as it is a subset of GP 'FGF22_ligand_receptor_GP'.
# Removing GP 'FGF13_ligand_targetgenes_GP' as it is a subset of GP 'FGF13_ligand_receptor_GP'.
# Removing GP 'FGF11_ligand_targetgenes_GP' as it is a subset of GP 'FGF11_ligand_receptor_GP'.
# Removing GP 'FGF14_ligand_targetgenes_GP' as it is a subset of GP 'FGF14_ligand_receptor_GP'.
# Removing GP 'PODXL2_ligand_targetgenes_GP' as it is a subset of GP 'PODXL2_ligand_receptor_GP'.
# Removing GP 'ADM2_ligand_targetgenes_GP' as it is a subset of GP 'ADM2_ligand_receptor_GP'.
# Removing GP 'APOB_ligand_targetgenes_GP' as it is a subset of GP 'APOB_ligand_receptor_GP'.
# Removing GP 'NPS_ligand_targetgenes_GP' as it is a subset of GP 'NPS_ligand_receptor_GP'.
# Removing GP 'PTH2_ligand_targetgenes_GP' as it is a subset of GP 'PTH2_ligand_receptor_GP'.
# Removing GP 'INSL3_ligand_targetgenes_GP' as it is a subset of GP 'INSL3_ligand_receptor_GP'.
# Removing GP 'NECTIN3_ligand_targetgenes_GP' as it is a subset of GP 'NECTIN3_ligand_receptor_GP'.
# Removing GP 'LAMA1_ligand_targetgenes_GP' as it is a subset of GP 'LAMA1_ligand_receptor_GP'.
# Removing GP 'WNT9A_ligand_targetgenes_GP' as it is a subset of GP 'WNT9A_ligand_receptor_GP'.
# Removing GP 'WNT9B_ligand_targetgenes_GP' as it is a subset of GP 'WNT9B_ligand_receptor_GP'.
# Removing GP 'WNT3_ligand_targetgenes_GP' as it is a subset of GP 'WNT3_ligand_receptor_GP'.
# Removing GP 'SOST_ligand_targetgenes_GP' as it is a subset of GP 'SOST_ligand_receptor_GP'.
# Removing GP 'EFNA1_ligand_targetgenes_GP' as it is a subset of GP 'EFNA1_ligand_receptor_GP'.
# Removing GP 'EFNA2_ligand_targetgenes_GP' as it is a subset of GP 'EFNA2_ligand_receptor_GP'.
# Removing GP 'EFNA3_ligand_targetgenes_GP' as it is a subset of GP 'EFNA3_ligand_receptor_GP'.
# Removing GP 'CCL22_ligand_targetgenes_GP' as it is a subset of GP 'CCL22_ligand_receptor_GP'.
# Removing GP 'NRG2_ligand_targetgenes_GP' as it is a subset of GP 'NRG2_ligand_receptor_GP'.
# Removing GP 'LAMC2_ligand_targetgenes_GP' as it is a subset of GP 'LAMC2_ligand_receptor_GP'.
# Removing GP 'ICAM5_ligand_targetgenes_GP' as it is a subset of GP 'ICAM5_ligand_receptor_GP'.
# Removing GP 'COMP_ligand_targetgenes_GP' as it is a subset of GP 'COMP_ligand_receptor_GP'.
# Removing GP 'CHAD_ligand_targetgenes_GP' as it is a subset of GP 'CHAD_ligand_receptor_GP'.
# Removing GP 'THBS4_ligand_targetgenes_GP' as it is a subset of GP 'THBS4_ligand_receptor_GP'.
# Removing GP 'SEMA7A_ligand_targetgenes_GP' as it is a subset of GP 'SEMA7A_ligand_receptor_GP'.
# Removing GP 'CCL8_ligand_targetgenes_GP' as it is a subset of GP 'CCL8_ligand_receptor_GP'.
# Removing GP 'CCL7_ligand_targetgenes_GP' as it is a subset of GP 'CCL7_ligand_receptor_GP'.
# Removing GP 'XCL1_ligand_targetgenes_GP' as it is a subset of GP 'XCL1_ligand_receptor_GP'.
# Removing GP 'CCL4L1_ligand_targetgenes_GP' as it is a subset of GP 'CCL4L1_ligand_receptor_GP'.
# Removing GP 'COPA_ligand_targetgenes_GP' as it is a subset of GP 'COPA_ligand_receptor_GP'.
# Removing GP 'GUCA2A_ligand_targetgenes_GP' as it is a subset of GP 'GUCA2A_ligand_receptor_GP'.
# Removing GP 'GUCA2B_ligand_targetgenes_GP' as it is a subset of GP 'GUCA2B_ligand_receptor_GP'.
# Removing GP 'NTN4_ligand_targetgenes_GP' as it is a subset of GP 'NTN4_ligand_receptor_GP'.
# Removing GP 'CD99_ligand_targetgenes_GP' as it is a subset of GP 'CD99_ligand_receptor_GP'.
# Removing GP 'SEMA3C_ligand_targetgenes_GP' as it is a subset of GP 'SEMA3C_ligand_receptor_GP'.
# Removing GP 'NECTIN2_ligand_targetgenes_GP' as it is a subset of GP 'NECTIN2_ligand_receptor_GP'.
# Removing GP 'HLA-B_ligand_targetgenes_GP' as it is a subset of GP 'HLA-B_ligand_receptor_GP'.
# Removing GP 'HLA-C_ligand_targetgenes_GP' as it is a subset of GP 'HLA-C_ligand_receptor_GP'.
# Removing GP 'CNTN1_ligand_targetgenes_GP' as it is a subset of GP 'CNTN1_ligand_receptor_GP'.
# Removing GP 'SEMA3F_ligand_targetgenes_GP' as it is a subset of GP 'SEMA3F_ligand_receptor_GP'.
# Removing GP 'FAM3C_ligand_targetgenes_GP' as it is a subset of GP 'FAM3C_ligand_receptor_GP'.
# Removing GP 'ULBP2_ligand_targetgenes_GP' as it is a subset of GP 'ULBP2_ligand_receptor_GP'.
# Removing GP 'GPHA2_ligand_targetgenes_GP' as it is a subset of GP 'GPHA2_ligand_receptor_GP'.
# Removing GP 'FLRT3_ligand_targetgenes_GP' as it is a subset of GP 'FLRT3_ligand_receptor_GP'.
# Removing GP 'PRND_ligand_targetgenes_GP' as it is a subset of GP 'PRND_ligand_receptor_GP'.
# Removing GP 'NDP_ligand_targetgenes_GP' as it is a subset of GP 'NDP_ligand_receptor_GP'.
# Removing GP 'RSPO2_ligand_targetgenes_GP' as it is a subset of GP 'RSPO2_ligand_receptor_GP'.
# Removing GP 'RSPO4_ligand_targetgenes_GP' as it is a subset of GP 'RSPO4_ligand_receptor_GP'.
# Removing GP 'NTN3_ligand_targetgenes_GP' as it is a subset of GP 'NTN3_ligand_receptor_GP'.
# Removing GP 'DHH_ligand_targetgenes_GP' as it is a subset of GP 'DHH_ligand_receptor_GP'.
# Removing GP 'DSC1_ligand_targetgenes_GP' as it is a subset of GP 'DSC1_ligand_receptor_GP'.
# Removing GP 'DSC2_ligand_targetgenes_GP' as it is a subset of GP 'DSC2_ligand_receptor_GP'.
# Removing GP 'NLGN2_ligand_targetgenes_GP' as it is a subset of GP 'NLGN2_ligand_receptor_GP'.
# Removing GP 'NXPH1_ligand_targetgenes_GP' as it is a subset of GP 'NXPH1_ligand_receptor_GP'.
# Removing GP 'NPFF_ligand_targetgenes_GP' as it is a subset of GP 'NPFF_ligand_receptor_GP'.
# Removing GP 'TAC3_ligand_targetgenes_GP' as it is a subset of GP 'TAC3_ligand_receptor_GP'.
# Removing GP 'TAC4_ligand_targetgenes_GP' as it is a subset of GP 'TAC4_ligand_receptor_GP'.
# Removing GP 'NMB_ligand_targetgenes_GP' as it is a subset of GP 'NMB_ligand_receptor_GP'.
# Removing GP 'GALP_ligand_targetgenes_GP' as it is a subset of GP 'GALP_ligand_receptor_GP'.
# Removing GP 'MLN_ligand_targetgenes_GP' as it is a subset of GP 'MLN_ligand_receptor_GP'.
# Removing GP 'IL17B_ligand_targetgenes_GP' as it is a subset of GP 'IL17B_ligand_receptor_GP'.
# Removing GP 'QRFP_ligand_targetgenes_GP' as it is a subset of GP 'QRFP_ligand_receptor_GP'.
# Removing GP 'TXLNA_ligand_targetgenes_GP' as it is a subset of GP 'TXLNA_ligand_receptor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Guanosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Inosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Adenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Corticosterone_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Cortisol_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'D-Galactose_metabolite_enzyme_sensor_GP' as it is a subset of GP 'D-Glucose_metabolite_enzyme_sensor_GP'.
# Removing GP 'D-Maltose_metabolite_enzyme_sensor_GP' as it is a subset of GP 'D-Glucose_metabolite_enzyme_sensor_GP'.
# Removing GP 'Estriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Estrone_metabolite_enzyme_sensor_GP'.
# Removing GP 'Estriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Estradiol_metabolite_enzyme_sensor_GP'.
# Removing GP 'L-Dopa_metabolite_enzyme_sensor_GP' as it is a subset of GP 'L-Tyrosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyinosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Deoxyadenosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Guanosine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Inosine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Stearic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Oleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Epinephrine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Norepinephrine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Stearic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Palmitic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Androsterone_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Testosterone_metabolite_enzyme_sensor_GP'.
# Removing GP 'Liothyronine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Thyroxine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Cytidine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Uridine_metabolite_enzyme_sensor_GP'.
# Removing GP 'Thymine_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Uracil_metabolite_enzyme_sensor_GP'.
# Removing GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Linoleic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Stearic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Stearic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Arachidonic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Prostaglandin F2a_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Prostaglandin E2_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Retinal_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'alpha-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'all-trans-Retinoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Docosahexaenoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Eicosapentaenoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Eicosapentaenoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Docosahexaenoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP '13-cis-Retinoic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP '9-cis-Retinoic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Dihomo-gamma-linolenic acid_metabolite_enzyme_sensor_GP' as it is a subset of GP 'gamma-Linolenic acid_metabolite_enzyme_sensor_GP'.
# Removing GP 'Calcitriol_metabolite_enzyme_sensor_GP' as it is a subset of GP 'Calcidiol_metabolite_enzyme_sensor_GP'.
# Number of gene programs before filtering and combining: 1725.
# Number of gene programs after filtering and combining: 1575.
# Number of gene programs with probed genes: 489.
# Example gene programs: ['RSPO3_ligand_targetgenes_GP', 'INHBA_ligand_targetgenes_GP', 'IFNL3_ligand_targetgenes_GP', 'CALR_ligand_targetgenes_GP', 'FGF4_ligand_receptor_GP'].
# Number of gene program target genes: 7476.
# Number of gene program source genes: 127.
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 4.78.
# Number of total edges: 42526.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 16025
# Number of validation nodes: 1781
# Number of training edges: 38274
# Number of validation edges: 4252
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.9528; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 535.5358; train_group_lasso_reg_loss: 0.0000; train_global_loss: 536.4886; train_optim_loss: 536.4886; val_kl_reg_loss: 0.7329; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 524.7384; val_group_lasso_reg_loss: 0.0000; val_global_loss: 525.4713; val_optim_loss: 525.4713
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.5000; val_auprc_score: 0.5000; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.7517; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 513.1595; train_group_lasso_reg_loss: 0.0000; train_global_loss: 513.9112; train_optim_loss: 513.9112; val_kl_reg_loss: 0.6552; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 513.1255; val_group_lasso_reg_loss: 0.0000; val_global_loss: 513.7806; val_optim_loss: 513.7806
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.5006; val_auprc_score: 0.5003; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.7030; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 503.9418; train_group_lasso_reg_loss: 0.0000; train_global_loss: 504.6448; train_optim_loss: 504.6448; val_kl_reg_loss: 0.6332; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 505.3667; val_group_lasso_reg_loss: 0.0000; val_global_loss: 505.9999; val_optim_loss: 505.9999
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.5002; val_auprc_score: 0.5001; val_best_acc_score: 0.5002; val_best_f1_score: 0.6668; train_kl_reg_loss: 0.6693; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 497.0745; train_group_lasso_reg_loss: 0.0000; train_global_loss: 497.7438; train_optim_loss: 497.7438; val_kl_reg_loss: 0.6112; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 502.9719; val_group_lasso_reg_loss: 0.0000; val_global_loss: 503.5832; val_optim_loss: 503.5832
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.5004; val_auprc_score: 0.5002; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.6551; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 492.2538; train_group_lasso_reg_loss: 0.0000; train_global_loss: 492.9089; train_optim_loss: 492.9089; val_kl_reg_loss: 0.6154; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 497.3045; val_group_lasso_reg_loss: 0.0000; val_global_loss: 497.9199; val_optim_loss: 497.9199
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.5002; val_auprc_score: 0.5001; val_best_acc_score: 0.5000; val_best_f1_score: 0.6667; train_kl_reg_loss: 0.6493; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 488.8149; train_group_lasso_reg_loss: 0.0000; train_global_loss: 489.4643; train_optim_loss: 489.4643; val_kl_reg_loss: 0.6036; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 494.9857; val_group_lasso_reg_loss: 0.0000; val_global_loss: 495.5894; val_optim_loss: 495.5894
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.5009; val_auprc_score: 0.5005; val_best_acc_score: 0.5006; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.6409; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 486.1956; train_group_lasso_reg_loss: 0.0000; train_global_loss: 486.8365; train_optim_loss: 486.8365; val_kl_reg_loss: 0.6173; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 493.7040; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.3213; val_optim_loss: 494.3213
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.5012; val_auprc_score: 0.5006; val_best_acc_score: 0.5007; val_best_f1_score: 0.6670; train_kl_reg_loss: 0.6420; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 483.8869; train_group_lasso_reg_loss: 0.0000; train_global_loss: 484.5289; train_optim_loss: 484.5289; val_kl_reg_loss: 0.5884; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 493.7052; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.2936; val_optim_loss: 494.2936
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.5008; val_auprc_score: 0.5004; val_best_acc_score: 0.5006; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.6449; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 481.7570; train_group_lasso_reg_loss: 0.0000; train_global_loss: 482.4019; train_optim_loss: 482.4019; val_kl_reg_loss: 0.6090; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 491.2987; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.9077; val_optim_loss: 491.9077
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.5013; val_auprc_score: 0.5006; val_best_acc_score: 0.5008; val_best_f1_score: 0.6670; train_kl_reg_loss: 0.6380; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 480.4991; train_group_lasso_reg_loss: 0.0000; train_global_loss: 481.1371; train_optim_loss: 481.1371; val_kl_reg_loss: 0.5928; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 490.6330; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.2258; val_optim_loss: 491.2258
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.5020; val_auprc_score: 0.5010; val_best_acc_score: 0.5014; val_best_f1_score: 0.6673; train_kl_reg_loss: 0.6400; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 479.4300; train_group_lasso_reg_loss: 0.0000; train_global_loss: 480.0700; train_optim_loss: 480.0700; val_kl_reg_loss: 0.6059; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 491.1768; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.7827; val_optim_loss: 491.7827
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.5006; val_auprc_score: 0.5003; val_best_acc_score: 0.5004; val_best_f1_score: 0.6668; train_kl_reg_loss: 0.6400; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 478.2079; train_group_lasso_reg_loss: 0.0000; train_global_loss: 478.8478; train_optim_loss: 478.8478; val_kl_reg_loss: 0.6060; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 490.4363; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.0423; val_optim_loss: 491.0423
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.5006; val_auprc_score: 0.5003; val_best_acc_score: 0.5004; val_best_f1_score: 0.6668; train_kl_reg_loss: 0.6452; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 477.4898; train_group_lasso_reg_loss: 0.0000; train_global_loss: 478.1349; train_optim_loss: 478.1349; val_kl_reg_loss: 0.6078; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 489.1824; val_group_lasso_reg_loss: 0.0000; val_global_loss: 489.7903; val_optim_loss: 489.7903
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.5012; val_auprc_score: 0.5006; val_best_acc_score: 0.5005; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.6413; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 476.9153; train_group_lasso_reg_loss: 0.0000; train_global_loss: 477.5565; train_optim_loss: 477.5565; val_kl_reg_loss: 0.6116; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 489.8986; val_group_lasso_reg_loss: 0.0000; val_global_loss: 490.5102; val_optim_loss: 490.5102
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.5028; val_auprc_score: 0.5014; val_best_acc_score: 0.5018; val_best_f1_score: 0.6675; train_kl_reg_loss: 0.6498; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 476.3535; train_group_lasso_reg_loss: 0.0000; train_global_loss: 477.0033; train_optim_loss: 477.0033; val_kl_reg_loss: 0.6054; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 489.4341; val_group_lasso_reg_loss: 0.0000; val_global_loss: 490.0395; val_optim_loss: 490.0395
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.5009; val_auprc_score: 0.5005; val_best_acc_score: 0.5006; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.6416; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 475.4051; train_group_lasso_reg_loss: 0.0000; train_global_loss: 476.0467; train_optim_loss: 476.0467; val_kl_reg_loss: 0.6215; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 488.2166; val_group_lasso_reg_loss: 0.0000; val_global_loss: 488.8381; val_optim_loss: 488.8381
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.5013; val_auprc_score: 0.5006; val_best_acc_score: 0.5009; val_best_f1_score: 0.6671; train_kl_reg_loss: 0.6414; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 474.8445; train_group_lasso_reg_loss: 0.0000; train_global_loss: 475.4859; train_optim_loss: 475.4859; val_kl_reg_loss: 0.6145; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 489.3677; val_group_lasso_reg_loss: 0.0000; val_global_loss: 489.9822; val_optim_loss: 489.9822
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.5018; val_auprc_score: 0.5009; val_best_acc_score: 0.5013; val_best_f1_score: 0.6672; train_kl_reg_loss: 0.6438; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 474.6938; train_group_lasso_reg_loss: 0.0000; train_global_loss: 475.3375; train_optim_loss: 475.3375; val_kl_reg_loss: 0.6136; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 489.2755; val_group_lasso_reg_loss: 0.0000; val_global_loss: 489.8891; val_optim_loss: 489.8891
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.5019; val_auprc_score: 0.5009; val_best_acc_score: 0.5006; val_best_f1_score: 0.6669; train_kl_reg_loss: 0.6428; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 473.6451; train_group_lasso_reg_loss: 0.0000; train_global_loss: 474.2879; train_optim_loss: 474.2879; val_kl_reg_loss: 0.6085; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 490.5652; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.1737; val_optim_loss: 491.1737
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 0.0001.
#
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.5018; val_auprc_score: 0.5009; val_best_acc_score: 0.5007; val_best_f1_score: 0.6670; train_kl_reg_loss: 0.6374; train_edge_recon_loss: 0.0000; train_gene_expr_recon_loss: 470.8186; train_group_lasso_reg_loss: 0.0000; train_global_loss: 471.4560; train_optim_loss: 471.4560; val_kl_reg_loss: 0.6098; val_edge_recon_loss: 0.0000; val_gene_expr_recon_loss: 487.8714; val_group_lasso_reg_loss: 0.0000; val_global_loss: 488.4813; val_optim_loss: 488.4813
#
# Model training finished after 4 min 44 sec.
# Using best model state, which was in epoch 20.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.5022
# Val AUPRC score: 0.5011
# Val best accuracy score: 0.5015
# Val best F1 score: 0.6673
# Val MSE score: 0.8423
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 4.78.
# Number of total edges: 42526.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 16025
# Number of validation nodes: 1781
# Number of training edges: 38274
# Number of validation edges: 4252
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.6551; val_auprc_score: 0.5918; val_best_acc_score: 0.6132; val_best_f1_score: 0.7211; train_kl_reg_loss: 0.3028; train_edge_recon_loss: 4.3764; train_gene_expr_recon_loss: 540.8100; train_group_lasso_reg_loss: 0.0000; train_global_loss: 545.4893; train_optim_loss: 545.4893; val_kl_reg_loss: 0.3603; val_edge_recon_loss: 3.6493; val_gene_expr_recon_loss: 527.1673; val_group_lasso_reg_loss: 0.0000; val_global_loss: 531.1770; val_optim_loss: 531.1770
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.6818; val_auprc_score: 0.6111; val_best_acc_score: 0.6262; val_best_f1_score: 0.7279; train_kl_reg_loss: 0.4099; train_edge_recon_loss: 3.0743; train_gene_expr_recon_loss: 515.0371; train_group_lasso_reg_loss: 0.0000; train_global_loss: 518.5213; train_optim_loss: 518.5213; val_kl_reg_loss: 0.4186; val_edge_recon_loss: 2.6249; val_gene_expr_recon_loss: 514.0160; val_group_lasso_reg_loss: 0.0000; val_global_loss: 517.0595; val_optim_loss: 517.0595
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.6771; val_auprc_score: 0.6076; val_best_acc_score: 0.6171; val_best_f1_score: 0.7231; train_kl_reg_loss: 0.4606; train_edge_recon_loss: 2.4984; train_gene_expr_recon_loss: 504.6457; train_group_lasso_reg_loss: 0.0000; train_global_loss: 507.6048; train_optim_loss: 507.6048; val_kl_reg_loss: 0.4488; val_edge_recon_loss: 2.2352; val_gene_expr_recon_loss: 505.5764; val_group_lasso_reg_loss: 0.0000; val_global_loss: 508.2605; val_optim_loss: 508.2605
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.6737; val_auprc_score: 0.6051; val_best_acc_score: 0.6158; val_best_f1_score: 0.7225; train_kl_reg_loss: 0.4866; train_edge_recon_loss: 2.1544; train_gene_expr_recon_loss: 497.1771; train_group_lasso_reg_loss: 0.0000; train_global_loss: 499.8182; train_optim_loss: 499.8182; val_kl_reg_loss: 0.4661; val_edge_recon_loss: 2.0879; val_gene_expr_recon_loss: 502.7577; val_group_lasso_reg_loss: 0.0000; val_global_loss: 505.3117; val_optim_loss: 505.3117
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.6849; val_auprc_score: 0.6134; val_best_acc_score: 0.6088; val_best_f1_score: 0.7188; train_kl_reg_loss: 0.5116; train_edge_recon_loss: 1.9184; train_gene_expr_recon_loss: 492.0652; train_group_lasso_reg_loss: 0.0000; train_global_loss: 494.4952; train_optim_loss: 494.4952; val_kl_reg_loss: 0.5037; val_edge_recon_loss: 1.8272; val_gene_expr_recon_loss: 497.0708; val_group_lasso_reg_loss: 0.0000; val_global_loss: 499.4017; val_optim_loss: 499.4017
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.7103; val_auprc_score: 0.6331; val_best_acc_score: 0.6203; val_best_f1_score: 0.7248; train_kl_reg_loss: 0.5284; train_edge_recon_loss: 1.7403; train_gene_expr_recon_loss: 488.5940; train_group_lasso_reg_loss: 0.0000; train_global_loss: 490.8626; train_optim_loss: 490.8626; val_kl_reg_loss: 0.4911; val_edge_recon_loss: 1.5827; val_gene_expr_recon_loss: 494.9509; val_group_lasso_reg_loss: 0.0000; val_global_loss: 497.0248; val_optim_loss: 497.0248
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.7132; val_auprc_score: 0.6355; val_best_acc_score: 0.6243; val_best_f1_score: 0.7269; train_kl_reg_loss: 0.5390; train_edge_recon_loss: 1.6446; train_gene_expr_recon_loss: 485.9900; train_group_lasso_reg_loss: 0.0000; train_global_loss: 488.1736; train_optim_loss: 488.1736; val_kl_reg_loss: 0.5188; val_edge_recon_loss: 1.4926; val_gene_expr_recon_loss: 494.1578; val_group_lasso_reg_loss: 0.0000; val_global_loss: 496.1692; val_optim_loss: 496.1692
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.7217; val_auprc_score: 0.6424; val_best_acc_score: 0.6238; val_best_f1_score: 0.7267; train_kl_reg_loss: 0.5507; train_edge_recon_loss: 1.5250; train_gene_expr_recon_loss: 483.8772; train_group_lasso_reg_loss: 0.0000; train_global_loss: 485.9529; train_optim_loss: 485.9529; val_kl_reg_loss: 0.5206; val_edge_recon_loss: 1.4282; val_gene_expr_recon_loss: 493.6001; val_group_lasso_reg_loss: 0.0000; val_global_loss: 495.5490; val_optim_loss: 495.5490
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.7101; val_auprc_score: 0.6330; val_best_acc_score: 0.6187; val_best_f1_score: 0.7239; train_kl_reg_loss: 0.5618; train_edge_recon_loss: 1.4617; train_gene_expr_recon_loss: 481.8135; train_group_lasso_reg_loss: 0.0000; train_global_loss: 483.8371; train_optim_loss: 483.8371; val_kl_reg_loss: 0.5411; val_edge_recon_loss: 1.4246; val_gene_expr_recon_loss: 491.9379; val_group_lasso_reg_loss: 0.0000; val_global_loss: 493.9036; val_optim_loss: 493.9036
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.7324; val_auprc_score: 0.6513; val_best_acc_score: 0.6303; val_best_f1_score: 0.7301; train_kl_reg_loss: 0.5605; train_edge_recon_loss: 1.3917; train_gene_expr_recon_loss: 480.7687; train_group_lasso_reg_loss: 0.0000; train_global_loss: 482.7209; train_optim_loss: 482.7209; val_kl_reg_loss: 0.5326; val_edge_recon_loss: 1.2825; val_gene_expr_recon_loss: 491.5536; val_group_lasso_reg_loss: 0.0000; val_global_loss: 493.3687; val_optim_loss: 493.3687
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.7468; val_auprc_score: 0.6639; val_best_acc_score: 0.6463; val_best_f1_score: 0.7387; train_kl_reg_loss: 0.5679; train_edge_recon_loss: 1.3238; train_gene_expr_recon_loss: 479.6956; train_group_lasso_reg_loss: 0.0000; train_global_loss: 481.5873; train_optim_loss: 481.5873; val_kl_reg_loss: 0.5466; val_edge_recon_loss: 1.2186; val_gene_expr_recon_loss: 492.3695; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.1347; val_optim_loss: 494.1347
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.7218; val_auprc_score: 0.6425; val_best_acc_score: 0.6163; val_best_f1_score: 0.7227; train_kl_reg_loss: 0.5698; train_edge_recon_loss: 1.2863; train_gene_expr_recon_loss: 478.5386; train_group_lasso_reg_loss: 0.0000; train_global_loss: 480.3947; train_optim_loss: 480.3947; val_kl_reg_loss: 0.5412; val_edge_recon_loss: 1.3131; val_gene_expr_recon_loss: 491.7817; val_group_lasso_reg_loss: 0.0000; val_global_loss: 493.6361; val_optim_loss: 493.6361
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.7361; val_auprc_score: 0.6546; val_best_acc_score: 0.6276; val_best_f1_score: 0.7286; train_kl_reg_loss: 0.5790; train_edge_recon_loss: 1.2493; train_gene_expr_recon_loss: 477.9180; train_group_lasso_reg_loss: 0.0000; train_global_loss: 479.7464; train_optim_loss: 479.7464; val_kl_reg_loss: 0.5450; val_edge_recon_loss: 1.2314; val_gene_expr_recon_loss: 490.1029; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.8794; val_optim_loss: 491.8794
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.7484; val_auprc_score: 0.6652; val_best_acc_score: 0.6361; val_best_f1_score: 0.7332; train_kl_reg_loss: 0.5801; train_edge_recon_loss: 1.2282; train_gene_expr_recon_loss: 477.2724; train_group_lasso_reg_loss: 0.0000; train_global_loss: 479.0807; train_optim_loss: 479.0807; val_kl_reg_loss: 0.5513; val_edge_recon_loss: 1.1596; val_gene_expr_recon_loss: 490.8192; val_group_lasso_reg_loss: 0.0000; val_global_loss: 492.5301; val_optim_loss: 492.5301
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.7453; val_auprc_score: 0.6625; val_best_acc_score: 0.6315; val_best_f1_score: 0.7307; train_kl_reg_loss: 0.5858; train_edge_recon_loss: 1.1974; train_gene_expr_recon_loss: 476.7865; train_group_lasso_reg_loss: 0.0000; train_global_loss: 478.5697; train_optim_loss: 478.5697; val_kl_reg_loss: 0.5373; val_edge_recon_loss: 1.1722; val_gene_expr_recon_loss: 490.7319; val_group_lasso_reg_loss: 0.0000; val_global_loss: 492.4414; val_optim_loss: 492.4414
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.7259; val_auprc_score: 0.6459; val_best_acc_score: 0.6167; val_best_f1_score: 0.7229; train_kl_reg_loss: 0.5844; train_edge_recon_loss: 1.1959; train_gene_expr_recon_loss: 475.8224; train_group_lasso_reg_loss: 0.0000; train_global_loss: 477.6028; train_optim_loss: 477.6028; val_kl_reg_loss: 0.5591; val_edge_recon_loss: 1.2406; val_gene_expr_recon_loss: 489.6932; val_group_lasso_reg_loss: 0.0000; val_global_loss: 491.4929; val_optim_loss: 491.4929
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.7594; val_auprc_score: 0.6751; val_best_acc_score: 0.6457; val_best_f1_score: 0.7384; train_kl_reg_loss: 0.5824; train_edge_recon_loss: 1.1613; train_gene_expr_recon_loss: 475.3070; train_group_lasso_reg_loss: 0.0000; train_global_loss: 477.0506; train_optim_loss: 477.0506; val_kl_reg_loss: 0.5601; val_edge_recon_loss: 1.0673; val_gene_expr_recon_loss: 490.8519; val_group_lasso_reg_loss: 0.0000; val_global_loss: 492.4793; val_optim_loss: 492.4793
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.7500; val_auprc_score: 0.6667; val_best_acc_score: 0.6381; val_best_f1_score: 0.7342; train_kl_reg_loss: 0.5870; train_edge_recon_loss: 1.1410; train_gene_expr_recon_loss: 475.2815; train_group_lasso_reg_loss: 0.0000; train_global_loss: 477.0094; train_optim_loss: 477.0094; val_kl_reg_loss: 0.5677; val_edge_recon_loss: 1.1257; val_gene_expr_recon_loss: 490.6877; val_group_lasso_reg_loss: 0.0000; val_global_loss: 492.3811; val_optim_loss: 492.3811
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.7488; val_auprc_score: 0.6656; val_best_acc_score: 0.6376; val_best_f1_score: 0.7340; train_kl_reg_loss: 0.5871; train_edge_recon_loss: 1.1301; train_gene_expr_recon_loss: 474.2184; train_group_lasso_reg_loss: 0.0000; train_global_loss: 475.9357; train_optim_loss: 475.9357; val_kl_reg_loss: 0.5559; val_edge_recon_loss: 1.1218; val_gene_expr_recon_loss: 491.9907; val_group_lasso_reg_loss: 0.0000; val_global_loss: 493.6685; val_optim_loss: 493.6685
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 0.0001.
#
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.7880; val_auprc_score: 0.7023; val_best_acc_score: 0.6740; val_best_f1_score: 0.7542; train_kl_reg_loss: 0.5919; train_edge_recon_loss: 0.9698; train_gene_expr_recon_loss: 471.0090; train_group_lasso_reg_loss: 0.0000; train_global_loss: 472.5708; train_optim_loss: 472.5708; val_kl_reg_loss: 0.5650; val_edge_recon_loss: 0.9508; val_gene_expr_recon_loss: 489.1116; val_group_lasso_reg_loss: 0.0000; val_global_loss: 490.6274; val_optim_loss: 490.6274
#
# Model training finished after 4 min 45 sec.
# Using best model state, which was in epoch 20.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.7858
# Val AUPRC score: 0.7001
# Val best accuracy score: 0.6679
# Val best F1 score: 0.7507
# Val MSE score: 0.8445
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 4.78.
# Number of total edges: 42526.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 16025
# Number of validation nodes: 1781
# Number of training edges: 38274
# Number of validation edges: 4252
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.7019; val_auprc_score: 0.6265; val_best_acc_score: 0.6386; val_best_f1_score: 0.7346; train_kl_reg_loss: 0.2660; train_edge_recon_loss: 5.1518; train_gene_expr_recon_loss: 543.5228; train_group_lasso_reg_loss: 0.0000; train_global_loss: 548.9407; train_optim_loss: 548.9407; val_kl_reg_loss: 0.3356; val_edge_recon_loss: 4.5202; val_gene_expr_recon_loss: 528.8871; val_group_lasso_reg_loss: 0.0000; val_global_loss: 533.7428; val_optim_loss: 533.7428
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.7400; val_auprc_score: 0.6579; val_best_acc_score: 0.6603; val_best_f1_score: 0.7464; train_kl_reg_loss: 0.3902; train_edge_recon_loss: 3.7496; train_gene_expr_recon_loss: 516.5903; train_group_lasso_reg_loss: 0.0000; train_global_loss: 520.7301; train_optim_loss: 520.7301; val_kl_reg_loss: 0.4078; val_edge_recon_loss: 3.3334; val_gene_expr_recon_loss: 515.4403; val_group_lasso_reg_loss: 0.0000; val_global_loss: 519.1815; val_optim_loss: 519.1815
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.7439; val_auprc_score: 0.6613; val_best_acc_score: 0.6475; val_best_f1_score: 0.7393; train_kl_reg_loss: 0.4524; train_edge_recon_loss: 3.1400; train_gene_expr_recon_loss: 505.8015; train_group_lasso_reg_loss: 0.0000; train_global_loss: 509.3940; train_optim_loss: 509.3940; val_kl_reg_loss: 0.4421; val_edge_recon_loss: 2.8455; val_gene_expr_recon_loss: 506.6305; val_group_lasso_reg_loss: 0.0000; val_global_loss: 509.9181; val_optim_loss: 509.9181
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.7419; val_auprc_score: 0.6595; val_best_acc_score: 0.6403; val_best_f1_score: 0.7354; train_kl_reg_loss: 0.4846; train_edge_recon_loss: 2.7589; train_gene_expr_recon_loss: 498.1442; train_group_lasso_reg_loss: 0.0000; train_global_loss: 501.3877; train_optim_loss: 501.3877; val_kl_reg_loss: 0.4639; val_edge_recon_loss: 2.6873; val_gene_expr_recon_loss: 503.5262; val_group_lasso_reg_loss: 0.0000; val_global_loss: 506.6775; val_optim_loss: 506.6775
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.7555; val_auprc_score: 0.6716; val_best_acc_score: 0.6379; val_best_f1_score: 0.7342; train_kl_reg_loss: 0.5132; train_edge_recon_loss: 2.4856; train_gene_expr_recon_loss: 492.7991; train_group_lasso_reg_loss: 0.0000; train_global_loss: 495.7979; train_optim_loss: 495.7979; val_kl_reg_loss: 0.5045; val_edge_recon_loss: 2.4087; val_gene_expr_recon_loss: 497.6233; val_group_lasso_reg_loss: 0.0000; val_global_loss: 500.5365; val_optim_loss: 500.5365
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.7712; val_auprc_score: 0.6860; val_best_acc_score: 0.6465; val_best_f1_score: 0.7388; train_kl_reg_loss: 0.5317; train_edge_recon_loss: 2.2808; train_gene_expr_recon_loss: 489.2277; train_group_lasso_reg_loss: 0.0000; train_global_loss: 492.0401; train_optim_loss: 492.0401; val_kl_reg_loss: 0.4951; val_edge_recon_loss: 2.1349; val_gene_expr_recon_loss: 495.7025; val_group_lasso_reg_loss: 0.0000; val_global_loss: 498.3325; val_optim_loss: 498.3325
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.7725; val_auprc_score: 0.6872; val_best_acc_score: 0.6511; val_best_f1_score: 0.7413; train_kl_reg_loss: 0.5444; train_edge_recon_loss: 2.1716; train_gene_expr_recon_loss: 486.5688; train_group_lasso_reg_loss: 0.0000; train_global_loss: 489.2847; train_optim_loss: 489.2847; val_kl_reg_loss: 0.5289; val_edge_recon_loss: 2.0168; val_gene_expr_recon_loss: 494.8454; val_group_lasso_reg_loss: 0.0000; val_global_loss: 497.3911; val_optim_loss: 497.3911
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.7857; val_auprc_score: 0.7000; val_best_acc_score: 0.6472; val_best_f1_score: 0.7392; train_kl_reg_loss: 0.5582; train_edge_recon_loss: 2.0120; train_gene_expr_recon_loss: 484.3689; train_group_lasso_reg_loss: 0.0000; train_global_loss: 486.9390; train_optim_loss: 486.9390; val_kl_reg_loss: 0.5307; val_edge_recon_loss: 1.9580; val_gene_expr_recon_loss: 494.2657; val_group_lasso_reg_loss: 0.0000; val_global_loss: 496.7543; val_optim_loss: 496.7543
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.7814; val_auprc_score: 0.6958; val_best_acc_score: 0.6428; val_best_f1_score: 0.7368; train_kl_reg_loss: 0.5697; train_edge_recon_loss: 1.9388; train_gene_expr_recon_loss: 482.1149; train_group_lasso_reg_loss: 0.0000; train_global_loss: 484.6234; train_optim_loss: 484.6234; val_kl_reg_loss: 0.5514; val_edge_recon_loss: 1.9199; val_gene_expr_recon_loss: 492.3505; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.8219; val_optim_loss: 494.8219
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.8134; val_auprc_score: 0.7282; val_best_acc_score: 0.6718; val_best_f1_score: 0.7529; train_kl_reg_loss: 0.5697; train_edge_recon_loss: 1.8435; train_gene_expr_recon_loss: 481.0098; train_group_lasso_reg_loss: 0.0000; train_global_loss: 483.4230; train_optim_loss: 483.4230; val_kl_reg_loss: 0.5397; val_edge_recon_loss: 1.6325; val_gene_expr_recon_loss: 492.0502; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.2224; val_optim_loss: 494.2224
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.8141; val_auprc_score: 0.7290; val_best_acc_score: 0.6723; val_best_f1_score: 0.7532; train_kl_reg_loss: 0.5767; train_edge_recon_loss: 1.7616; train_gene_expr_recon_loss: 479.9768; train_group_lasso_reg_loss: 0.0000; train_global_loss: 482.3151; train_optim_loss: 482.3151; val_kl_reg_loss: 0.5519; val_edge_recon_loss: 1.6370; val_gene_expr_recon_loss: 493.1256; val_group_lasso_reg_loss: 0.0000; val_global_loss: 495.3145; val_optim_loss: 495.3145
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.8127; val_auprc_score: 0.7275; val_best_acc_score: 0.6496; val_best_f1_score: 0.7405; train_kl_reg_loss: 0.5797; train_edge_recon_loss: 1.7136; train_gene_expr_recon_loss: 478.8244; train_group_lasso_reg_loss: 0.0000; train_global_loss: 481.1177; train_optim_loss: 481.1177; val_kl_reg_loss: 0.5456; val_edge_recon_loss: 1.6739; val_gene_expr_recon_loss: 492.3486; val_group_lasso_reg_loss: 0.0000; val_global_loss: 494.5681; val_optim_loss: 494.5681
# ...
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 1e-05.
#
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.8935; val_auprc_score: 0.8244; val_best_acc_score: 0.7137; val_best_f1_score: 0.7775; train_kl_reg_loss: 0.3367; train_edge_recon_loss: 1.1098; train_gene_expr_recon_loss: 445.2326; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.6791; train_optim_loss: 446.6791; val_kl_reg_loss: 0.3429; val_edge_recon_loss: 1.0788; val_gene_expr_recon_loss: 456.6922; val_group_lasso_reg_loss: 0.0000; val_global_loss: 458.1139; val_optim_loss: 458.1139
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.8890; val_auprc_score: 0.8183; val_best_acc_score: 0.7216; val_best_f1_score: 0.7822; train_kl_reg_loss: 0.3370; train_edge_recon_loss: 1.0966; train_gene_expr_recon_loss: 445.0442; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.4779; train_optim_loss: 446.4779; val_kl_reg_loss: 0.3430; val_edge_recon_loss: 1.0824; val_gene_expr_recon_loss: 456.4550; val_group_lasso_reg_loss: 0.0000; val_global_loss: 457.8804; val_optim_loss: 457.8804
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.8908; val_auprc_score: 0.8208; val_best_acc_score: 0.7171; val_best_f1_score: 0.7795; train_kl_reg_loss: 0.3365; train_edge_recon_loss: 1.1033; train_gene_expr_recon_loss: 445.1665; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.6063; train_optim_loss: 446.6063; val_kl_reg_loss: 0.3407; val_edge_recon_loss: 1.0964; val_gene_expr_recon_loss: 456.9860; val_group_lasso_reg_loss: 0.0000; val_global_loss: 458.4231; val_optim_loss: 458.4231
#
# Model training finished after 12 min 32 sec.
# Using best model state, which was in epoch 19.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.8902
# Val AUPRC score: 0.8200
# Val best accuracy score: 0.7168
# Val best F1 score: 0.7793
# Val MSE score: 0.7498
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 9.08.
# Number of total edges: 80820.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 16025
# Number of validation nodes: 1781
# Number of training edges: 72738
# Number of validation edges: 8082
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.8020; val_auprc_score: 0.7163; val_best_acc_score: 0.6939; val_best_f1_score: 0.7656; train_kl_reg_loss: 0.1588; train_edge_recon_loss: 5.1329; train_gene_expr_recon_loss: 500.7589; train_group_lasso_reg_loss: 0.0000; train_global_loss: 506.0506; train_optim_loss: 506.0506; val_kl_reg_loss: 0.2239; val_edge_recon_loss: 3.8871; val_gene_expr_recon_loss: 479.9112; val_group_lasso_reg_loss: 0.0000; val_global_loss: 484.0223; val_optim_loss: 484.0223
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.8281; val_auprc_score: 0.7441; val_best_acc_score: 0.6958; val_best_f1_score: 0.7668; train_kl_reg_loss: 0.2439; train_edge_recon_loss: 3.3758; train_gene_expr_recon_loss: 475.0702; train_group_lasso_reg_loss: 0.0000; train_global_loss: 478.6900; train_optim_loss: 478.6900; val_kl_reg_loss: 0.2668; val_edge_recon_loss: 2.9786; val_gene_expr_recon_loss: 468.6079; val_group_lasso_reg_loss: 0.0000; val_global_loss: 471.8532; val_optim_loss: 471.8532
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.8485; val_auprc_score: 0.7674; val_best_acc_score: 0.6917; val_best_f1_score: 0.7643; train_kl_reg_loss: 0.2780; train_edge_recon_loss: 2.7667; train_gene_expr_recon_loss: 466.9614; train_group_lasso_reg_loss: 0.0000; train_global_loss: 470.0061; train_optim_loss: 470.0061; val_kl_reg_loss: 0.2883; val_edge_recon_loss: 2.4637; val_gene_expr_recon_loss: 465.6743; val_group_lasso_reg_loss: 0.0000; val_global_loss: 468.4263; val_optim_loss: 468.4263
# Epoch 4/20 |████----------------| 20.0% val_auroc_score: 0.8585; val_auprc_score: 0.7794; val_best_acc_score: 0.6917; val_best_f1_score: 0.7643; train_kl_reg_loss: 0.3008; train_edge_recon_loss: 2.4298; train_gene_expr_recon_loss: 462.3721; train_group_lasso_reg_loss: 0.0000; train_global_loss: 465.1027; train_optim_loss: 465.1027; val_kl_reg_loss: 0.3192; val_edge_recon_loss: 2.3159; val_gene_expr_recon_loss: 462.2650; val_group_lasso_reg_loss: 0.0000; val_global_loss: 464.9002; val_optim_loss: 464.9002
# Epoch 5/20 |█████---------------| 25.0% val_auroc_score: 0.8728; val_auprc_score: 0.7972; val_best_acc_score: 0.6915; val_best_f1_score: 0.7642; train_kl_reg_loss: 0.3156; train_edge_recon_loss: 2.2138; train_gene_expr_recon_loss: 459.4316; train_group_lasso_reg_loss: 0.0000; train_global_loss: 461.9609; train_optim_loss: 461.9609; val_kl_reg_loss: 0.3276; val_edge_recon_loss: 2.0811; val_gene_expr_recon_loss: 462.8203; val_group_lasso_reg_loss: 0.0000; val_global_loss: 465.2290; val_optim_loss: 465.2290
# Epoch 6/20 |██████--------------| 30.0% val_auroc_score: 0.8756; val_auprc_score: 0.8008; val_best_acc_score: 0.6905; val_best_f1_score: 0.7637; train_kl_reg_loss: 0.3243; train_edge_recon_loss: 2.0279; train_gene_expr_recon_loss: 457.4725; train_group_lasso_reg_loss: 0.0000; train_global_loss: 459.8248; train_optim_loss: 459.8248; val_kl_reg_loss: 0.3365; val_edge_recon_loss: 2.0297; val_gene_expr_recon_loss: 462.0406; val_group_lasso_reg_loss: 0.0000; val_global_loss: 464.4068; val_optim_loss: 464.4068
# Epoch 7/20 |███████-------------| 35.0% val_auroc_score: 0.8963; val_auprc_score: 0.8282; val_best_acc_score: 0.7021; val_best_f1_score: 0.7705; train_kl_reg_loss: 0.3324; train_edge_recon_loss: 1.9247; train_gene_expr_recon_loss: 455.3987; train_group_lasso_reg_loss: 0.0000; train_global_loss: 457.6558; train_optim_loss: 457.6558; val_kl_reg_loss: 0.3391; val_edge_recon_loss: 1.8095; val_gene_expr_recon_loss: 460.0324; val_group_lasso_reg_loss: 0.0000; val_global_loss: 462.1810; val_optim_loss: 462.1810
# Epoch 8/20 |████████------------| 40.0% val_auroc_score: 0.8815; val_auprc_score: 0.8084; val_best_acc_score: 0.6943; val_best_f1_score: 0.7658; train_kl_reg_loss: 0.3376; train_edge_recon_loss: 1.8299; train_gene_expr_recon_loss: 454.3224; train_group_lasso_reg_loss: 0.0000; train_global_loss: 456.4899; train_optim_loss: 456.4899; val_kl_reg_loss: 0.3515; val_edge_recon_loss: 1.9023; val_gene_expr_recon_loss: 459.6914; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.9453; val_optim_loss: 461.9453
# Epoch 9/20 |█████████-----------| 45.0% val_auroc_score: 0.9076; val_auprc_score: 0.8440; val_best_acc_score: 0.7180; val_best_f1_score: 0.7800; train_kl_reg_loss: 0.3411; train_edge_recon_loss: 1.7683; train_gene_expr_recon_loss: 453.1829; train_group_lasso_reg_loss: 0.0000; train_global_loss: 455.2924; train_optim_loss: 455.2924; val_kl_reg_loss: 0.3440; val_edge_recon_loss: 1.6336; val_gene_expr_recon_loss: 460.4762; val_group_lasso_reg_loss: 0.0000; val_global_loss: 462.4537; val_optim_loss: 462.4537
# Epoch 10/20 |██████████----------| 50.0% val_auroc_score: 0.9162; val_auprc_score: 0.8565; val_best_acc_score: 0.7251; val_best_f1_score: 0.7844; train_kl_reg_loss: 0.3437; train_edge_recon_loss: 1.7068; train_gene_expr_recon_loss: 452.4036; train_group_lasso_reg_loss: 0.0000; train_global_loss: 454.4540; train_optim_loss: 454.4540; val_kl_reg_loss: 0.3521; val_edge_recon_loss: 1.5467; val_gene_expr_recon_loss: 459.4179; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.3167; val_optim_loss: 461.3167
# Epoch 11/20 |███████████---------| 55.0% val_auroc_score: 0.9097; val_auprc_score: 0.8470; val_best_acc_score: 0.7068; val_best_f1_score: 0.7732; train_kl_reg_loss: 0.3466; train_edge_recon_loss: 1.6457; train_gene_expr_recon_loss: 451.5096; train_group_lasso_reg_loss: 0.0000; train_global_loss: 453.5020; train_optim_loss: 453.5020; val_kl_reg_loss: 0.3473; val_edge_recon_loss: 1.6429; val_gene_expr_recon_loss: 459.8783; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.8684; val_optim_loss: 461.8684
# Epoch 12/20 |████████████--------| 60.0% val_auroc_score: 0.9150; val_auprc_score: 0.8548; val_best_acc_score: 0.7094; val_best_f1_score: 0.7748; train_kl_reg_loss: 0.3487; train_edge_recon_loss: 1.6115; train_gene_expr_recon_loss: 450.7895; train_group_lasso_reg_loss: 0.0000; train_global_loss: 452.7497; train_optim_loss: 452.7497; val_kl_reg_loss: 0.3662; val_edge_recon_loss: 1.5850; val_gene_expr_recon_loss: 459.2124; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.1636; val_optim_loss: 461.1636
# Epoch 13/20 |█████████████-------| 65.0% val_auroc_score: 0.9172; val_auprc_score: 0.8580; val_best_acc_score: 0.7063; val_best_f1_score: 0.7730; train_kl_reg_loss: 0.3510; train_edge_recon_loss: 1.5726; train_gene_expr_recon_loss: 450.2904; train_group_lasso_reg_loss: 0.0000; train_global_loss: 452.2140; train_optim_loss: 452.2140; val_kl_reg_loss: 0.3630; val_edge_recon_loss: 1.5835; val_gene_expr_recon_loss: 459.0268; val_group_lasso_reg_loss: 0.0000; val_global_loss: 460.9733; val_optim_loss: 460.9733
# Epoch 14/20 |██████████████------| 70.0% val_auroc_score: 0.9257; val_auprc_score: 0.8707; val_best_acc_score: 0.7337; val_best_f1_score: 0.7897; train_kl_reg_loss: 0.3522; train_edge_recon_loss: 1.5389; train_gene_expr_recon_loss: 449.6400; train_group_lasso_reg_loss: 0.0000; train_global_loss: 451.5311; train_optim_loss: 451.5311; val_kl_reg_loss: 0.3535; val_edge_recon_loss: 1.4793; val_gene_expr_recon_loss: 459.3141; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.1470; val_optim_loss: 461.1470
# Epoch 15/20 |███████████████-----| 75.0% val_auroc_score: 0.9300; val_auprc_score: 0.8773; val_best_acc_score: 0.7379; val_best_f1_score: 0.7923; train_kl_reg_loss: 0.3538; train_edge_recon_loss: 1.5268; train_gene_expr_recon_loss: 449.3505; train_group_lasso_reg_loss: 0.0000; train_global_loss: 451.2310; train_optim_loss: 451.2310; val_kl_reg_loss: 0.3664; val_edge_recon_loss: 1.4150; val_gene_expr_recon_loss: 460.2320; val_group_lasso_reg_loss: 0.0000; val_global_loss: 462.0135; val_optim_loss: 462.0135
# Epoch 16/20 |████████████████----| 80.0% val_auroc_score: 0.9233; val_auprc_score: 0.8669; val_best_acc_score: 0.7215; val_best_f1_score: 0.7822; train_kl_reg_loss: 0.3549; train_edge_recon_loss: 1.5061; train_gene_expr_recon_loss: 448.7046; train_group_lasso_reg_loss: 0.0000; train_global_loss: 450.5656; train_optim_loss: 450.5656; val_kl_reg_loss: 0.3669; val_edge_recon_loss: 1.4874; val_gene_expr_recon_loss: 459.7831; val_group_lasso_reg_loss: 0.0000; val_global_loss: 461.6374; val_optim_loss: 461.6374
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 3 epochs.
# New learning rate is 0.0001.
#
# Epoch 17/20 |█████████████████---| 85.0% val_auroc_score: 0.9379; val_auprc_score: 0.8895; val_best_acc_score: 0.7635; val_best_f1_score: 0.8087; train_kl_reg_loss: 0.3657; train_edge_recon_loss: 1.2970; train_gene_expr_recon_loss: 444.9712; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.6338; train_optim_loss: 446.6338; val_kl_reg_loss: 0.3703; val_edge_recon_loss: 1.2728; val_gene_expr_recon_loss: 457.9321; val_group_lasso_reg_loss: 0.0000; val_global_loss: 459.5752; val_optim_loss: 459.5752
# Epoch 18/20 |██████████████████--| 90.0% val_auroc_score: 0.9402; val_auprc_score: 0.8932; val_best_acc_score: 0.7582; val_best_f1_score: 0.8053; train_kl_reg_loss: 0.3577; train_edge_recon_loss: 1.2983; train_gene_expr_recon_loss: 445.0474; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.7033; train_optim_loss: 446.7033; val_kl_reg_loss: 0.3612; val_edge_recon_loss: 1.2779; val_gene_expr_recon_loss: 457.0681; val_group_lasso_reg_loss: 0.0000; val_global_loss: 458.7072; val_optim_loss: 458.7072
# Epoch 19/20 |███████████████████-| 95.0% val_auroc_score: 0.9394; val_auprc_score: 0.8919; val_best_acc_score: 0.7603; val_best_f1_score: 0.8067; train_kl_reg_loss: 0.3523; train_edge_recon_loss: 1.2872; train_gene_expr_recon_loss: 444.7402; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.3797; train_optim_loss: 446.3797; val_kl_reg_loss: 0.3589; val_edge_recon_loss: 1.2708; val_gene_expr_recon_loss: 456.9203; val_group_lasso_reg_loss: 0.0000; val_global_loss: 458.5499; val_optim_loss: 458.5499
# Epoch 20/20 |████████████████████| 100.0% val_auroc_score: 0.9370; val_auprc_score: 0.8882; val_best_acc_score: 0.7544; val_best_f1_score: 0.8028; train_kl_reg_loss: 0.3488; train_edge_recon_loss: 1.2936; train_gene_expr_recon_loss: 444.7700; train_group_lasso_reg_loss: 0.0000; train_global_loss: 446.4125; train_optim_loss: 446.4125; val_kl_reg_loss: 0.3546; val_edge_recon_loss: 1.3182; val_gene_expr_recon_loss: 457.4050; val_group_lasso_reg_loss: 0.0000; val_global_loss: 459.0778; val_optim_loss: 459.0778
#
# Model training finished after 12 min 31 sec.
# Using best model state, which was in epoch 19.
#
# --- MODEL EVALUATION ---
# Val AUROC score: 0.9393
# Val AUPRC score: 0.8917
# Val best accuracy score: 0.7609
# Val best F1 score: 0.8070
# Val MSE score: 0.7527
# --------------------
#
# --------------------
#
# --- SPATIAL CONNECTIVITY ---
# Average number of edges per node: 9.08.
# Number of total edges: 80820.
#
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, gene_expr_recon_dist: nb
# NODE LABEL METHOD -> one-hop-attention
# ACTIVE GP THRESHOLD RATIO -> 0.0
# GRAPH ENCODER -> n_input: 351, n_hidden: 489, n_latent: 489, n_addon_latent: 0, conv_layer: gcnconv, n_attention_heads: -, dropout_rate: 0.0
# DOT PRODUCT GRAPH DECODER -> dropout_rate: 0.0
# MASKED GENE EXPRESSION DECODER -> n_input: 489, n_addon_input: 0, n_output: 702
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 16025
# Number of validation nodes: 1781
# Number of training edges: 72738
# Number of validation edges: 8082
#
# --- MODEL TRAINING ---
# Epoch 1/20 |█-------------------| 5.0% val_auroc_score: 0.8485; val_auprc_score: 0.7675; val_best_acc_score: 0.7229; val_best_f1_score: 0.7830; train_kl_reg_loss: 0.1501; train_edge_recon_loss: 5.7005; train_gene_expr_recon_loss: 502.6887; train_group_lasso_reg_loss: 0.0000; train_global_loss: 508.5394; train_optim_loss: 508.5394; val_kl_reg_loss: 0.2119; val_edge_recon_loss: 4.3367; val_gene_expr_recon_loss: 481.1162; val_group_lasso_reg_loss: 0.0000; val_global_loss: 485.6648; val_optim_loss: 485.6648
# Epoch 2/20 |██------------------| 10.0% val_auroc_score: 0.8740; val_auprc_score: 0.7988; val_best_acc_score: 0.7345; val_best_f1_score: 0.7902; train_kl_reg_loss: 0.2401; train_edge_recon_loss: 3.8294; train_gene_expr_recon_loss: 476.0616; train_group_lasso_reg_loss: 0.0000; train_global_loss: 480.1311; train_optim_loss: 480.1311; val_kl_reg_loss: 0.2656; val_edge_recon_loss: 3.3499; val_gene_expr_recon_loss: 469.4727; val_group_lasso_reg_loss: 0.0000; val_global_loss: 473.0883; val_optim_loss: 473.0883
# Epoch 3/20 |███-----------------| 15.0% val_auroc_score: 0.8993; val_auprc_score: 0.8323; val_best_acc_score: 0.7296; val_best_f1_score: 0.7872; train_kl_reg_loss: 0.2791; train_edge_recon_loss: 3.1672; train_gene_expr_recon_loss: 467.7206; train_group_lasso_reg_loss: 0.0000; train_global_loss: 471.1669; train_optim_loss: 471.1669; val_kl_reg_loss: 0.2867; val_edge_recon_loss: 2.7480; val_gene_expr_recon_loss: 466.4394; val_group_lasso_reg_loss: 0.0000; val_global_loss: 469.4741; val_optim_loss: 469.4741

# %%
hyperparam_option_dict["radius"] = [0.03979, 0.05279, 0.06450, 0.07458, 0.08348]
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0, 0.1, 0.2, 0.33, 0.5]

model = run_hyperparam_tuning(dataset="seqfish_mouse_organogenesis_embryo1",
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=1,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              save_model=False)

# %%
hyperparam_option_dict["radius"] = [0.04019, 0.05293, 0.06450, 0.07460, 0.08349]
hyperparam_option_dict["lambda_edge_recon"] = [0, 0.1, 0.2, 0.33, 0.5, 1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [1.]

model = run_hyperparam_tuning(dataset="seqfish_mouse_organogenesis_embryo2",
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=2,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              save_model=False)

# %%
hyperparam_option_dict["radius"] = [0.04019, 0.05293, 0.06450, 0.07460, 0.08349]
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0, 0.1, 0.2, 0.33, 0.5]

model = run_hyperparam_tuning(dataset="seqfish_mouse_organogenesis_embryo2",
                              hyperparam_option_dict=hyperparam_option_dict,
                              n_iters=2,
                              experiment_name=experiment_name,
                              gp_mask="combined_priors",
                              save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

def get_loss_weights(row):  
    return f"lambda_edge_recon_{row['lambda_edge_recon_']}_+_lambda_gene_expr_recon_{row['lambda_gene_expr_recon_']}"
df["loss_weights"] = df.apply(lambda row: get_loss_weights(row), axis=1)

# %%
plot_hyperparam_benchmarking_metrics(fig_title="Loss Weights Benchmarking Evaluation Metrics",
                                     df=df,
                                     y_col_name="loss_weights",
                                     plot_ratio_active_gps=False,
                                     file_name="loss_weights_hyperparam_tuning_metrics.png",
                                     save_fig=True)

# %% [markdown]
# ### 2.2. Benchmark Node Label Method

# %% [markdown]
# - Different node label methods are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per node label method.

# %%
experiment_name = "benchmark_node_label_method"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention", "one-hop-norm", "one-hop-sum"]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Node Label Method Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="node_label_method_",
                  plot_ratio_active_gps=False,
                  file_name="node_label_method_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.3. Benchmark Gene Expression Reconstruction Distribution

# %% [markdown]
# - Different gene expression reconstruction distributions are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per gene expression reconstruction distribution.

# %%
experiment_name = "benchmark_gene_expr_recon_dist"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Gene Expression Reconstruction Distribution Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="gene_expr_recon_dist_",
                  plot_ratio_active_gps=False,
                  file_name="gene_expr_recon_dist_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.4. Benchmark Encoder Layer Architecture

# %% [markdown]
# - Different encoder layer architectures are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per encoder layer architecture.

# %%
experiment_name = "benchmark_encoder_layer_arch"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.2]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb"]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = [64]

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["conv_layer_encoder"] = ["gatv2conv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [1, 2, 4, 8]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

def get_encoder_layer_arch(row):  
    return f"conv_layer_encoder_{row['conv_layer_encoder_']}_+_encoder_n_attention_heads_{row['encoder_n_attention_heads_']}"
df["encoder_layer_arch"] = df.apply(lambda row: get_encoder_layer_arch(row), axis=1)

# %%
plot_hyperparam_benchmarking_metrics(fig_title="Encoder Layer Architecture Benchmarking Evaluation Metrics",
                                     df=df,
                                     y_col_name="encoder_layer_arch",
                                     plot_ratio_active_gps=False,
                                     file_name="encoder_layer_arch_benchmarking_eval_metrics.png",
                                     save_fig=True)

# %% [markdown]
# ### 2.5. Benchmark Encoder Hidden Layer Size

# %% [markdown]
# - Different sizes of the encoder hidden layer are tested.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per encoder hidden layer size.

# %%
experiment_name = "benchmark_encoder_n_hidden"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0.]
hyperparam_option_dict["lambda_group_lasso"] = [0]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None, 0.5, 1., 2.]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# %%
plot_eval_metrics(fig_title="Encoder Hidden Layer Size Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="encoder_n_hidden_",
                  plot_ratio_active_gps=False,
                  file_name="encoder_n_hidden_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ### 2.6. Benchmark Active Gene Programs

# %% [markdown]
# - Different combinations of the active gene program threshold ratio and the group lasso regularization weighting hyperparameter are tested. Both these hyperparameters contribute to a reduction of active gene programs.
# - Average number of neighbors is varied. The radius is set in order to get an average number of neighbors of ```2```, ```4```, ```8```, ```16``` and ```32``` with 2 iterations respectively, resulting in a total of 10 runs per active gp hyperparameter combination.

# %%
experiment_name = "benchmark_active_gps"

# Set hyperparameters that are not varied as part of the experiment
hyperparam_option_dict = {}
hyperparam_option_dict["lambda_edge_recon"] = [1.]
hyperparam_option_dict["lambda_gene_expr_recon"] = [0.33]
hyperparam_option_dict["node_label_method"] = ["one-hop-attention"]
hyperparam_option_dict["gene_expr_recon_dist"] = ["nb", "zinb"]
hyperparam_option_dict["conv_layer_encoder"] = ["gcnconv"]
hyperparam_option_dict["encoder_n_attention_heads"] = [0]
hyperparam_option_dict["n_hidden_encoder_divisor"] = [None]

hyperparam_option_dict["n_epochs"] = [20]
hyperparam_option_dict["n_epochs_all_gps"] = [10]
hyperparam_option_dict["lr"] = [0.001]
hyperparam_option_dict["batch_size"] = 64

# %%
hyperparam_option_dict["radius"] = [0.03094, 0.03875, 0.05102, 0.07200, 0.10241]
hyperparam_option_dict["active_gp_thresh_ratio"] = [0., 0.01, 0.03, 0.1, 0.3]
hyperparam_option_dict["lambda_group_lasso"] = [0, 0.01, 0.03, 0.1, 0.3]

model = run_hyperparam_benchmarking(dataset=dataset,
                                    hyperparam_option_dict=hyperparam_option_dict,
                                    n_iters=2,
                                    experiment_name=experiment_name,
                                    gp_mask="combined_priors",
                                    save_model=False)

# %%
runs = mlflow.search_runs(experiment_names=[experiment_name],
                          output_format="list")

data = []
for run in runs:
    data.append({**run.data.metrics, **run.data.params})
df = pd.DataFrame.from_dict(data)

# Get active gene program ratio
def get_ratio_active_gps(row):
    return row["n_active_gps"] / (int(row["n_nonaddon_gps_"]) + int(row["n_addon_gps_"]))
df["ratio_active_gps"] = df.apply(lambda row: get_ratio_active_gps(row), axis=1)

# Get combination of active gene program threshold and lambda group lasso
def get_active_gp_thresh_lambda_group_lasso(row):
    return f"active_gp_thresh_{row['active_gp_thresh_ratio_']}_+_lambda_group_lasso_{row['lambda_group_lasso_']}"
df["active_gp_thresh_lambda_group_lasso"] = df.apply(lambda row: get_active_gp_thresh_lambda_group_lasso(row), axis=1)

# %%
plot_eval_metrics(fig_title="Active GP Benchmarking Evaluation Metrics",
                  df=df,
                  y_col_name="active_gp_thresh_lambda_group_lasso",
                  plot_ratio_active_gps=True,
                  file_name="active_gp_benchmarking_eval_metrics.png",
                  save_fig=True)

# %% [markdown]
# ## 3. Method Benchmarking Experiments
