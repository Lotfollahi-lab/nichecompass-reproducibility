# %% [markdown]
# # Method Benchmarking

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of Computational Biology (ICB), Talavera-López Lab
# - **Date of Creation:** 06.01.2023
# - **Date of Last Modification:** 06.01.2023

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import sys
sys.path.append("../../autotalker")

# %%
from datetime import datetime

import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scib

from autotalker.benchmarking import compute_benchmarking_metrics

# %% [markdown]
# ### 1.2 Define Parameters

# %%
dataset = "squidpy_seqfish_mouse_organogenesis"
cell_type_key = "celltype_mapped_refined"
latent_key = "deeplinc_latent"
active_gp_names_key = "deeplinc_active_gp_names"
spatial_key = "spatial"
leiden_resolution = 0.3
random_seed = 0

# %% [markdown]
# ### 1.3 Run Notebook Setup

# %%
sc.set_figure_params(figsize=(6, 6))

# %%
# Get time of notebook execution for timestamping saved artifacts
now = datetime.now()
current_timestamp = now.strftime("%d%m%Y_%H%M%S")

# %% [markdown]
# ### 1.4 Configure Paths and Directories

# %%
data_folder_path = "../datasets/srt_data/gold/"
figure_folder_path = f"../figures/{dataset}/benchmarking/"
benchmark_data_folder_path = "../datasets/benchmark_data/"

# %% [markdown]
# ## 2. Data

# %%
# Load Data
adata = sc.read_h5ad(data_folder_path + f"{dataset}_deeplinc.h5ad")

# %%
benchmarking_dict_list = []
for run_number, n_neighbors in zip(np.arange(1, 11), [2, 2, 4, 4, 8, 8, 16, 16, 32, 32]):
    benchmarking_dict = compute_benchmarking_metrics(adata=adata,
                                                     spatial_model=True,
                                                     latent_key=latent_key + f"_run{run_number}",
                                                     active_gp_names_key=active_gp_names_key,
                                                     cell_type_key=cell_type_key,
                                                     spatial_key="spatial",
                                                     spatial_knng_key = f"deeplinc_spatial_{n_neighbors}nng",
                                                     latent_knng_key = f"deeplinc_latent_{n_neighbors}nng",
                                                     n_neighbors=n_neighbors)
    benchmarking_dict["model"] = "deeplinc"
    benchmarking_dict["run"] = run_number
    benchmarking_dict_list.append(benchmarking_dict)
df = pd.DataFrame(benchmarking_dict_list)

# %%
mean_df = df.groupby("model").mean()

# %%
mean_df
# Out:
#                  gcd    mlnmi         cad   arclisi    germse       cca  run
# model
# deeplinc  477.625874  0.65982  181.090176  0.090984  1.009998  0.790096  5.5

# %%
mean_df.columns
# Out:
# Index(['gcd', 'mlnmi', 'cad', 'arclisi', 'germse', 'cca', 'run'], dtype='object')

# %%
columns = ["gcd", "mlnmi", "cad", "arclisi", "germse", "cca"]

# %%
fig, axs = plt.subplots(1, len(columns), figsize=(4*len(columns), 4))

# Plot each column in a separate subplot
for ax, col in zip(axs, columns):
    sns.barplot(data=mean_df, x=mean_df.index, y=col, hue="run", ax=ax)
plt.suptitle("Method Benchmarking Metrics")
plt.subplots_adjust(wspace=0.5, top=0.9)
plt.show()

# %% [markdown]
# ## scib Metrics

# %%
scib.me.clisi_graph(adata, label_key=cell_type_key, type_="embed", use_rep="deeplinc_latent_run1")
# Out:
# 0.8931737894511032

# %%
scib.me.silhouette(adata, label_key=cell_type_key, embed="deeplinc_latent_run1")
# Out:
# 0.4881663015112281

# %%
sc.pp.neighbors(adata, use_rep="deeplinc_latent_run1")
scib.me.cluster_optimal_resolution(adata, cluster_key="cluster", label_key=cell_type_key)
scib.me.nmi(adata, cluster_key="cluster", label_key=cell_type_key)
# Out:
# resolution: 0.1, nmi: 0.1460711389323943
# resolution: 0.2, nmi: 0.2788425777549914
# resolution: 0.3, nmi: 0.3624194426537873
# resolution: 0.4, nmi: 0.3960541259384599
# resolution: 0.5, nmi: 0.4103523837687169
# resolution: 0.6, nmi: 0.4190425357060047
# resolution: 0.7, nmi: 0.446932847437658
# resolution: 0.8, nmi: 0.44784439847684887
# resolution: 0.9, nmi: 0.4466037140793616
# resolution: 1.0, nmi: 0.4436325196525985
# resolution: 1.1, nmi: 0.4424248074015207
# resolution: 1.2, nmi: 0.45169442006830074
# resolution: 1.3, nmi: 0.43857815852884163
# resolution: 1.4, nmi: 0.4374476529339145
# resolution: 1.5, nmi: 0.4307404064913363
# resolution: 1.6, nmi: 0.4326218175112338
# resolution: 1.7, nmi: 0.42924194380211567
# resolution: 1.8, nmi: 0.42646650062098374
# resolution: 1.9, nmi: 0.4228323581985222
# resolution: 2.0, nmi: 0.4221252518692213
# optimised clustering against celltype_mapped_refined
# optimal cluster resolution: 1.2
# optimal score: 0.45169442006830074
# 0.45169442006830074

# %%
# embedding output
scib.me.isolated_labels_asw(
    adata, batch_key="sample", label_key=cell_type_key, embed="deeplinc_latent_run1"
)
# Out:
# isolated labels: no more than 1 batches per label
# Allantois: 0.5141967898234725
# Anterior somitic tissues: 0.48902864288538694
# Cardiomyocytes: 0.5521743632853031
# Cranial mesoderm: 0.5366314612329006
# Definitive endoderm: 0.5164308380335569
# Dermomyotome: 0.5022071169223636
# Endothelium: 0.5276878029108047
# Erythroid: 0.4904935248196125
# Forebrain/Midbrain/Hindbrain: 0.49055894929915667
# Gut tube: 0.5230415537953377
# Haematoendothelial progenitors: 0.5051924935542047
# Intermediate mesoderm: 0.4729359969496727
# Lateral plate mesoderm: 0.5134807536378503
# Low quality: 0.4709640461951494
# Mixed mesenchymal mesoderm: 0.5493774339556694
# Neural crest: 0.5050619710236788
# NMP: 0.47356842644512653
# Presomitic mesoderm: 0.5842803940176964
# Sclerotome: 0.49069899041205645
# Spinal cord: 0.4737453982234001
# Splanchnic mesoderm: 0.5215937551110983
# Surface ectoderm: 0.522842900827527
# 0.5102815274255011

# %%
sc.pp.neighbors(adata, use_rep="deeplinc_latent_run1")
scib.me.cluster_optimal_resolution(adata, cluster_key="cluster", label_key=cell_type_key)
scib.me.ari(adata, cluster_key="cluster", label_key=cell_type_key)
# Out:
# WARNING: cluster key cluster already exists in adata.obs and will be overwritten because force=True
# resolution: 0.1, nmi: 0.1460711389323943
# resolution: 0.2, nmi: 0.2788425777549914
# resolution: 0.3, nmi: 0.3624194426537873
# resolution: 0.4, nmi: 0.3960541259384599
# resolution: 0.5, nmi: 0.4103523837687169
# resolution: 0.6, nmi: 0.4190425357060047
# resolution: 0.7, nmi: 0.446932847437658
# resolution: 0.8, nmi: 0.44784439847684887
# resolution: 0.9, nmi: 0.4466037140793616
# resolution: 1.0, nmi: 0.4436325196525985
# resolution: 1.1, nmi: 0.4424248074015207
# resolution: 1.2, nmi: 0.45169442006830074
# resolution: 1.3, nmi: 0.43857815852884163
# resolution: 1.4, nmi: 0.4374476529339145
# resolution: 1.5, nmi: 0.4307404064913363
# resolution: 1.6, nmi: 0.4326218175112338
