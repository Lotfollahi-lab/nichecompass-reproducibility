# %% [markdown]
# # Ablation

# %% [markdown]
# - **Creator**: Sebastian Birk (<sebastian.birk@helmholtz-munich.de>).
# - **Affiliation:** Helmholtz Munich, Institute of Computational Biology (ICB), Talavera-López Lab
# - **Date of Creation:** 06.01.2023
# - **Date of Last Modification:** 30.06.2023

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Import Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../../utils")

# %%
import os
import warnings
from datetime import datetime

import mlflow
import numpy as np
import pandas as pd
import pickle
import plottable
import scanpy as sc
import scib


from nichecompass.benchmarking import compute_benchmarking_metrics
from nichecompass.models import NicheCompass
from nichecompass.utils import (add_gps_from_gp_dict_to_adata,
                                create_new_color_dict,
                                extract_gp_dict_from_mebocost_es_interactions,
                                extract_gp_dict_from_nichenet_lrt_interactions,
                                extract_gp_dict_from_omnipath_lr_interactions,
                                filter_and_combine_gp_dict_gps)

from ablation_utils import *
# Out:
# /home/aih/sebastian.birk/.local/lib/python3.9/site-packages/lightning_fabric/__init__.py:29: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning_fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__("pkg_resources").declare_namespace(__name__)
# /home/aih/sebastian.birk/.local/lib/python3.9/site-packages/pytorch_lightning/__init__.py:45: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('pytorch_lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__("pkg_resources").declare_namespace(__name__)
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/bokeh/core/property/primitive.py:37: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   bokeh_bool_types += (np.bool8,)
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/umap/__init__.py:9: ImportWarning: Tensorflow not installed; ParametricUMAP will be unavailable
#   warn(

# %% [markdown]
# ### 1.2 Define Parameters

# %%
latent_key = "nichecompass_latent"
spatial_key = "spatial"
latent_knng_key = "nichecompass_latent_knng"
spatial_knng_key = "spatial_knng"
gp_names_key = "nichecompass_gp_names"

# %% [markdown]
# ### 1.4 Run Notebook Setup

# %%
sc.set_figure_params(figsize=(6, 6))
# Out:
# /home/aih/sebastian.birk/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/scanpy/_settings.py:447: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   IPython.display.set_matplotlib_formats(*ipython_format)

# %%
# Ignore future warnings and user warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=UserWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)

# %%
# Get time of notebook execution for timestamping saved artifacts
now = datetime.now()
current_timestamp = now.strftime("%d%m%Y_%H%M%S")

# %%
# Set mlflow tracking server (run it on the defined port)
mlflow.set_tracking_uri("http://localhost:8889")

# %% [markdown]
# ### 1.5 Configure Paths and Directories

# %%
artifact_folder_path = f"../../artifacts"
miscellaneous_folder_path = f"{artifact_folder_path}/miscellaneous"

# %% [markdown]
# ## 2. Ablation

# %% [markdown]
# ### 2.1 Loss Weights (Edge Reconstruction & Gene Expression Reconstruction)

# %% [markdown]
# - Different combinations of the edge reconstruction loss and gene expression reconstruction loss weighting hyperparameters are tested.
# - Number of neighbors of the spatial neighborhood graph is varied between ```4```, ```8```, ```12```, and ```16``` and for each dataset and 'n_neighbors', one run is performed with a fully connected gene program mask and one with a NicheCompass default GP mask, resulting in a total of 8 runs per loss weight combination.

# %%
ablation_task = "loss_weights"
datasets = ["xenium_human_breast_cancer", "starmap_plus_mouse_cns"]
cell_type_keys = ["cell_states", "Main_molecular_cell_type"]
condition_keys = [None, None]
experiment_ids = [3, 4]

# %%
# Retrieve metrics and params of ablation runs from mlflow and store in summary df
summary_df = pd.DataFrame()
for dataset, experiment_id in zip(datasets, experiment_ids):
    runs_info = mlflow.list_run_infos(experiment_id)
    for run_info in runs_info:
        run = mlflow.get_run(run_info.run_uuid)
        if run.info.status == "RUNNING":
            continue
        run_dict = {"dataset": dataset}
        run_dict["timestamp"] = run.data.params["timestamp"]
        run_dict["val_auroc_score"] = run.data.metrics.get("val_auroc_score", np.nan)
        run_dict["val_gene_expr_mse_score"] = run.data.metrics.get("val_gene_expr_mse_score", np.nan)
        run_dict["lambda_edge_recon_"] = run.data.params["lambda_edge_recon_"]
        run_dict["lambda_gene_expr_recon_"] = run.data.params["lambda_gene_expr_recon_"]
        run_dict["n_neighbors"] = run.data.params["n_neighbors"]
        run_dict["nichenet_keep_target_genes_ratio"] = run.data.params["nichenet_keep_target_genes_ratio"]
        run_dict["add_fc_gps_instead_of_gp_dict_gps"] = run.data.params["add_fc_gps_instead_of_gp_dict_gps"]
        run_df = pd.DataFrame(run_dict, index=[0])
        summary_df = pd.concat([summary_df, run_df], ignore_index=True)
summary_df["loss_weights"] = summary_df.apply(lambda row: get_loss_weights(row), axis=1)

for dataset in datasets:
    summary_df[summary_df["dataset"] == dataset].to_csv(f"{miscellaneous_folder_path}/mlflow_summary_{ablation_task}_ablation_{dataset}.csv")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=4, connect=5, read=4, redirect=5, status=5)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /api/2.0/mlflow/runs/search

# %%
summary_df.groupby("nichenet_keep_target_genes_ratio").mean()
# Out:
#                                   val_auroc_score  val_gene_expr_mse_score
# nichenet_keep_target_genes_ratio
# 0.01                                     0.934910                 1.767176
# 0.1                                      0.941705                 1.760437
# 1.0                                      0.936999                 1.816169

# %%
summary_df[(summary_df["dataset"] == "starmap_plus_mouse_cns") & (summary_df["nichenet_keep_target_genes_ratio"] == "0.1")].sort_values(["lambda_edge_recon_", "lambda_gene_expr_recon_"])
# Out:
#                     dataset             timestamp  val_auroc_score  \
# 212  starmap_plus_mouse_cns     01072023_143216_3         0.524029
# 213  starmap_plus_mouse_cns     01072023_142146_2         0.528775
# 214  starmap_plus_mouse_cns     01072023_141752_1         0.550148
# 148  starmap_plus_mouse_cns  03072023_135013_1003         0.994157
# 149  starmap_plus_mouse_cns  03072023_132805_1002         0.993887
# 150  starmap_plus_mouse_cns  03072023_131455_1001         0.991201
# 151  starmap_plus_mouse_cns  03072023_131347_1000         0.969641
# 144  starmap_plus_mouse_cns  03072023_171838_1007         0.996494
# 145  starmap_plus_mouse_cns  03072023_171838_1006         0.996093
# 146  starmap_plus_mouse_cns  03072023_141549_1005         0.991448
# 147  starmap_plus_mouse_cns  03072023_141504_1004         0.948201
# 170  starmap_plus_mouse_cns  02072023_161452_1003         0.996176
# 171  starmap_plus_mouse_cns  02072023_161351_1002         0.990963
# 172  starmap_plus_mouse_cns  02072023_161102_1001         0.988490
# 173  starmap_plus_mouse_cns  02072023_155422_1000         0.981897
# 166  starmap_plus_mouse_cns  02072023_164304_1007         0.998029
# 167  starmap_plus_mouse_cns  02072023_163503_1006         0.997750
# 168  starmap_plus_mouse_cns  02072023_162554_1005         0.996213
# 169  starmap_plus_mouse_cns  02072023_162204_1004         0.988348
# 162  starmap_plus_mouse_cns  02072023_173407_1011         0.997515
# 163  starmap_plus_mouse_cns  02072023_171006_1010         0.996680
# 164  starmap_plus_mouse_cns  02072023_165903_1009         0.994956
# 165  starmap_plus_mouse_cns  02072023_165304_1008         0.982935
# 154  starmap_plus_mouse_cns  03072023_122014_2000         0.985470
# 157  starmap_plus_mouse_cns  03072023_122014_2002         0.996586
# 158  starmap_plus_mouse_cns  03072023_122014_2001         0.994314
# 159  starmap_plus_mouse_cns  03072023_122014_2003         0.998202
# 152  starmap_plus_mouse_cns  03072023_131004_2007         0.998446
# 153  starmap_plus_mouse_cns  03072023_125310_2006         0.997125
# 160  starmap_plus_mouse_cns  03072023_122014_2005         0.995732
# 161  starmap_plus_mouse_cns  03072023_122014_2004         0.988537
# 155  starmap_plus_mouse_cns  03072023_122014_3000         0.988329
# 156  starmap_plus_mouse_cns  03072023_122014_3001         0.996513
# 210  starmap_plus_mouse_cns    01072023_155436_36         0.998368
# 211  starmap_plus_mouse_cns    01072023_150751_35         0.997496
#
#      val_gene_expr_mse_score lambda_edge_recon_ lambda_gene_expr_recon_  \
# 212                 0.900167                0.0                     0.0
# 213                 0.962689                0.0                     0.0
# 214                 0.974185                0.0                     0.0
# 148                 0.673327                0.0                    30.0
# 149                 0.641392                0.0                    30.0
# 150                 0.643315                0.0                    30.0
# 151                 0.693365                0.0                    30.0
# 144                 0.593698                0.0                   300.0
# 145                 0.624603                0.0                   300.0
# 146                 0.633484                0.0                   300.0
# 147                 0.698776                0.0                   300.0
# 170                 0.921705            50000.0                     0.0
# 171                 0.895831            50000.0                     0.0
# 172                 0.937892            50000.0                     0.0
# 173                 0.995836            50000.0                     0.0
# 166                 0.656570            50000.0                    30.0
# 167                 0.648792            50000.0                    30.0
# 168                 0.644544            50000.0                    30.0
# 169                 0.631378            50000.0                    30.0
# 162                 0.610748            50000.0                   300.0
# 163                 0.591022            50000.0                   300.0
# 164                 0.625947            50000.0                   300.0
# 165                 0.702414            50000.0                   300.0
# 154                 1.007066           500000.0                     0.0
# 157                 0.929094           500000.0                     0.0
# 158                 0.947988           500000.0                     0.0
# 159                 0.899099           500000.0                     0.0
# 152                 0.621218           500000.0                    30.0
# 153                 0.636808           500000.0                    30.0
# 160                 0.693980           500000.0                    30.0
# 161                 0.694366           500000.0                    30.0
# 155                 0.662448           500000.0                   300.0
# 156                 0.638468           500000.0                   300.0
# 210                 0.626714           500000.0                   300.0
# 211                 0.622627           500000.0                   300.0
#
#     n_neighbors nichenet_keep_target_genes_ratio  \
# 212          12                              0.1
# 213           8                              0.1
# 214           4                              0.1
# 148          16                              0.1
# 149          12                              0.1
# 150           8                              0.1
# 151           4                              0.1
# 144          16                              0.1
# 145          12                              0.1
# 146           8                              0.1
# 147           4                              0.1
# 170          16                              0.1
# 171          12                              0.1
# 172           8                              0.1
# 173           4                              0.1
# 166          16                              0.1
# 167          12                              0.1
# 168           8                              0.1
# 169           4                              0.1
# 162          16                              0.1
# 163          12                              0.1
# 164           8                              0.1
# 165           4                              0.1
# 154           4                              0.1
# 157          12                              0.1
# 158           8                              0.1
# 159          16                              0.1
# 152          16                              0.1
# 153          12                              0.1
# 160           8                              0.1
# 161           4                              0.1
# 155           4                              0.1
# 156           8                              0.1
# 210          16                              0.1
# 211          12                              0.1
#
#     add_fc_gps_instead_of_gp_dict_gps  \
# 212                             False
# 213                             False
# 214                             False
# 148                             False
# 149                             False
# 150                             False
# 151                             False
# 144                             False
# 145                             False
# 146                             False
# 147                             False
# 170                             False
# 171                             False
# 172                             False
# 173                             False
# 166                             False
# 167                             False
# 168                             False
# 169                             False
# 162                             False
# 163                             False
# 164                             False
# 165                             False
# 154                             False
# 157                             False
# 158                             False
# 159                             False
# 152                             False
# 153                             False
# 160                             False
# 161                             False
# 155                             False
# 156                             False
# 210                             False
# 211                             False
#
#                                           loss_weights
# 212  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 213  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 214  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 148  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 149  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 150  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 151  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 144  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 145  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 146  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 147  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 170  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 171  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 172  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 173  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 166  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 167  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 168  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 169  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 162  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 163  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 164  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 165  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 154  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 157  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 158  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 159  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 152  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 153  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 160  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 161  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 155  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 156  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 210  lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 211  lambda_edge_recon_500000.0_+_lambda_gene_expr_...

# %%
for dataset in datasets:
    summary_df[summary_df["dataset"] == dataset].to_csv(f"{miscellaneous_folder_path}/mlflow_summary_{ablation_task}_ablation_{dataset}.csv")

# %%
summary_df = pd.read_csv(f"{miscellaneous_folder_path}/mlflow_summary_{ablation_task}_ablation.csv", index_col=0)

# %%
summary_df
# Out:
#                         dataset             timestamp  val_auroc_score  \
# 0    xenium_human_breast_cancer  02072023_073546_2011         0.996472
# 1    xenium_human_breast_cancer  02072023_072424_2010         0.995574
# 2    xenium_human_breast_cancer  02072023_064949_2009         0.992328
# 3    xenium_human_breast_cancer  02072023_064251_2008         0.979258
# 4    xenium_human_breast_cancer  02072023_053747_2007         0.996632
# ..                          ...                   ...              ...
# 286      starmap_plus_mouse_cns     29062023_161622_7         0.997866
# 287      starmap_plus_mouse_cns    29062023_161622_11         0.979904
# 288      starmap_plus_mouse_cns    29062023_161622_12         0.997421
# 289      starmap_plus_mouse_cns     29062023_161622_1         0.560831
# 290      starmap_plus_mouse_cns     29062023_161622_2         0.525714
#
#      val_gene_expr_mse_score  lambda_edge_recon_  lambda_gene_expr_recon_  \
# 0                   1.660857            500000.0                    300.0
# 1                   1.605819            500000.0                    300.0
# 2                   1.533650            500000.0                    300.0
# 3                   1.426696            500000.0                    300.0
# 4                   1.799987            500000.0                     30.0
# ..                       ...                 ...                      ...
# 286                 0.470623                 0.0                     30.0
# 287                 0.499574                 0.0                    300.0
# 288                 0.481453                 0.0                    300.0
# 289                 0.707935                 0.0                      0.0
# 290                 0.647292                 0.0                      0.0
#
#      n_neighbors  add_fc_gps_instead_of_gp_dict_gps  \
# 0             16                              False
# 1             12                              False
# 2              8                              False
# 3              4                              False
# 4             16                              False
# ..           ...                                ...
# 286            8                               True
# 287            4                               True
# 288            8                               True
# 289            4                               True
# 290            8                               True
#
#                                           loss_weights
# 0    lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 1    lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 2    lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 3    lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# 4    lambda_edge_recon_500000.0_+_lambda_gene_expr_...
# ..                                                 ...
# 286  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 287  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 288  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 289  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 290  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
#
# [291 rows x 9 columns]

# %%
summary_df = summary_df[summary_df["dataset"] == "xenium_human_breast_cancer"]

# %%
summary_df[46:].to_csv(f"{miscellaneous_folder_path}/mlflow_summary_loss_weights_ablation_xenium_human_breast_cancer.csv")

# %%
summary_df = pd.read_csv(f"{miscellaneous_folder_path}/mlflow_summary_loss_weights_ablation_xenium_human_breast_cancer.csv", index_col=0)

# %%
summary_df
# Out:
#                         dataset           timestamp  val_auroc_score  \
# 46   xenium_human_breast_cancer   01072023_174536_6         0.969510
# 47   xenium_human_breast_cancer   01072023_174214_5         0.932853
# 48   xenium_human_breast_cancer   01072023_173609_4         0.500000
# 49   xenium_human_breast_cancer   01072023_173609_3         0.500000
# 50   xenium_human_breast_cancer   01072023_162730_2         0.500000
# ..                          ...                 ...              ...
# 139  xenium_human_breast_cancer  28062023_164600_11         0.965506
# 140  xenium_human_breast_cancer  28062023_164600_12         0.993967
# 141  xenium_human_breast_cancer  28062023_164600_13         0.997351
# 142  xenium_human_breast_cancer  28062023_164600_16         0.973018
# 143  xenium_human_breast_cancer  28062023_164600_14         0.998378
#
#      val_gene_expr_mse_score  lambda_edge_recon_  lambda_gene_expr_recon_  \
# 46                  1.547869                 0.0                     30.0
# 47                  1.402551                 0.0                     30.0
# 48                  5.073387                 0.0                      0.0
# 49                  5.118559                 0.0                      0.0
# 50                  5.130722                 0.0                      0.0
# ..                       ...                 ...                      ...
# 139                 2.606598                 0.0                    300.0
# 140                 2.656636                 0.0                    300.0
# 141                 2.624020                 0.0                    300.0
# 142                 4.571494             50000.0                      0.0
# 143                 2.626300                 0.0                    300.0
#
#      n_neighbors  add_fc_gps_instead_of_gp_dict_gps  \
# 46             8                              False
# 47             4                              False
# 48            16                              False
# 49            12                              False
# 50             8                              False
# ..           ...                                ...
# 139            4                               True
# 140            8                               True
# 141           12                               True
# 142            4                               True
# 143           16                               True
#
#                                           loss_weights
# 46   lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 47   lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 48   lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 49   lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 50   lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# ..                                                 ...
# 139  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 140  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 141  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
# 142  lambda_edge_recon_50000.0_+_lambda_gene_expr_r...
# 143  lambda_edge_recon_0.0_+_lambda_gene_expr_recon...
#
# [98 rows x 9 columns]

# %%
# Compute metrics and add to summary df
metrics_df = pd.DataFrame()
for i, dataset in enumerate(datasets):
    # Get timestamps of ablation runs for specific dataset
    timestamps = summary_df[(summary_df["dataset"] == dataset) & (summary_df["val_auroc_score"].notnull())]["timestamp"].tolist()
    
    # Compute metrics for ablation runs models
    current_iteration_metrics_df = compute_metrics(
        artifact_folder_path=artifact_folder_path,
        dataset=dataset,
        task=ablation_task + "_ablation",
        timestamps=timestamps,
        cell_type_key=cell_type_keys[i],
        condition_key=condition_keys[i],
        spatial_knng_key=spatial_knng_key,
        latent_knng_key=latent_knng_key,
        spatial_key=spatial_key,
        latent_key=latent_key)
    metrics_df = pd.concat([metrics_df, current_iteration_metrics_df], axis=0)
summary_df = pd.merge(summary_df, metrics_df, on=["dataset", "timestamp"], how="left")
# Out:
# Loading xenium_human_breast_cancer model with timestamp 29062023_014049_44.
# Computing metric CLISIS
# Computing spatial nearest neighbor graph for entire dataset...
# /root/miniconda3/envs/nichecompass-reproducibility/lib/python3.9/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# Computing spatial cell CLISI scores for entire dataset...
# Computing latent nearest neighbor graph...
# Computing latent cell CLISI scores...
# KeyboardInterrupt

# %%
test_df = summary_df.dropna()

# %%
test_df

# %%
ablation_col = "loss_weights"
dataset_col = "dataset"
group_cols = [dataset_col] + [ablation_col]
metric_cols = ["cas", "mlami", "gcs", "cca"]
metric_cols_weights = [0.6, 0.6, 0.6, 0.4]
metric_score_cols = [metric_col + "_points" for metric_col in metric_cols]

# Compute ablation points
points_df = compute_ablation_points(
    df=test_df,
    group_col=ablation_col,
    metric_cols=metric_cols,
    metric_cols_weights=metric_cols_weights,
    sort_metric_col="total_score")

# %%
# Plot metrics
for dataset in datasets:
    dataset_df = points_df[points_df["dataset"] == dataset]
    plot_metrics(
        fig_title=f"Loss Weights Ablation: {dataset}",
        df=dataset_df,
        group_col="loss_weights",
        metric_cols=metric_cols,
        plot_ratio_active_gps=False,
        save_fig=False,
        file_name="ablation_metrics.png")

# %%
ablation_col = "loss_weights"
dataset_col = "dataset"
group_cols = [dataset_col] + [ablation_col]
metric_cols = ["cas", "mlami", "gcs", "cca"]
metric_cols_weights = [0.6, 0.6, 0.6, 0.4]
metric_score_cols = [metric_col + "_points" for metric_col in metric_cols]

# %%
# Unroll points df and compute means over group columns and score type
unrolled_points_df = pd.melt(points_df, 
   id_vars=group_cols,
   value_vars=metric_score_cols,
   var_name="score_type", 
   value_name="score")

# Compute metric means over all runs
mean_points_df = unrolled_points_df.groupby(group_cols + ["score_type"]).mean()
mean_points_df.reset_index(inplace=True)

# %%
mean_points_df

# %%
group_cols + ["score_type"]

# %%
group_cols

# %%
mean_points_df

# %%
plot_ablation_points(df=mean_points_df,
                     ablation_col=ablation_col,
                     ablation_col_width=7,
                     group_col=dataset_col,
                     metric_cols=metric_score_cols,
                     show=True,
                     save_dir=None,
                     save_name="ablation_results.svg")

# %%
visualize_latent_embeddings(artifact_folder_path=artifact_folder_path,
                            plot_label="test",
                            task=ablation_task + "_ablation",
                            timestamps=timestamps,
                            dataset="xenium_human_breast_cancer",
                            cat_key="cell_states",
                            sample_key="batch",
                            groups=None,
                            spot_size=30.,
                            save_fig=False)

# %% [markdown]
# ### 2.2 Encoder Architecture (GCN vs GATv2)

# %% [markdown]
# #### 2.1.2 Categorical Covariates Contrastive Loss

# %% [markdown]
# ### 2.5 Spatial Neighborhood Graph

# %%
visualize_niches(artifact_folder_path=artifact_folder_path,
                 dataset=dataset,
                 task=ablation_task + "_ablation",
                 timestamps=timestamps,
                 sample_key="batch",
                 latent_key=latent_key,
                 latent_leiden_resolution=0.2,
                 latent_cluster_key="nichecompass_latent_clusters",
                 spot_size=30.)

# %% [markdown]
# ### 2.5 Gene Program Mask

# %%
"""
# Log additional mlflow param
run_ids = []
runs_info = mlflow.list_run_infos(3)
for run_info in runs_info:
    run = mlflow.get_run(run_info.run_uuid)
    if "add_fc_gps_instead_of_gp_dict_gps" not in run.data.params:
        run_ids.append(run_info.run_uuid)
        
for run_id in run_ids:
    with mlflow.start_run(run_id=run_id) as run:
        mlflow.log_param("add_fc_gps_instead_of_gp_dict_gps", True)
"""
